# %% [markdown]
# # Integrantes
# - Anggie Quispe
# - Jeanfrank Rojo
# - Sebastian Pizzino

# %% [markdown]
# # WH7

# %% [markdown]
# # 1 - Insertar el link del repositorio del curso.

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }a
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }a
# </style>

# %%
#!pip install selenium
#!pip install webdriver-manager

# %%
# this library is to manipulate browser
from selenium import webdriver

# it allows you to work with differen versions of drivers
# We call ChromeDriver
from webdriver_manager.chrome import ChromeDriverManager
import re
import time

# %%
import os
import sys

# %%
# Case 1 - Download the driver

driver = webdriver.Chrome("../../Laboratorios/Lab8/chromedriver.exe")
driver.maximize_window()

url = 'https://github.com/Robertopucp/1ECO35_R_PYTHON'

driver.get( url )
# Out:
# C:\Users\Yoga\AppData\Local\Temp/ipykernel_22840/1124883701.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("../../Laboratorios/Lab8/chromedriver.exe")

# %% [markdown]
# # 2 - Replicar la tabla de inflación anual de marzo en el rango meta.

# %%
#!pip install prettytable 
from prettytable import PrettyTable as pt

# %%
tb = pt ()

# Add Headers 
tb.field_names = ["Positiva", "Peso", "Var.%", "Contr.", "Negativa", "Peso_", "Var.%_", "Contr._"]
#Add Rows 
tb.add_row(["Matrícula y pensión de enseñanza",8.8, 1.9,0.20, "Papa", 0.9, -3.7, -0.04])
tb.add_row(["Azúcar", 0.5, 13.6, 0.07, "Gasolina y lubricantes", 1.3, -1.8, -0.02])
tb.add_row(["Huevos", 0.6, 13.2, 0.07, "Mandarina", 0.2, -6.7, -0.02])
tb.add_row(["Cebolla", 0.4, 20.2, 0.06, "Palta", 0.1, -9.3, -0.02])
tb.add_row(["Otras Hortalizas", 0.4, 11.1, 0.06, "Pasaje de avión", 0.4, -4.6, -0.02])
tb.add_row(["Naranja de jugo", 0.1, 37.7, 0.04, "Carne de pollo", 3.0, -0.4, -0.01])
tb.add_row(["Tomate", 0.2, 15.0, 0.03, "Papaya", 0.2, -3.5, -0.01])
tb.add_row(["Limón", 0.2, 15.8, 0.03, "Choclo", 0.1, -4.9, -0.01])
tb.add_row(["Plátano", 0.3, 6.5, 0.03, "Olluco y similares", 0.1, -4.6, -0.01])
tb.add_row(["Zanahoria", 0.1, 15.4, 0.02, "Pescado fresco y congelado", 0.7, -0.7, -0.00])
tb.add_row(["Total","" ,"" , 0.61, "Total_","" ,"" , -0.16])

#Add title

print("Contribucion ponderada a la inflación: Marzo 2020")           
print(tb)
# Out:
# Contribucion ponderada a la inflación: Marzo 2020
# +----------------------------------+------+-------+--------+----------------------------+-------+--------+---------+
# |             Positiva             | Peso | Var.% | Contr. |          Negativa          | Peso_ | Var.%_ | Contr._ |
# +----------------------------------+------+-------+--------+----------------------------+-------+--------+---------+
# | Matrícula y pensión de enseñanza | 8.8  |  1.9  |  0.2   |            Papa            |  0.9  |  -3.7  |  -0.04  |
# |              Azúcar              | 0.5  |  13.6 |  0.07  |   Gasolina y lubricantes   |  1.3  |  -1.8  |  -0.02  |
# |              Huevos              | 0.6  |  13.2 |  0.07  |         Mandarina          |  0.2  |  -6.7  |  -0.02  |
# |             Cebolla              | 0.4  |  20.2 |  0.06  |           Palta            |  0.1  |  -9.3  |  -0.02  |
# ...

# %%
print(tb.get_html_string())    #Con este comando hacemos que el paquete de pretty table haga la conversion a un codigo html
# Out:
# <table>
#     <thead>
#         <tr>
#             <th>Positiva</th>
#             <th>Peso</th>
#             <th>Var.%</th>
#             <th>Contr.</th>
#             <th>Negativa</th>
#             <th>Peso_</th>
#             <th>Var.%_</th>
#             <th>Contr._</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Matrícula y pensión de enseñanza</td>
#             <td>8.8</td>
#             <td>1.9</td>
#             <td>0.2</td>
#             <td>Papa</td>
#             <td>0.9</td>
#             <td>-3.7</td>
#             <td>-0.04</td>
#         </tr>
#         <tr>
#             <td>Azúcar</td>
#             <td>0.5</td>
#             <td>13.6</td>
#             <td>0.07</td>
#             <td>Gasolina y lubricantes</td>
#             <td>1.3</td>
#             <td>-1.8</td>
#             <td>-0.02</td>
#         </tr>
#         <tr>
#             <td>Huevos</td>
#             <td>0.6</td>
#             <td>13.2</td>
# ...

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th>Positiva</th>
#             <th>Peso</th>
#             <th>Var.%</th>
#             <th>Contr.</th>
#             <th>Negativa</th>
#             <th>Peso_</th>
#             <th>Var.%_</th>
#             <th>Contr._</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Matrícula y pensión de enseñanza</td>
#             <td>8.8</td>
#             <td>1.9</td>
#             <td>0.2</td>
#             <td>Papa</td>
#             <td>0.9</td>
#             <td>-3.7</td>
#             <td>-0.04</td>
#         </tr>
#         <tr>
#             <td>Azúcar</td>
#             <td>0.5</td>
#             <td>13.6</td>
#             <td>0.07</td>
#             <td>Gasolina y lubricantes</td>
#             <td>1.3</td>
#             <td>-1.8</td>
#             <td>-0.02</td>
#         </tr>
#         <tr>
#             <td>Huevos</td>
#             <td>0.6</td>
#             <td>13.2</td>
#             <td>0.07</td>
#             <td>Mandarina</td>
#             <td>0.2</td>
#             <td>-6.7</td>
#             <td>-0.02</td>
#         </tr>
#         <tr>
#             <td>Cebolla</td>
#             <td>0.4</td>
#             <td>20.2</td>
#             <td>0.06</td>
#             <td>Palta</td>
#             <td>0.1</td>
#             <td>-9.3</td>
#             <td>-0.02</td>
#         </tr>
#         <tr>
#             <td>Otras Hortalizas</td>
#             <td>0.4</td>
#             <td>11.1</td>
#             <td>0.06</td>
#             <td>Pasaje de avión</td>
#             <td>0.4</td>
#             <td>-4.6</td>
#             <td>-0.02</td>
#         </tr>
#         <tr>
#             <td>Naranja de jugo</td>
#             <td>0.1</td>
#             <td>37.7</td>
#             <td>0.04</td>
#             <td>Carne de pollo</td>
#             <td>3.0</td>
#             <td>-0.4</td>
#             <td>-0.01</td>
#         </tr>
#         <tr>
#             <td>Tomate</td>
#             <td>0.2</td>
#             <td>15.0</td>
#             <td>0.03</td>
#             <td>Papaya</td>
#             <td>0.2</td>
#             <td>-3.5</td>
#             <td>-0.01</td>
#         </tr>
#         <tr>
#             <td>Limón</td>
#             <td>0.2</td>
#             <td>15.8</td>
#             <td>0.03</td>
#             <td>Choclo</td>
#             <td>0.1</td>
#             <td>-4.9</td>
#             <td>-0.01</td>
#         </tr>
#         <tr>
#             <td>Plátano</td>
#             <td>0.3</td>
#             <td>6.5</td>
#             <td>0.03</td>
#             <td>Olluco y similares</td>
#             <td>0.1</td>
#             <td>-4.6</td>
#             <td>-0.01</td>
#         </tr>
#         <tr>
#             <td>Zanahoria</td>
#             <td>0.1</td>
#             <td>15.4</td>
#             <td>0.02</td>
#             <td>Pescado fresco y congelado</td>
#             <td>0.7</td>
#             <td>-0.7</td>
#             <td>-0.0</td>
#         </tr>
#         <tr>
#             <td>Total</td>
#             <td></td>
#             <td></td>
#             <td>0.61</td>
#             <td>Total_</td>
#             <td></td>
#             <td></td>
#             <td>-0.16</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # 3- Crear las siguientes opciones para marcar (Lima Metropolitana, Lima provincia y Lima región ). Crear una lista despegable con las opciones de 5 distritos de Lima.

# %% [markdown]
# <html>
# <body>
#
# <h1>Lugar</h1>
#
# <form action="/action_page.php">
#   <input type="radio" id="limam" name="lugar" value="Lima Metropolitana">
#   <label for="limam">Lima Metropolitana</label><br>
#   <input type="radio" id="limap" name="lugar" value="Lima Provincia">
#   <label for="limap">Lima Provincia</label><br>
#   <input type="radio" id="limar" name="lugar" value="Lima Región">
#       <label for="limar">Lima Región</label><br>
#     </form>
#
# <h1>Seleccionar distrito</h1>
# <form action="/action_page.php">
#   <label for="distrito">Selecciona un distrito:</label>
#   <select name="distrito" id="distrito">
#     <option value="San Juan de Lurigancho">San Juan de Lurigancho</option>
#     <option value="Los Olivos">Los Olivos</option>
#     <option value="San Isidro">San Isidro</option>
#     <option value="La Molina">La Molina</option>
#     <option value="Miraflores">Miraflores</option>
#   </select>
#   <br><br>
# </form>
#     <button onclick="showContent()">Enviar</button>
#
# </body>
# </html>

# %% [markdown]
# # 4 - Crear un formulario para ingresar el nombre, apellidos, DNI y correo electrónico. Asimismo, debe añadirse un botón para enviar los resultados

# %% [markdown]
# <!DOCTYPE html>
# <html>
#     <h1>Formulario de registro</h1>
# <head>
# <body>
# <form action="/action_page.php">
#   <label for="fname">First name:</label>
#   <input type="text" id="fname" name="fname" placeholder="Ingrese su nombre"><br><br>
#   <label for="lname">Last name:</label>
#   <input type="text" id="lname" name="lname" placeholder="Ingrese su apellido"><br><br>
#   <label for="lname">DNI:</label>
#   <input type="text" id="DNI" name="DNI" placeholder="Ingrese su DNI"><br><br>
#   <label for="lname">Email:</label>
#   <input type="text" id="email" name="email" placeholder="Ingrese su email"><br><br>
#   <p>Estoy de acuerdo con <a href='#'>los términos y condiciones.</a></p>
#   <button onclick="showContent()">Registrar</button>
# </form>
# </body>
# </html>

# %% [markdown]
# # Página Onpe - Scrapper
# # - Extraer información de votos congresales de las ultimas elecciones general

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# ActionChains es una forma de automatizar interacciones de bajo nivel,
#como movimientos del mouse, acciones de botones del mouse 
# o realizar acciones más complejas como pasar el cursor por encima y arrastrar y soltar.

from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import time  
import re # Regular expression 
import unidecode  # read Not ASCII text
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )
# Maximize window

url = 'https://resultadoshistorico.onpe.gob.pe/EG2021/'
driver.get( url )
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Yoga\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\Yoga\AppData\Local\Temp/ipykernel_22840/801210642.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %%
results = driver.find_element_by_xpath("/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[3]/div/div/a/div[2]")

results.click() #le damos click a los resultados congresales
# Out:
# C:\Users\Yoga\AppData\Local\Temp/ipykernel_22840/2339930505.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   results = driver.find_element_by_xpath("/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[3]/div/div/a/div[2]")

# %%
# Store all_tables
all_tables = {}

# %%
for rgn_idx in range( 26 ):
    rgn = Select( driver.find_element_by_id( "select_departamento" ) ) #Estamos creando un loop para seleccionar las diferentes regiones 
    region = rgn.options[ rgn_idx ]
    rgn_name = region.text #creamos rgn_name para todas las regiones 
    
    print(rgn_name)
    region.click() #hacemos click a todas las regiones
    
    ## Get table of presidential votes
    # Get html at this point
    table_path = driver.find_element_by_xpath("//*[@id='table-scroll']/div") 
    table_html = table_path.get_attribute( 'innerHTML' )
    # Read the table using pandas
    table = pd.read_html( table_html )
    # Get UBIGEO
    ubigeo = driver.current_url.split("/")[ -1 ]   #El URL sabemos que esta divido por "/" y al final esta el ubigeo, por ello "-1"
                                           
    #Cleaningtables
    row_new_columns = table[ 0 ].iloc[ 0 , 1:5 ] #seleccionamos la fila desde el 0 y columnas 1:5
    clean_columns = row_new_columns.str.replace( " ", "_").str.lower().str.replace( "%", "share_").tolist() #limpiamos la tabla con espacios y reemplazamos valores como % por share_
     # Selecting specific columns
    table_clean = table[0].iloc[ 1:, 1:5 ].copy()
    # rename columns
    table_clean.columns = clean_columns
     
    # New values to columns 
    table_clean[ 'region' ] = rgn_name
    table_clean[ 'ubigeo' ] = ubigeo
                        
  # store tables
    all_tables[ ubigeo ] = table_clean
# Out:
# C:\Users\Yoga\AppData\Local\Temp/ipykernel_22840/2022193112.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rgn = Select( driver.find_element_by_id( "select_departamento" ) ) #Estamos creando un loop para seleccionar las diferentes regiones
# C:\Users\Yoga\AppData\Local\Temp/ipykernel_22840/2022193112.py:11: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   table_path = driver.find_element_by_xpath("//*[@id='table-scroll']/div")
# AMAZONAS
# ANCASH
# APURIMAC
# AREQUIPA
# AYACUCHO
# CAJAMARCA
# CALLAO
# CUSCO
# HUANCAVELICA
# HUANUCO
# ICA
# JUNIN
# LA LIBERTAD
# LAMBAYEQUE
# LIMA
# LIMA PROVINCIAS
# LORETO
# MADRE DE DIOS
# MOQUEGUA
# PASCO
# PIURA
# PUNO
# SAN MARTIN
# TACNA
# TUMBES
# UCAYALI

# %%
all_tables['D44026']    #en este caso seleccionamosla tabla  del ubigeo de Ucayali
# Out:
#                          organizaciones_políticas   total share_válidos  \
# 1   FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP    9967        5.802%
# 2                    PARTIDO NACIONALISTA PERUANO    2644        1.539%
# 3                                  PARTIDO MORADO    3672        2.138%
# 4                               VICTORIA NACIONAL    9957        5.797%
# 5                                  ACCION POPULAR   20274       11.803%
# 6                                    PODEMOS PERU   15619        9.093%
# 7                              JUNTOS POR EL PERU   13665        7.955%
# 8                 PARTIDO POPULAR CRISTIANO - PPC    3808        2.217%
# 9                                  FUERZA POPULAR   30098       17.522%
# 10                              UNION POR EL PERU    8389        4.884%
# 11                             RENOVACION POPULAR    9623        5.602%
# 12                    RENACIMIENTO UNIDO NACIONAL    1112        0.647%
# ...

# %%
final_data = pd.concat( all_tables.values() ).reset_index( drop = True )

# %%
final_data
# Out:
#                            organizaciones_políticas   total share_válidos  \
# 0     FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP    2000        1.678%
# 1                      PARTIDO NACIONALISTA PERUANO   11651        9.772%
# 2    EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD    2923        2.452%
# 3                                    PARTIDO MORADO    3641        3.054%
# 4                                 VICTORIA NACIONAL    6109        5.124%
# ..                                              ...     ...           ...
# 558                        ALIANZA PARA EL PROGRESO   17190       10.007%
# 559                          TOTAL DE VOTOS VÁLIDOS  171774      100.000%
# 560                                   VOTOS BLANCOS   37820           NaN
# 561                                     VOTOS NULOS   48800           NaN
# 562                         TOTAL DE VOTOS EMITIDOS  258394           NaN
#
#     share_emitidos    region  ubigeo
# 0           1.086%  AMAZONAS  D44001
# ...

# %%
final_data.to_excel(r'C:\Users\Yoga\Documents\GitHub\1ECO35_R_PYTHON\Trabajo_grupal\WH7\onpe_congreso_grupo_(2).xlsx', index = False) #Guardamos la data en formato excel
