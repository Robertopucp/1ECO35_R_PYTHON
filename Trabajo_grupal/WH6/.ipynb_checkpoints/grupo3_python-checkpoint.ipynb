# %% [markdown]
# ## 1. Plots

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# #### Use la base de tados pesos.dta almacenada en la carpeta \data\Pesos

# %%
pesos = pd.read_stata(r"C:\Users\maria\OneDrive\Documentos\GitHub\R-y-Python\Pesos\peso.dta")
pesos
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 0       13.5    16.5  122.300003  109.0      12.0      12.0     1.0   1.0
# 1        7.5    16.5  122.300003  133.0       6.0      12.0     2.0   1.0
# 2        0.5    16.5  122.300003  129.0       NaN      12.0     2.0   0.0
# 3       15.5    16.5  122.300003  126.0      12.0      12.0     2.0   1.0
# 4       27.5    16.5  122.300003  134.0      14.0      12.0     2.0   1.0
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1383    27.5    30.0  138.300003  110.0      12.0      12.0     4.0   1.0
# 1384     5.5    30.0  138.300003  146.0       NaN      16.0     2.0   1.0
# 1385    65.0     8.0  118.599998  135.0      18.0      16.0     2.0   0.0
# 1386    27.5     8.0  118.599998  118.0       NaN      14.0     2.0   0.0
# 1387    37.5     8.0  118.599998  111.0      16.0      13.0     2.0   0.0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %% [markdown]
# #### En un mismo gráfico presente la distribución absoluta, frecuencia y densidades de los pesos de los recién nacidos si la madre es fumadora o no. El gráfico debe presentar titulo, títulos en ejes y leyenda.

# %% [markdown]
# Crear una dummy si la madre es fumadora de cigarros

# %%
def f(pesos):
    if pesos["cigs"]  > 0:
        val = 1
    else:
        val = 0
    return val

pesos['dummy'] = pesos.apply(f, axis=1)
pesos
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 0       13.5    16.5  122.300003  109.0      12.0      12.0     1.0   1.0
# 1        7.5    16.5  122.300003  133.0       6.0      12.0     2.0   1.0
# 2        0.5    16.5  122.300003  129.0       NaN      12.0     2.0   0.0
# 3       15.5    16.5  122.300003  126.0      12.0      12.0     2.0   1.0
# 4       27.5    16.5  122.300003  134.0      14.0      12.0     2.0   1.0
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1383    27.5    30.0  138.300003  110.0      12.0      12.0     4.0   1.0
# 1384     5.5    30.0  138.300003  146.0       NaN      16.0     2.0   1.0
# 1385    65.0     8.0  118.599998  135.0      18.0      16.0     2.0   0.0
# 1386    27.5     8.0  118.599998  118.0       NaN      14.0     2.0   0.0
# 1387    37.5     8.0  118.599998  111.0      16.0      13.0     2.0   0.0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc  dummy
# ...

# %%
fig, axes = plt.subplots(1, 3)
plt.rcParams["figure.figsize"] = [15, 6]

sns.histplot(data=pesos, x="lbwght", hue="dummy", kde=True, ax=axes[2])

sns.kdeplot(data=pesos, x="lbwght", hue="dummy", cut=0, fill=True, common_norm=False, alpha=0.2, ax=axes[1])

sns.histplot(data=pesos, x="lbwght", hue="dummy", ax=axes[0])
plt.ylabel("Distribución absoluta")
plt.title("Log peso del bebé (Si la madre es o no fumadora)")

plt.show()

# %% [markdown]
# #### Crear un coefplot de las siguientes tres regresiones:

# %% [markdown]
# a) lbwght ~ Dummy

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
flex = ' lbwght ~ dummy '
nocontrol_model = smf.ols( formula = flex, data = pesos )
nocontrol_est = nocontrol_model.fit().summary2().tables[1]['Coef.']['dummy']
HCV_coefs = nocontrol_model.fit().cov_HC0
nocontrol_se = np.power( HCV_coefs.diagonal() , 0.5)[1]

print(nocontrol_model.fit().summary2().tables[1])
print( f"Coefficient for OLS with controls {nocontrol_est}" )
# print unconditional effect of gender and the corresponding standard error
print( f'The estimated gender coefficient is {nocontrol_est} and the corresponding robust standard error is {nocontrol_se}' )

nocontrol_model.fit().conf_int( alpha=0.05 ).loc['dummy']
# Out:
#               Coef.  Std.Err.           t         P>|t|    [0.025    0.975]
# Intercept  4.771778  0.005503  867.137073  0.000000e+00  4.760984  4.782573
# dummy     -0.076913  0.014081   -5.462332  5.563417e-08 -0.104534 -0.049291
# Coefficient for OLS with controls -0.07691258345071249
# The estimated gender coefficient is -0.07691258345071249 and the corresponding robust standard error is 0.013741452598044426
# 0   -0.104534
# 1   -0.049291
# Name: dummy, dtype: float64

# %% [markdown]
# b) lbwght ~ Dummy + mothedu

# %%
flex1 = ' lbwght ~ dummy + motheduc '
control_model1 = smf.ols( formula = flex1, data = pesos) 
control_est1 = control_model1.fit().summary2().tables[1]['Coef.']['dummy']

print(control_model1.fit().summary2().tables[1])
print( f"Coefficient for OLS with controls {control_est1}" )

HCV_coefs1 = control_model1.fit().cov_HC0
control_se1 = np.power( HCV_coefs1.diagonal() , 0.5)[1]

control_model1.fit().conf_int( alpha=0.05 ).loc['dummy']
# Out:
#               Coef.  Std.Err.           t         P>|t|    [0.025    0.975]
# Intercept  4.737780  0.029402  161.139867  0.000000e+00  4.680103  4.795456
# dummy     -0.073028  0.014479   -5.043736  5.170337e-07 -0.101432 -0.044625
# motheduc   0.002588  0.002193    1.180098  2.381642e-01 -0.001714  0.006890
# Coefficient for OLS with controls -0.07302847753068187
# 0   -0.101432
# 1   -0.044625
# Name: dummy, dtype: float64

# %% [markdown]
# c) lbwght~ Dummy + mothedu + lfaminc + white + Dummy:(mothedu + lfaminc + white)

# %%
flex2 = ' lbwght ~ dummy + motheduc + lfaminc + white + (dummy)*( motheduc +  lfaminc + white) '
control_model2 = smf.ols( formula = flex2, data = pesos) 
control_est2 = control_model2.fit().summary2().tables[1]['Coef.']['dummy']

print(control_model2.fit().summary2().tables[1])
print( f"Coefficient for OLS with controls {control_est2}" )

HCV_coefs2 = control_model2.fit().cov_HC0
control_se2 = np.power( HCV_coefs2.diagonal() , 0.5)[1]

control_model2.fit().conf_int( alpha=0.05 ).loc['dummy']
# Out:
#                    Coef.  Std.Err.           t     P>|t|    [0.025    0.975]
# Intercept       4.695856  0.031758  147.865604  0.000000  4.633557  4.758154
# dummy           0.012595  0.093189    0.135157  0.892508 -0.170213  0.195403
# motheduc        0.001314  0.002493    0.527148  0.598176 -0.003577  0.006205
# lfaminc         0.003137  0.007111    0.441078  0.659225 -0.010813  0.017086
# white           0.062192  0.014332    4.339514  0.000015  0.034078  0.090306
# dummy:motheduc -0.008570  0.008081   -1.060483  0.289111 -0.024423  0.007283
# dummy:lfaminc   0.019471  0.016682    1.167204  0.243330 -0.013253  0.052196
# dummy:white    -0.049757  0.035563   -1.399113  0.162004 -0.119522  0.020007
# Coefficient for OLS with controls 0.012595146073766439
# 0   -0.170213
# 1    0.195403
# Name: dummy, dtype: float64

# %%
table3 = np.zeros( ( 3 , 4 ) )

table3[0,0] = nocontrol_est
table3[0,1] = nocontrol_se 
table3[0,2] = nocontrol_model.fit().conf_int( alpha=0.05 ).loc['dummy'][0]
table3[0,3] = nocontrol_model.fit().conf_int( alpha=0.05 ).loc['dummy'][1] 

table3[1,0] = control_est1
table3[1,1] = control_se1  
table3[1,2] = control_model1.fit().conf_int( alpha=0.05 ).loc['dummy'][0]
table3[1,3] = control_model1.fit().conf_int( alpha=0.05 ).loc['dummy'][1] 

table3[2,0] = control_est2
table3[2,1] = control_se2  
table3[2,2] = control_model2.fit().conf_int( alpha=0.05 ).loc['dummy'][0]
table3[2,3] = control_model2.fit().conf_int( alpha=0.05 ).loc['dummy'][1] 

table3_pandas = pd.DataFrame( table3, columns = [ "Estimate","Std. Error","Lower_bound" , "Upper_bound"])
table3_pandas.index = [ "no_control", "lbwght ~ dummy + mothedu", "lbwght ~ dummy + mothedu + ..."]

table3_pandas.reset_index(inplace = True)
table3_pandas.rename(columns = {"index" : "Model"}, inplace = True)

table3_pandas.round(8)
# Out:
#                             Model  Estimate  Std. Error  Lower_bound  \
# 0                      no_control -0.076913    0.013741    -0.104534
# 1        lbwght ~ dummy + mothedu -0.073028    0.014140    -0.101432
# 2  lbwght ~ dummy + mothedu + ...  0.012595    0.088879    -0.170213
#
#    Upper_bound
# 0    -0.049291
# 1    -0.044625
# 2     0.195403

# %%
table3_pandas['errors'] = table3_pandas['Estimate'] - table3_pandas['Lower_bound']

# %%
fig, ax = plt.subplots(figsize=(10, 6))
    
    
   # Coefficients
ax.scatter(x=pd.np.arange(table3_pandas.shape[0]), 
         marker='o', s=80, 
         y=table3_pandas['Estimate'], color='black')

# Error bars for 95% confidence interval
# Can increase capsize to add whiskers
eb1 = plt.errorbar(x=table3_pandas["Model"], y=table3_pandas['Estimate'],
            yerr=table3_pandas['errors'], color = 'darkblue', ls='', capsize = 8)

eb1[-1][0].set_linestyle('--')
    
# Set title & labels
plt.title('Coefficients confindece interval at 5% confidence level',fontsize=15)
ax.set_ylabel('Coefficients',fontsize=15)
ax.set_xlabel('',fontsize=22)

    
plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_26452/3827401918.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   ax.scatter(x=pd.np.arange(table3_pandas.shape[0]),

# %% [markdown]
# ## 2 - Regular expresión y Geocoding

# %% [markdown]
# #### Use la base de datos mental_health_center para crear las columnas del tipo de institución del centro de salud y del RUC. Nótese que esta información está contenida en la columna Institución_ruc.

# %%
mental = pd.read_excel(r"C:\Users\maria\OneDrive\Documentos\GitHub\R-y-Python\Centro_salud\Centro_salud_mental.xls")
mental. head(5)
# Out:
#   Departamento Provincia                       Distrito  UBIGEO  \
# 0       CALLAO    CALLAO                       LA PERLA   70104
# 1         LIMA      LIMA                          RIMAC  150128
# 2     AREQUIPA  AREQUIPA  JOSE LUIS BUSTAMANTE Y RIVERO   40129
# 3         LIMA      LIMA                          COMAS  150110
# 4  LA LIBERTAD  TRUJILLO                    EL PORVENIR  130102
#
#                                            Dirección  \
# 0    AVENIDA LA PAZ CUADRA 3 LA PERLA CALLAO CALLAO
# 1  Calle Los Virreyes 205. Urbanización El Manzan...
# 2  AVENIDA CARACAS NÚMERO 807 URBANIZACIÓN SIMÓN ...
# 3  Los Rosales Mz G8 Lt 02 altura de la 33 de la ...
# 4  Mz Z1 Antenor Orrego - Rio Seco. Ref. Casa Bla...
#
#                  Institución_ruc
# 0  GOBIERNO REGIONAL 20147907487
# 1              MINSA 20602217508
# 2  GOBIERNO REGIONAL 20172661794
# 3              MINSA 20602217508
# 4  GOBIERNO REGIONAL 20218911189

# %%
mental ['Institución'] = mental['Institución_ruc'].str.strip().str.extract('([A-Z ]+)')
mental ['Ruc'] = mental.Institución_ruc.str.extract(r'(\d+)')
mental
# Out:
#      Departamento          Provincia                       Distrito  UBIGEO  \
# 0          CALLAO             CALLAO                       LA PERLA   70104
# 1            LIMA               LIMA                          RIMAC  150128
# 2        AREQUIPA           AREQUIPA  JOSE LUIS BUSTAMANTE Y RIVERO   40129
# 3            LIMA               LIMA                          COMAS  150110
# 4     LA LIBERTAD           TRUJILLO                    EL PORVENIR  130102
# 5     LA LIBERTAD           TRUJILLO              FLORENCIA DE MORA  130103
# 6     LA LIBERTAD           TRUJILLO                    EL PORVENIR  130102
# 7     LA LIBERTAD           TRUJILLO                       TRUJILLO  130101
# 8        APURIMAC        ANDAHUAYLAS                       TALAVERA   30216
# 9          LORETO             LORETO                          NAUTA  160301
# 10           LIMA               LIMA              VILLA EL SALVADOR  150142
# ...

# %% [markdown]
# #### Use la base de datos mental_health_center para crear columnas con las coordenadas geográficas y la dirección proporcionada por Google map. Resuelva usando un Loop o apply - lambda

# %%
geodata = pd.read_excel(r"C:\Users\maria\OneDrive\Documentos\GitHub\R-y-Python\Centro_salud\Centro_salud_mental.xls")
geodata
# Out:
#      Departamento          Provincia                       Distrito  UBIGEO  \
# 0          CALLAO             CALLAO                       LA PERLA   70104
# 1            LIMA               LIMA                          RIMAC  150128
# 2        AREQUIPA           AREQUIPA  JOSE LUIS BUSTAMANTE Y RIVERO   40129
# 3            LIMA               LIMA                          COMAS  150110
# 4     LA LIBERTAD           TRUJILLO                    EL PORVENIR  130102
# 5     LA LIBERTAD           TRUJILLO              FLORENCIA DE MORA  130103
# 6     LA LIBERTAD           TRUJILLO                    EL PORVENIR  130102
# 7     LA LIBERTAD           TRUJILLO                       TRUJILLO  130101
# 8        APURIMAC        ANDAHUAYLAS                       TALAVERA   30216
# 9          LORETO             LORETO                          NAUTA  160301
# 10           LIMA               LIMA              VILLA EL SALVADOR  150142
# ...

# %%
coord = np.zeros( (geodata['Dirección'].shape[0],2),  dtype =float)
coord.shape
# Out:
# (56, 2)

# %%
from tqdm import tqdm_notebook as tqdm

# %%
import googlemaps

i=0

for index,row in tqdm(geodata.iterrows()):
    
    gmaps = googlemaps.Client(key='AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE')

    # Geocoding an address
    geocode_result = gmaps.geocode(row['Dirección'] , region='pe')
    
    if len(geocode_result) == 0 :
        coord[i][0] = "nan"
        coord[i][1] = "nan"
        i=i+1
        print(row['Dirección'])
        print("el código encontró error")
        
    else :
        coord[i][0]=geocode_result[0]['geometry']['location']['lat']
        coord[i][1]=geocode_result[0]['geometry']['location']['lng']
        i=i+1
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_26452/1501919079.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index,row in tqdm(geodata.iterrows()):
# 0it [00:00, ?it/s]
# Los Rosales Mz G8 Lt 02 altura de la 33 de la Av. Los
# el código encontró error
# Jr. Pentagono s/n Ureb. Taparachi sector III
# el código encontró error
# Centro Recreacional Tomas Gálvez Quispe
# el código encontró error
# Av. Antonio Raymondi N°111
# el código encontró error

# %%
coord
# Out:
# array([[-12.0745861, -77.117829 ],
#        [-12.0286122, -77.0302312],
#        [-16.4341104, -71.5219477],
#        [        nan,         nan],
#        [ -8.0559028, -78.9910352],
#        [ -8.0809149, -79.0221257],
#        [ -8.0864106, -79.0085758],
#        [ -8.1006469, -79.0092751],
#        [-13.6574845, -73.4386466],
#        [ -4.5076451, -73.5766375],
#        [-12.1852213, -76.9651259],
#        [-12.0716654, -77.0135028],
#        [-16.0710704, -72.4879444],
#        [-13.3010672, -71.9633913],
#        [-13.5337646, -71.9092469],
#        [        nan,         nan],
#        [ -7.7061422, -78.0327377],
#        [-12.0384329, -76.9570244],
#        [ -5.0938488, -81.0962172],
#        [-12.8563839, -69.097023 ],
#        [ -3.5564921, -80.4270885],
#        [        nan,         nan],
#        [ -9.2954878, -76.0009236],
#        [-10.1734024, -75.8533954],
#        [-16.3499293, -72.1855395],
#        [ -7.1747042, -78.5094601],
#        [-10.5750237, -75.400011 ],
# ...

# %%
coord.tolist()
pd.DataFrame( coord.tolist(), index = geodata.index )
# Out:
#             0          1
# 0  -12.074586 -77.117829
# 1  -12.028612 -77.030231
# 2  -16.434110 -71.521948
# 3         NaN        NaN
# 4   -8.055903 -78.991035
# 5   -8.080915 -79.022126
# 6   -8.086411 -79.008576
# 7   -8.100647 -79.009275
# 8  -13.657485 -73.438647
# 9   -4.507645 -73.576638
# 10 -12.185221 -76.965126
# 11 -12.071665 -77.013503
# 12 -16.071070 -72.487944
# 13 -13.301067 -71.963391
# 14 -13.533765 -71.909247
# 15        NaN        NaN
# 16  -7.706142 -78.032738
# 17 -12.038433 -76.957024
# 18  -5.093849 -81.096217
# 19 -12.856384 -69.097023
# 20  -3.556492 -80.427088
# 21        NaN        NaN
# 22  -9.295488 -76.000924
# 23 -10.173402 -75.853395
# 24 -16.349929 -72.185539
# 25  -7.174704 -78.509460
# 26 -10.575024 -75.400011
# 27 -13.540050 -71.984353
# 28 -12.055837 -77.082258
# 29 -13.013732 -69.955034
# 30  -5.899128 -76.105955
# 31 -13.986091 -75.772759
# 32  -6.475638 -79.854984
# 33        NaN        NaN
# 34 -13.029529 -76.375305
# 35 -12.157974 -77.019332
# ...

# %%
geodata[ [ 'latitude' , 'longitud' ] ] = pd.DataFrame( coord.tolist() , index = geodata.index )
geodata
# Out:
#      Departamento          Provincia                       Distrito  UBIGEO  \
# 0          CALLAO             CALLAO                       LA PERLA   70104
# 1            LIMA               LIMA                          RIMAC  150128
# 2        AREQUIPA           AREQUIPA  JOSE LUIS BUSTAMANTE Y RIVERO   40129
# 3            LIMA               LIMA                          COMAS  150110
# 4     LA LIBERTAD           TRUJILLO                    EL PORVENIR  130102
# 5     LA LIBERTAD           TRUJILLO              FLORENCIA DE MORA  130103
# 6     LA LIBERTAD           TRUJILLO                    EL PORVENIR  130102
# 7     LA LIBERTAD           TRUJILLO                       TRUJILLO  130101
# 8        APURIMAC        ANDAHUAYLAS                       TALAVERA   30216
# 9          LORETO             LORETO                          NAUTA  160301
# 10           LIMA               LIMA              VILLA EL SALVADOR  150142
# ...
