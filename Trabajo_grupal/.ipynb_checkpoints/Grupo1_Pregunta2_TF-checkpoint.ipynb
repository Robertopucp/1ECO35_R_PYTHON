# %% [markdown]
# ## Manejo de información geo-referenciada

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 80%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 80%; }a
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 80%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 80%; }a
# </style>

# %%
# import package pandas, geopandas, plots

import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import chardet
import os
import seaborn as sns

import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString, Polygon


import contextily as cx  # import street map
#from pyproj import CRS

# %%
# selecting distric

district = ['ANCON','ATE','BARRANCO','BREÑA', 'CALLAO', 'CARABAYLLO','CHACLACAYO','CHORRILLOS','CIENEGUILLA','COMAS','EL_AGUSTINO','INDEPENDENCIA',
           'JESUS_MARIA','LA_MOLINA_LIMA','LA_VICTORIA','LIMA','LINCE','LOS_OLIVOS_LIMA','LURIGANCHO_LIMA','LURIN','MAGDALENA_DEL_MAR',
           'MIRAFLORES','PUEBLO_LIBRE','PUENTE_PIEDRA', 'RIMAC_LIMA','SAN_BORJA','SAN_ISIDRO','SAN_JUAN_DE_LURIGANCHO','SAN_JUAN_DE_MIRAFLORES','SAN_LUIS',
            'SAN_MARTIN_DE_PORRES','SAN_MIGUEL','SANTA_ANITA','SURCO','SURQUILLO','VILLA_EL_SALVADOR','VILLA_MARIA_DEL_TRIUNFO']

# %%
#datos  = gpd.read_file(r"..\Trabajo_final\5_Informacion_Cartografica-Shape\LIMA\LIMA.shp")

datos = r"../data/Trabajo_final/5_Informacion_Cartografica-Shape/"
 

i = 0

for j in district:
        i = i + 1
        globals()[f'manzana{i}']  = gpd.read_file(f'{datos}{j}/{j}.shp')
        globals()[f'manzana{i}']  = globals()[f'manzana{i}'][['Mz','geometry','UBIGEO']]
        globals()[f'manzana{i}']  = globals()[f'manzana{i}'].rename(columns = {"Mz":"id_manzana"})

        
       
        
mapa = manzana1.copy()

for k in range(2,i+1):
    mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# Out:
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_16076\2864693109.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)

# %%
mapa['bool_series'] = mapa.duplicated(["id_manzana"])

# %%
mapa[mapa['bool_series'] == 1]
mapa = mapa[mapa['bool_series'] == 0]
mapa
# Out:
#                 id_manzana                                           geometry  \
# 0       150102000102100023  POLYGON ((-77.12763 -11.81363, -77.12723 -11.8...
# 1       150102000101101010  POLYGON ((-77.15185 -11.73780, -77.15151 -11.7...
# 2       150102000100600037  POLYGON ((-77.16978 -11.77796, -77.16981 -11.7...
# 3       150102000101202048  POLYGON ((-77.15222 -11.74137, -77.15140 -11.7...
# 4      150102000101202010A  POLYGON ((-77.16253 -11.73364, -77.16255 -11.7...
# ...                    ...                                                ...
# 97602  150143000103400036D  POLYGON ((-76.93692 -12.16901, -76.93692 -12.1...
# 97603  150143000104600043L  POLYGON ((-76.91812 -12.16638, -76.91813 -12.1...
# 97604   150143000106800020  POLYGON ((-76.91389 -12.20689, -76.91403 -12.2...
# 97605   150143000108000026  POLYGON ((-76.90854 -12.22466, -76.90858 -12.2...
# 97606   150143000108000045  POLYGON ((-76.91243 -12.22237, -76.91248 -12.2...
#
#        UBIGEO  bool_series
# 0      150102        False
# 1      150102        False
# 2      150102        False
# 3      150102        False
# 4      150102        False
# ...       ...          ...
# 97602  150143        False
# 97603  150143        False
# 97604  150143        False
# 97605  150143        False
# 97606  150143        False
#
# [96932 rows x 4 columns]

# %%
manzana_data = pd.read_excel(r'../data/Trabajo_final/Salud_mental_peru.xls')
manzana_data
# Out:
#    Institución Departamento Provincia                 Distrito  UBIGEO  \
# 0        MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 1        MINSA         LIMA      LIMA  VILLA MARIA DEL TRIUNFO  150143
# 2        MINSA         LIMA      LIMA                SAN BORJA  150130
# 3        MINSA         LIMA      LIMA              LA VICTORIA  150115
# 4        MINSA         LIMA      LIMA          CERCADO DE LIMA  150101
# 5        MINSA         LIMA      LIMA            PUNTA HERMOZA  150126
# 6        MINSA         LIMA      LIMA                    RIMAC  150128
# 7        MINSA         LIMA      LIMA                    COMAS  150110
# 8        MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 9        MINSA         LIMA      LIMA              LA VICTORIA  150115
# 10       MINSA         LIMA      LIMA               LOS OLIVOS  150117
# 11       MINSA         LIMA      LIMA               PACHACAMAC  150123
# 12       MINSA         LIMA      LIMA                      ATE  150103
# 13       MINSA         LIMA      LIMA              EL AGUSTINO  150111
# 14       MINSA         LIMA      LIMA                LA MOLINA  150114
# 15       MINSA         LIMA      LIMA              CIENEGUILLA  150109
# 16       MINSA         LIMA      LIMA                    ANCON  150102
# 17       MINSA         LIMA      LIMA     SAN MARTIN DE PORRES  150135
# 18       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 19       MINSA         LIMA      LIMA            PUENTE PIEDRA  150125
# 20       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 21       MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 22       MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 23       MINSA         LIMA      LIMA               CARABAYLLO  150106
# 24       MINSA         LIMA      LIMA                     LIMA  150101
# 25       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 26       MINSA         LIMA      LIMA             PUEBLO LIBRE  150121
# 27       MINSA         LIMA      LIMA              SANTA ANITA  150137
# 28       MINSA         LIMA      LIMA                 BARRANCO  150104
# 29       MINSA         LIMA      LIMA  VILLA MARIA DEL TRIUNFO  150143
# 30       MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 31       MINSA         LIMA      LIMA                      ATE  150103
# 32       MINSA         LIMA      LIMA               CARABAYLLO  150106
# 33       MINSA         LIMA      LIMA            PUENTE PIEDRA  150125
# 34       MINSA         LIMA      LIMA               PACHACAMAC  150123
# 35       MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 36       MINSA         LIMA      LIMA   SAN JUAN DE MIRAFLORES  150133
# 37       MINSA         LIMA      LIMA              EL AGUSTINO  150111
#
#     lat_original long_original
# 0     -12.017282     -77.00095
# 1     -12.136658   -76.9482472
# 2     -12.107663    -76.999385
# 3     -12.062212    -77.005597
# 4     -12.066349    -77.035523
# 5     -12.333766    -76.823147
# 6     -12.029416  -77.02954497
# 7     -11.934511   -77.0456523
# 8     -12.186086   -76.9644885
# 9     -12.071416  -77.01337496
# 10    -11.977315   -77.0810609
# 11    -12.094998    -76.885043
# 12    -12.016739  -76.82504094
# 13    -12.032862  -77.00244761
# 14    -12.087299  -76.94220124
# 15    -12.112567    -76.817506
# 16    -11.709974   -77.1255055
# 17    -11.941694  -77.12550653
# 18    -12.191916  -77.00966007
# 19    -11.868171    -77.075281
# 20    -12.201012  -76.97877609
# 21    -12.201321   -76.9423404
# 22    -12.017345  -77.00097776
# 23    -11.901389  -77.03373058
# 24    -12.055652  -77.08246864
# 25    -12.159270   -77.0200131
# 26    -12.069488       -77.058
# 27    -12.045035    -76.975877
# 28    -12.146948   -77.0157362
# 29    -12.161575   -76.9382139
# 30    -12.243153   -76.9294507
# 31    -12.055808   -76.9528728
# 32    -11.880225  -76.99734605
# 33    -11.936079   -77.0941826
# 34    -12.128169    -76.871122
# 35    -12.002754   -77.0177604
# 36    -12.137509    -76.968200
# 37    -12.051241  -76.99732016

# %%
base_map_manzana = pd.merge(manzana_data, mapa , how = "inner" , on=['UBIGEO'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 base_map_manzana = pd.merge(manzana_data, mapa , how = "inner" , on=['UBIGEO'])
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\reshape\merge.py:704, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
#     700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
# --> 704 self._maybe_coerce_merge_keys()
#     706 # If argument passed to validate,
#     707 # check if columns specified as unique
#     708 # are in fact unique.
#     709 if validate is not None:
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\reshape\merge.py:1261, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1255     # unless we are merging non-string-like with string-like
#    1256     elif (
#    1257         inferred_left in string_types and inferred_right not in string_types
#    1258     ) or (
#    1259         inferred_right in string_types and inferred_left not in string_types
#    1260     ):
# -> 1261         raise ValueError(msg)
#    1263 # datetimelikes must match exactly
#    1264 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat

# %%
MAP = gpd.GeoDataFrame(base_map_manzana, geometry='geometry')

# %%
MAP['centroid'] = MAP['geometry'].centroid
#Extract lat and lon from the centerpoint
MAP["lat"] = MAP.centroid.map(lambda p: p.x)
MAP["long"] = MAP.centroid.map(lambda p: p.y)
