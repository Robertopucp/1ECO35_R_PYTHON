# %% [markdown]
# ## Trabajo grupal 2 - Grupo 1

# %% [markdown]
# ### Pregunta 1: If statement:

# %% [markdown]
# ###### Un archivo .csv llamado notas está en la carpeta data. Esta base de datos posee información de algunos postulantes universitarios a la universidad. Use if statement para crear una nueva columna e indicar si el el alumno ingreso o no (nota minima aprobatoria es 11). Luego crear un columna para colocar el nombre completo de la carrera a la que postulo el alumno (a001 : Economia, a002: quimica, a003: filosofia).

# %%
import pandas as pd
notes = pd.read_csv(r"..\..\data\notas.csv")
notes
# Out:
#      alumnos   notas carrera
# 0       DIEGO     10    a001
# 1     GABRIEL      4    a001
# 2       ANDRE      7    a001
# 3      ANDRES     16    a002
# 4    FERNANDO     16    a003
# 5    MILAGROS     19    a002
# 6       OSCAR      9    a001
# 7     RODRIGO      1    a003
# 8   ALEJANDRO      7    a001
# 9     LORENZO     21    a001
# 10     ELIANE     18    a001
# 11     ALDAIR     15    a002
# 12       LUIS      0    a004
# 13     JAVIER     12    a001
# 14     ALONSO     17    a002
# 15      MARCO     18    a001
# 16  SEBASTIAN     15    a004
# 17     LUZCIA      0    a001
# 18      NAYEL     18    a004
# 19    JOAQUIN      4    a002
# 20   ILIZARBE      6    a001
# 21    VIVIANA     18    a004
# 22       LUIS     10    a004
# 23      ROCIO     13    a002
# 24      LEIDY     21    a001
# 25    MELISSA     16    a002
# 26   FERNANDO     15    a001
# 27     MARTIN     21    a001
# 28    DANIELA     17    a003
# 29    GONZALO      7    a001
# 30      SOFIA      6    a003
# 31     ANGEL      10    a004
# 32     CAMILA      1    a001
# 33      ROSA       3    a001
# 34    MARCELO     21    a002
# 35      JOSUE     16    a001
# 36      RUBEN     19    a002
# 37       HUGO     13    a003

# %%
i=0
nrows = notes.notas.count()
while i < nrows:
    
    if notes['notas'][i] >= 11:
        notes.loc[[i],["Condicion"]] = "Aprobo"
    else:
        notes.loc[[i],["Condicion"]] = "No aprobo" 
    
    i += 1 

notes
# Out:
#      alumnos   notas carrera  Condicion
# 0       DIEGO     10    a001  No aprobo
# 1     GABRIEL      4    a001  No aprobo
# 2       ANDRE      7    a001  No aprobo
# 3      ANDRES     16    a002     Aprobo
# 4    FERNANDO     16    a003     Aprobo
# 5    MILAGROS     19    a002     Aprobo
# 6       OSCAR      9    a001  No aprobo
# 7     RODRIGO      1    a003  No aprobo
# 8   ALEJANDRO      7    a001  No aprobo
# 9     LORENZO     21    a001     Aprobo
# 10     ELIANE     18    a001     Aprobo
# 11     ALDAIR     15    a002     Aprobo
# 12       LUIS      0    a004  No aprobo
# 13     JAVIER     12    a001     Aprobo
# 14     ALONSO     17    a002     Aprobo
# 15      MARCO     18    a001     Aprobo
# 16  SEBASTIAN     15    a004     Aprobo
# 17     LUZCIA      0    a001  No aprobo
# 18      NAYEL     18    a004     Aprobo
# 19    JOAQUIN      4    a002  No aprobo
# 20   ILIZARBE      6    a001  No aprobo
# 21    VIVIANA     18    a004     Aprobo
# 22       LUIS     10    a004  No aprobo
# 23      ROCIO     13    a002     Aprobo
# 24      LEIDY     21    a001     Aprobo
# 25    MELISSA     16    a002     Aprobo
# 26   FERNANDO     15    a001     Aprobo
# 27     MARTIN     21    a001     Aprobo
# 28    DANIELA     17    a003     Aprobo
# 29    GONZALO      7    a001  No aprobo
# 30      SOFIA      6    a003  No aprobo
# 31     ANGEL      10    a004  No aprobo
# 32     CAMILA      1    a001  No aprobo
# 33      ROSA       3    a001  No aprobo
# 34    MARCELO     21    a002     Aprobo
# 35      JOSUE     16    a001     Aprobo
# 36      RUBEN     19    a002     Aprobo
# 37       HUGO     13    a003     Aprobo

# %%
i=0
nrows = notes.notas.count()
while i < nrows:
    
    if notes['carrera'][i] == "a001":
        notes.loc[[i],["nomb_carrera"]] = "Economía"
    elif notes['carrera'][i] == "a002":
        notes.loc[[i],["nomb_carrera"]] = "Química"
    elif  notes['carrera'][i] == "a003":
        notes.loc[[i],["nomb_carrera"]] = "Filosofía"
    else:
        notes.loc[[i],["nomb_carrera"]] = "NA"
    
    i += 1 
    
notes
# Out:
#      alumnos   notas carrera  Condicion nomb_carrera
# 0       DIEGO     10    a001  No aprobo     Economía
# 1     GABRIEL      4    a001  No aprobo     Economía
# 2       ANDRE      7    a001  No aprobo     Economía
# 3      ANDRES     16    a002     Aprobo      Química
# 4    FERNANDO     16    a003     Aprobo    Filosofía
# 5    MILAGROS     19    a002     Aprobo      Química
# 6       OSCAR      9    a001  No aprobo     Economía
# 7     RODRIGO      1    a003  No aprobo    Filosofía
# 8   ALEJANDRO      7    a001  No aprobo     Economía
# 9     LORENZO     21    a001     Aprobo     Economía
# 10     ELIANE     18    a001     Aprobo     Economía
# 11     ALDAIR     15    a002     Aprobo      Química
# 12       LUIS      0    a004  No aprobo           NA
# 13     JAVIER     12    a001     Aprobo     Economía
# 14     ALONSO     17    a002     Aprobo      Química
# 15      MARCO     18    a001     Aprobo     Economía
# 16  SEBASTIAN     15    a004     Aprobo           NA
# 17     LUZCIA      0    a001  No aprobo     Economía
# 18      NAYEL     18    a004     Aprobo           NA
# 19    JOAQUIN      4    a002  No aprobo      Química
# 20   ILIZARBE      6    a001  No aprobo     Economía
# 21    VIVIANA     18    a004     Aprobo           NA
# 22       LUIS     10    a004  No aprobo           NA
# 23      ROCIO     13    a002     Aprobo      Química
# 24      LEIDY     21    a001     Aprobo     Economía
# 25    MELISSA     16    a002     Aprobo      Química
# 26   FERNANDO     15    a001     Aprobo     Economía
# 27     MARTIN     21    a001     Aprobo     Economía
# 28    DANIELA     17    a003     Aprobo    Filosofía
# 29    GONZALO      7    a001  No aprobo     Economía
# 30      SOFIA      6    a003  No aprobo    Filosofía
# 31     ANGEL      10    a004  No aprobo           NA
# 32     CAMILA      1    a001  No aprobo     Economía
# 33      ROSA       3    a001  No aprobo     Economía
# 34    MARCELO     21    a002     Aprobo      Química
# 35      JOSUE     16    a001     Aprobo     Economía
# 36      RUBEN     19    a002     Aprobo      Química
# 37       HUGO     13    a003     Aprobo    Filosofía

# %% [markdown]
# ###### Use un loop while para mostrar el nombre de las personas ingresantes a la carrera de quimia.

# %%
i = 0

nrows = notes.notas.count()

while i < nrows:
    if (notes['Condicion'][i] == 'Aprobo' and notes['nomb_carrera'][i] == 'Química'):
        print(notes.iat[i,0])
    i += 1
# Out:
# ANDRES
# MILAGROS
# ALDAIR
# ALONSO
# ROCIO
# MELISSA
# MARCELO
# RUBEN

# %% [markdown]
# ### Pregunta 2: Loops:

# %% [markdown]
# ###### Simule un proceso generador de datos con 10 mil observaciones como se explicó en la primera práctica dirigida. Use un loop para obtener los coeficientes estimados con los siguientes tamaños de muestra (10, 50, 100,200,500,1000,5000). Guardar los coeficientes estimados en un Dataframe. Nombre las columnas del dataframe con los coeficientes estimados (i.e b1, b2, b3 ...) ; y las filas, con el tamaño de muestra (n=10 , n= 50, ... ).

# %%
import random 
import numpy as np
import pandas as pd

random.seed(74)

x1 = np.random.rand(5000) # uniform distribution  [0,1]
x2 = np.random.rand(5000) # uniform distribution [0,1]
e = np.random.normal(0,1,5000) # normal distribution mean = 0 and sd = 1

# Poblacional regression (Data Generating Process GDP)


Y = 1 + 3*x1 + 7*x2 + e

# %%
M = np.column_stack((np.ones(5000),x1,x2))
M
# Out:
# array([[1.        , 0.71018754, 0.29289964],
#        [1.        , 0.64334418, 0.27485783],
#        [1.        , 0.92896051, 0.97885409],
#        ...,
#        [1.        , 0.81246162, 0.09840345],
#        [1.        , 0.5814052 , 0.11376185],
#        [1.        , 0.89929159, 0.29874035]])

# %%
beta = np.linalg.inv(M.T @ M) @ ((M.T) @ Y )
print(beta)
# Out:
# [1.01013049 2.97280497 7.02439366]

# %% [markdown]
# ###### Use la base de datos production_fish.csv para obtener el porcentaje de consumo de ciertos tipos de producción marina respecto al consumo de anchoveta. Crear esta información solo para los siguiente tipos producción marina: Atun, Jurel, Langostino, Tollo.

# %%
production_fish = pd.read_csv( r"..\..\data\production_fish.csv" )

# %%
production_fish.head(6)
# Out:
#    year   Anchoveta  Concha de abanico  Langostino    Merluza  \
# 0  2005  8628.39600          13.537000    9.021000  23.279000
# 1  2006  5891.83800          14.714000   11.295000  25.189000
# 2  2007  6084.71300          19.937000   13.548000  28.358488
# 3  2008  6159.38700          18.790000   12.817000  26.348398
# 4  2009  5828.63600          24.634372   11.877399  36.774763
# 5  2010  3330.41304          60.001250   14.477939  25.647697
#
#    Calamar gigante       Atun    Caballa       Jurel  Sardina  \
# 0       235.630000   9.877000  25.711000   20.481000  0.16500
# 1       365.729000  11.336000  58.245000  122.904000  0.04800
# 2       379.556594   3.713293  26.248739   82.910307  0.00102
# 3       484.162082   3.283711  47.694121   58.864202  0.00000
# 4       355.106589   2.017061  51.355908   14.289041  0.00000
# 5       327.571909   9.182845   9.729522    5.774274  0.00000
#
#    Concha de abanico.1     Jurel.1       Liza     Tollo  total_production
# 0             1.843080   56.167940   5.875600  0.430000       9030.413620
# 1             4.048000  136.827000   3.166000  1.584000       6646.923000
# 2             4.822991  134.887316   9.317622  2.834958       6790.849328
# 3             0.828187   80.092885  14.514054  2.933360       6909.715000
# 4             1.843072   47.079175  17.311344  4.057886       6394.982610
# 5             2.824749   10.404933   9.706363  4.994712       3810.729233

# %%
production_fish.columns.to_list()[ 1:-1 ]
# Out:
# ['Anchoveta',
#  'Concha de abanico',
#  'Langostino',
#  'Merluza',
#  'Calamar gigante',
#  'Atun',
#  'Caballa',
#  'Jurel',
#  'Sardina',
#  'Concha de abanico.1',
#  'Jurel.1',
#  'Liza',
#  'Tollo']

# %%
grupo = ("Atun","Jurel","Langostino","Tollo")
for col in grupo:
    production_fish[ f'%_{col}' ]  = production_fish[ f'{col}' ] * 100 / production_fish[ 'Anchoveta' ]
production_fish.head(6)
# Out:
#    year   Anchoveta  Concha de abanico  Langostino    Merluza  \
# 0  2005  8628.39600          13.537000    9.021000  23.279000
# 1  2006  5891.83800          14.714000   11.295000  25.189000
# 2  2007  6084.71300          19.937000   13.548000  28.358488
# 3  2008  6159.38700          18.790000   12.817000  26.348398
# 4  2009  5828.63600          24.634372   11.877399  36.774763
# 5  2010  3330.41304          60.001250   14.477939  25.647697
#
#    Calamar gigante       Atun    Caballa       Jurel  Sardina  \
# 0       235.630000   9.877000  25.711000   20.481000  0.16500
# 1       365.729000  11.336000  58.245000  122.904000  0.04800
# 2       379.556594   3.713293  26.248739   82.910307  0.00102
# 3       484.162082   3.283711  47.694121   58.864202  0.00000
# 4       355.106589   2.017061  51.355908   14.289041  0.00000
# 5       327.571909   9.182845   9.729522    5.774274  0.00000
#
#    Concha de abanico.1     Jurel.1       Liza     Tollo  total_production  \
# 0             1.843080   56.167940   5.875600  0.430000       9030.413620
# 1             4.048000  136.827000   3.166000  1.584000       6646.923000
# 2             4.822991  134.887316   9.317622  2.834958       6790.849328
# 3             0.828187   80.092885  14.514054  2.933360       6909.715000
# 4             1.843072   47.079175  17.311344  4.057886       6394.982610
# 5             2.824749   10.404933   9.706363  4.994712       3810.729233
#
#      %_Atun   %_Jurel  %_Langostino   %_Tollo
# 0  0.114471  0.237367      0.104550  0.004984
# 1  0.192402  2.086004      0.191706  0.026885
# 2  0.061027  1.362600      0.222656  0.046591
# 3  0.053312  0.955683      0.208089  0.047624
# 4  0.034606  0.245152      0.203777  0.069620
# 5  0.275727  0.173380      0.434719  0.149973

# %% [markdown]
# ###### (Ejercicio solo en Python) Usar la base de datos places result para crear un DataFrame con la siguiente información: nombre de la institución pública, dirección (formatted_address), situación de actividad (business_status) y las coordenadas correspondientes a northeast y southwest.

# %% [markdown]
# ## Pregunta 3: Function:

# %% [markdown]
# ###### Crear una matrix aleatoria de orden 100x10. Crear un función que permita estandariza cada columna; es decir, cada observación de una columna debe restarse por su media y dividirse por la desviación estándar de la columna. Llame a esta función como standarize.
