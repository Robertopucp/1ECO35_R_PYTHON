# %% [markdown]
# # 1. IF STATEMENT

# %% [markdown]
# Un archivo .csv llamado notas está en la carpeta data. Esta base de datos posee información de algunos postulantes universitarios a la universidad. Use if statement para crear una nueva columna e indicar si el el alumno ingreso o no (nota minima aprobatoria es 11). Luego crear un columna para colocar el nombre completo de la carrera a la que postulo el alumno (a001 : Economia, a002: quimica, a003: filosofia).

# %%
import pandas as pd

postulantes = pd.read_csv(r"..\..\data\notas.csv")

postulantes
# Out:
#      alumnos   notas carrera
# 0       DIEGO     10    a001
# 1     GABRIEL      4    a001
# 2       ANDRE      7    a001
# 3      ANDRES     16    a002
# 4    FERNANDO     16    a003
# 5    MILAGROS     19    a002
# 6       OSCAR      9    a001
# 7     RODRIGO      1    a003
# 8   ALEJANDRO      7    a001
# 9     LORENZO     21    a001
# 10     ELIANE     18    a001
# 11     ALDAIR     15    a002
# 12       LUIS      0    a004
# 13     JAVIER     12    a001
# 14     ALONSO     17    a002
# 15      MARCO     18    a001
# 16  SEBASTIAN     15    a004
# 17     LUZCIA      0    a001
# 18      NAYEL     18    a004
# 19    JOAQUIN      4    a002
# 20   ILIZARBE      6    a001
# 21    VIVIANA     18    a004
# 22       LUIS     10    a004
# 23      ROCIO     13    a002
# 24      LEIDY     21    a001
# 25    MELISSA     16    a002
# 26   FERNANDO     15    a001
# 27     MARTIN     21    a001
# 28    DANIELA     17    a003
# 29    GONZALO      7    a001
# 30      SOFIA      6    a003
# 31     ANGEL      10    a004
# 32     CAMILA      1    a001
# 33      ROSA       3    a001
# 34    MARCELO     21    a002
# 35      JOSUE     16    a001
# 36      RUBEN     19    a002
# 37       HUGO     13    a003

# %%
i=0
nrows = postulantes.notas.count()

while i < nrows:
    if postulantes['notas'][i] < 11:
        postulantes.loc[[i],["Estado"]] = "no ingresó"
    else:
        postulantes.loc[[i],["Estado"]] = "ingresó" 
    
    i += 1 

postulantes
# Out:
#      alumnos   notas carrera      Estado
# 0       DIEGO     10    a001  no ingresó
# 1     GABRIEL      4    a001  no ingresó
# 2       ANDRE      7    a001  no ingresó
# 3      ANDRES     16    a002     ingresó
# 4    FERNANDO     16    a003     ingresó
# 5    MILAGROS     19    a002     ingresó
# 6       OSCAR      9    a001  no ingresó
# 7     RODRIGO      1    a003  no ingresó
# 8   ALEJANDRO      7    a001  no ingresó
# 9     LORENZO     21    a001     ingresó
# 10     ELIANE     18    a001     ingresó
# 11     ALDAIR     15    a002     ingresó
# 12       LUIS      0    a004  no ingresó
# 13     JAVIER     12    a001     ingresó
# 14     ALONSO     17    a002     ingresó
# 15      MARCO     18    a001     ingresó
# 16  SEBASTIAN     15    a004     ingresó
# 17     LUZCIA      0    a001  no ingresó
# 18      NAYEL     18    a004     ingresó
# 19    JOAQUIN      4    a002  no ingresó
# 20   ILIZARBE      6    a001  no ingresó
# 21    VIVIANA     18    a004     ingresó
# 22       LUIS     10    a004  no ingresó
# 23      ROCIO     13    a002     ingresó
# 24      LEIDY     21    a001     ingresó
# 25    MELISSA     16    a002     ingresó
# 26   FERNANDO     15    a001     ingresó
# 27     MARTIN     21    a001     ingresó
# 28    DANIELA     17    a003     ingresó
# 29    GONZALO      7    a001  no ingresó
# 30      SOFIA      6    a003  no ingresó
# 31     ANGEL      10    a004  no ingresó
# 32     CAMILA      1    a001  no ingresó
# 33      ROSA       3    a001  no ingresó
# 34    MARCELO     21    a002     ingresó
# 35      JOSUE     16    a001     ingresó
# 36      RUBEN     19    a002     ingresó
# 37       HUGO     13    a003     ingresó

# %%
i=0
nrows = postulantes.notas.count()

while i < nrows:
    if postulantes['carrera'][i] == "a001":
        postulantes.loc[[i],["nombre_carrera"]] = "ECONOMÍA"
    elif postulantes['carrera'][i] == "a002":
        postulantes.loc[[i],["nombre_carrera"]] = "QUÍMICA"
    elif  postulantes['carrera'][i] == "a003":
        postulantes.loc[[i],["nombre_carrera"]] = "FILOSOFÍA"
    else:
        postulantes.loc[[i],["nombre_carrera"]] = "-"
    
    i += 1 
    
postulantes
# Out:
#      alumnos   notas carrera      Estado nombre_carrera
# 0       DIEGO     10    a001  no ingresó       ECONOMÍA
# 1     GABRIEL      4    a001  no ingresó       ECONOMÍA
# 2       ANDRE      7    a001  no ingresó       ECONOMÍA
# 3      ANDRES     16    a002     ingresó        QUÍMICA
# 4    FERNANDO     16    a003     ingresó      FILOSOFÍA
# 5    MILAGROS     19    a002     ingresó        QUÍMICA
# 6       OSCAR      9    a001  no ingresó       ECONOMÍA
# 7     RODRIGO      1    a003  no ingresó      FILOSOFÍA
# 8   ALEJANDRO      7    a001  no ingresó       ECONOMÍA
# 9     LORENZO     21    a001     ingresó       ECONOMÍA
# 10     ELIANE     18    a001     ingresó       ECONOMÍA
# 11     ALDAIR     15    a002     ingresó        QUÍMICA
# 12       LUIS      0    a004  no ingresó              -
# 13     JAVIER     12    a001     ingresó       ECONOMÍA
# 14     ALONSO     17    a002     ingresó        QUÍMICA
# 15      MARCO     18    a001     ingresó       ECONOMÍA
# 16  SEBASTIAN     15    a004     ingresó              -
# 17     LUZCIA      0    a001  no ingresó       ECONOMÍA
# 18      NAYEL     18    a004     ingresó              -
# 19    JOAQUIN      4    a002  no ingresó        QUÍMICA
# 20   ILIZARBE      6    a001  no ingresó       ECONOMÍA
# 21    VIVIANA     18    a004     ingresó              -
# 22       LUIS     10    a004  no ingresó              -
# 23      ROCIO     13    a002     ingresó        QUÍMICA
# 24      LEIDY     21    a001     ingresó       ECONOMÍA
# 25    MELISSA     16    a002     ingresó        QUÍMICA
# 26   FERNANDO     15    a001     ingresó       ECONOMÍA
# 27     MARTIN     21    a001     ingresó       ECONOMÍA
# 28    DANIELA     17    a003     ingresó      FILOSOFÍA
# 29    GONZALO      7    a001  no ingresó       ECONOMÍA
# 30      SOFIA      6    a003  no ingresó      FILOSOFÍA
# 31     ANGEL      10    a004  no ingresó              -
# 32     CAMILA      1    a001  no ingresó       ECONOMÍA
# 33      ROSA       3    a001  no ingresó       ECONOMÍA
# 34    MARCELO     21    a002     ingresó        QUÍMICA
# 35      JOSUE     16    a001     ingresó       ECONOMÍA
# 36      RUBEN     19    a002     ingresó        QUÍMICA
# 37       HUGO     13    a003     ingresó      FILOSOFÍA

# %% [markdown]
# ### Use un loop while para mostrar el nombre de las personas ingresantes a la carrera de quimia.

# %%
i = 0

nrows = postulantes.notas.count()

while i < nrows:
    if (postulantes['Estado'][i] == 'ingresó' and postulantes['nombre_carrera'][i] == 'QUÍMICA'):
        print(postulantes.iat[i,0])
    i += 1
# Out:
# ANDRES
# MILAGROS
# ALDAIR
# ALONSO
# ROCIO
# MELISSA
# MARCELO
# RUBEN

# %% [markdown]
# # 2. Loops
# ### Simule un proceso generador de datos con 10 mil observaciones como se explicó en la primera práctica dirigida. Use un loop para obtener los coeficientes estimados con los siguientes tamaños de muestra (10, 50, 100,200,500,1000,5000). Guardar los coeficientes estimados en un Dataframe. Nombre las columnas del dataframe con los coeficientes estimados (i.e b1, b2, b3 ...) ; y las filas, con el tamaño de muestra (n=10 , n= 50, ... ).

# %%
import random 
import numpy as np
import pandas as pd

random.seed(2000)

x1 = np.random.rand(10000) # uniform distribution  [0,1]
x2 = np.random.rand(10000) # uniform distribution [0,1]
x3 = np.random.rand(10000) # uniform distribution [0,1]
x4 = np.random.rand(10000) # uniform distribution [0,1]
e = np.random.normal(0,1,10000) # normal distribution mean = 0 and sd = 1

# Poblacional regression (Data Generating Process GDP)


Y = 1 + 0.3*x1 + 0.75*x2 - 4.3*x3 + 3.6*x4 + e

# %%
X = np.column_stack((np.ones(10000),x1,x2,x3,x4))
X
# Out:
# array([[1.        , 0.76738355, 0.1562596 , 0.18813573, 0.36948506],
#        [1.        , 0.12839961, 0.83649303, 0.0067641 , 0.7783297 ],
#        [1.        , 0.35780409, 0.9319104 , 0.21476548, 0.37841327],
#        ...,
#        [1.        , 0.85177173, 0.16695415, 0.66377864, 0.44089881],
#        [1.        , 0.13709166, 0.35143514, 0.26852214, 0.71395039],
#        [1.        , 0.59760943, 0.5327854 , 0.8868483 , 0.08060741]])

# %%
#Betas estimados de toda la muestra (n=10000)
beta = np.linalg.inv(X.T @ X) @ ((X.T) @ Y )
print(beta)
# Out:
# [ 1.05720704  0.31403493  0.74756285 -4.3037107   3.51205103]

# %%
num = (10,50,100,200,500,1000,5000)
betas = np.zeros((7,5))

for i in np.arange(0,len(num)):
    Xn = X[1:num[i],:]
    betas[i,:] = np.linalg.inv(Xn.T @ Xn) @ ((Xn.T) @ Y[1:num[i]] )
    #print(Xn)
    #print(a[i])
    #print(betaN)
    
    
num1 = np.asarray(num)
df = pd.DataFrame(betas, columns = ['b1','b2','b3','b4','b5'])
df['N'] = num1
#df1 = pd.DataFrame((df.N,df.b1,df.b2,df.b3,df.b4,df.b5).transpose())
print(df)
# Out:
#          b1        b2        b3        b4        b5     N
# 0  0.827985 -0.332999  1.470515 -4.499695  3.124076    10
# 1  0.583754  0.785956  0.724577 -4.938953  4.600019    50
# 2  0.840185  0.732510  0.745699 -4.974280  4.111859   100
# 3  0.911018  0.591991  1.028247 -4.939902  3.797160   200
# 4  0.808772  0.553888  0.949814 -4.505603  3.629664   500
# 5  0.749167  0.530501  0.951732 -4.318332  3.611625  1000
# 6  0.949985  0.398492  0.744621 -4.232163  3.541990  5000

# %% [markdown]
# ### Use la base de datos production_fish.csv para obtener el porcentaje de consumo de ciertos tipos de producción marina respecto al consumo de anchoveta. Crear esta información solo para los siguiente tipos producción marina: Atun, Jurel, Langostino, Tollo.

# %%
production_fish = pd.read_csv( r"..\..\data\production_fish.csv" )

# %%
production_fish.head(3)
# Out:
#    year  Anchoveta  Concha de abanico  Langostino    Merluza  Calamar gigante  \
# 0  2005   8628.396             13.537       9.021  23.279000       235.630000
# 1  2006   5891.838             14.714      11.295  25.189000       365.729000
# 2  2007   6084.713             19.937      13.548  28.358488       379.556594
#
#         Atun    Caballa       Jurel  Sardina  Concha de abanico.1     Jurel.1  \
# 0   9.877000  25.711000   20.481000  0.16500             1.843080   56.167940
# 1  11.336000  58.245000  122.904000  0.04800             4.048000  136.827000
# 2   3.713293  26.248739   82.910307  0.00102             4.822991  134.887316
#
#        Liza     Tollo  total_production
# 0  5.875600  0.430000       9030.413620
# 1  3.166000  1.584000       6646.923000
# 2  9.317622  2.834958       6790.849328

# %%
production_fish.columns.to_list()[ 1:-1 ]
# Out:
# ['Anchoveta',
#  'Concha de abanico',
#  'Langostino',
#  'Merluza',
#  'Calamar gigante',
#  'Atun',
#  'Caballa',
#  'Jurel',
#  'Sardina',
#  'Concha de abanico.1',
#  'Jurel.1',
#  'Liza',
#  'Tollo']

# %%
select = ("Atun","Jurel","Langostino","Tollo")
for col in select:
    production_fish[ f'%_{col}' ]  = production_fish[ f'{col}' ] * 100 / production_fish[ 'Anchoveta' ]

# %%
production_fish.head(10)
# Out:
#    year    Anchoveta  Concha de abanico  Langostino    Merluza  \
# 0  2005  8628.396000          13.537000    9.021000  23.279000
# 1  2006  5891.838000          14.714000   11.295000  25.189000
# 2  2007  6084.713000          19.937000   13.548000  28.358488
# 3  2008  6159.387000          18.790000   12.817000  26.348398
# 4  2009  5828.636000          24.634372   11.877399  36.774763
# 5  2010  3330.413040          60.001250   14.477939  25.647697
# 6  2011  7000.092781          92.027637   23.384478  28.544458
# 7  2012  3693.871080          38.933390   22.707220  21.054780
# 8  2013  4754.118210          89.293284   19.111372  31.187461
# 9  2014  2255.453460          52.266500   21.762990  30.770800
#
#    Calamar gigante       Atun    Caballa       Jurel   Sardina  \
# 0       235.630000   9.877000  25.711000   20.481000  0.165000
# 1       365.729000  11.336000  58.245000  122.904000  0.048000
# 2       379.556594   3.713293  26.248739   82.910307  0.001020
# 3       484.162082   3.283711  47.694121   58.864202  0.000000
# 4       355.106589   2.017061  51.355908   14.289041  0.000000
# 5       327.571909   9.182845   9.729522    5.774274  0.000000
# 6       373.195661   6.586856  20.478814   83.277943  0.054463
# 7       457.072670   1.115060   9.978510   43.693940  0.088460
# 8       410.759534   7.136436  26.600553    7.197624  0.000000
# 9       465.007580   4.734540  29.576440    8.882560  0.000000
#
#    Concha de abanico.1     Jurel.1       Liza     Tollo  total_production  \
# 0             1.843080   56.167940   5.875600  0.430000       9030.413620
# 1             4.048000  136.827000   3.166000  1.584000       6646.923000
# 2             4.822991  134.887316   9.317622  2.834958       6790.849328
# 3             0.828187   80.092885  14.514054  2.933360       6909.715000
# 4             1.843072   47.079175  17.311344  4.057886       6394.982610
# 5             2.824749   10.404933   9.706363  4.994712       3810.729233
# 6             0.873130   72.955117  12.124808  5.687520       7719.283666
# 7             0.744610   72.930470  17.162420  4.235380       4383.587990
# 8             2.180252   54.454541  12.530821  3.945647       5418.515737
# 9             0.608160   46.346459  12.248670  5.206880       2932.865039
#
#      %_Atun   %_Jurel  %_Langostino   %_Tollo
# 0  0.114471  0.237367      0.104550  0.004984
# 1  0.192402  2.086004      0.191706  0.026885
# 2  0.061027  1.362600      0.222656  0.046591
# 3  0.053312  0.955683      0.208089  0.047624
# 4  0.034606  0.245152      0.203777  0.069620
# 5  0.275727  0.173380      0.434719  0.149973
# 6  0.094097  1.189669      0.334060  0.081249
# 7  0.030187  1.182877      0.614727  0.114660
# 8  0.150111  0.151398      0.401996  0.082994
# 9  0.209915  0.393826      0.964905  0.230857

# %% [markdown]
# ### (Ejercicio solo en Python) Usar la base de datos places result para crear un DataFrame con la siguiente información: nombre de la institución pública, dirección (formatted_address), situación de actividad (business_status) y las coordenadas correspondientes a northeast y southwest.

# %%
#pip install tqdm

# %%
from tqdm import tqdm   #measure time
import pickle

# %%
dictionary_places = open( r"..\..\data\places_result", "rb")
places_result = pickle.load( dictionary_places )

# %%
places_result
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwLh3uoP6jf4PKq9MlBMva7T7gLX6me9h6L5-7i1S_rPK5kF5MWqfRs1uVgEIa5dNPHQoLBeEpVlplDyNOVjQU7xjJBjzG9eijTYJ0buu9nF8zXLewvwFyr7p67kCkLIBOiHY-m4NPnbbT4LwSW1uuSY7oLjKMiqR7URA3uxtOPuwtxE7XlXKqxAxBrwetdCYMaSAWY7Q1ayAtVBFewBlNSVEPJn3KyH_eBQm-lOjGhapko0wn8OqcY91Jdr6gL-IXSNOHjq5G7b8Le4t72xJuECcfOk9WMbks2NN_NEwTHVs9h-OYP7IVxnEZECOkJ8JwOvrLfSCkM-ppAvth5uuA-8_ini-uEf_8wccEgmd6mmUgwXhRo9JEsEM97unu-5cW-X4rPoLiVQsSDlBfpDDYx1tn6LehAn7scIcwlrmExDowVjn48ZlXHMzuyrUn8n1CfbS-_g_g',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '11 Sokode Crescent, Off Dalaba Street Zone 5, Wuse P. M. B, 18, Garki, Abuja',
#    'geometry': {'location': {'lat': 9.065977, 'lng': 7.4549606},
#     'viewport': {'northeast': {'lat': 9.067332429892723,
#       'lng': 7.456282779892721},
#      'southwest': {'lat': 9.064632770107277, 'lng': 7.453583120107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110095172826797559117">Fortune Arinze</a>'],
#      'photo_reference': 'ATtYBwIfz2h2rM_FJkG-yQBlkVWKeovt6ifUcEMS-oibn4T5zgXhLpqhrl1lj07-RfAhWjrwClBoAgc_3Ckh-TekOWbaaQu-0J03OHYQBMqZK6xYSOonfP3tABNHcj_--1XB6urnlYHXNenRO8RhLJC9ahW3AjPS3t2Z4Ssh9hV-hQ-VjJuy',
#      'width': 1920}],
#    'place_id': 'ChIJwRTVOSELThARczd6MyuWUbs',
#    'plus_code': {'compound_code': '3F83+9X Abuja',
#     'global_code': '6FX93F83+9X'},
#    'rating': 3.8,
#    'reference': 'ChIJwRTVOSELThARczd6MyuWUbs',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 314},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Lafia - Shandam Rd, Lafia',
#    'geometry': {'location': {'lat': 8.50573, 'lng': 8.531774799999999},
#     'viewport': {'northeast': {'lat': 8.506788579892724,
#       'lng': 8.53327222989272},
#      'southwest': {'lat': 8.50408892010728, 'lng': 8.530572570107276}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission NIMC',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104393542635093633733">Masoyi Sanda</a>'],
#      'photo_reference': 'ATtYBwIE0LfhdRfp-T7JDNqlTgrqdBl2ZWIi0oin4Qv1qcHhrTgfSxBEAaJ29-WNNItxySXH14L1i78PN506HBFHbRrOU_vxYye70ll_1fwxWDqaqja6p4IZ6h-SLnoAEPI1eNayQcyoDoDrB438layysV-a7oIQuNJv9j3Hsv0nkWgDGo4',
#      'width': 3264}],
#    'place_id': 'ChIJt-5bYuEGURARJyb82LfQ97A',
#    'plus_code': {'compound_code': 'GG4J+7P Lafia',
#     'global_code': '6FWCGG4J+7P'},
#    'rating': 3.7,
#    'reference': 'ChIJt-5bYuEGURARJyb82LfQ97A',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 3},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Asa-Dam Rd, opp. Dangote Flour Mills, Ilorin',
#    'geometry': {'location': {'lat': 8.450151, 'lng': 4.542503},
#     'viewport': {'northeast': {'lat': 8.451072679892722,
#       'lng': 4.543705329892721},
#      'southwest': {'lat': 8.448373020107278, 'lng': 4.541005670107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJEZsSsTetNxAR1dg3wSeUrCA',
#    'plus_code': {'compound_code': 'FG2V+32 Ilorin',
#     'global_code': '6FW6FG2V+32'},
#    'rating': 4,
#    'reference': 'ChIJEZsSsTetNxAR1dg3wSeUrCA',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 24},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'zone 3, No 4 Maputo St, Wuse, Abuja',
#    'geometry': {'location': {'lat': 9.058854499999999,
#      'lng': 7.468077600000001},
#     'viewport': {'northeast': {'lat': 9.06035997989272,
#       'lng': 7.469236379892722},
#      'southwest': {'lat': 9.057660320107276, 'lng': 7.466536720107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100674673329877445887">Jacks Elsa</a>'],
#      'photo_reference': 'ATtYBwIWfQb45CnKaFUronntBzevJLHPQ6VMm1xhH6_ixbu8Ilkhe1Eo3im_h0_KN3h89dYJ1arCflM3RwFxGg0fcnsy8BsVDxCQ7rfkTCoh9Q0PX-et_eNpyT6WnjmVK0O6VPA33Vk7ZPFjE7kqcE6G-gHV4AhzaTgt9csg6xZC60il5kL6',
#      'width': 3264}],
#    'place_id': 'ChIJbZxZhq4LThARg41HgXp5W2w',
#    'plus_code': {'compound_code': '3F59+G6 Abuja',
#     'global_code': '6FX93F59+G6'},
#    'rating': 3.4,
#    'reference': 'ChIJbZxZhq4LThARg41HgXp5W2w',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 23},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Lamingo Dam Road Plateau',
#    'geometry': {'location': {'lat': 9.895973, 'lng': 8.931434},
#     'viewport': {'northeast': {'lat': 9.8984195, 'lng': 8.9328039},
#      'southwest': {'lat': 9.895157499999998, 'lng': 8.927324300000002}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJUxzO3-lxUxARdZDox6KE6UQ',
#    'plus_code': {'compound_code': 'VWWJ+9H Jos', 'global_code': '6FXCVWWJ+9H'},
#    'rating': 0,
#    'reference': 'ChIJUxzO3-lxUxARdZDox6KE6UQ',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Jos',
#    'geometry': {'location': {'lat': 9.892294699999999, 'lng': 8.9175658},
#     'viewport': {'northeast': {'lat': 9.893702729892722,
#       'lng': 8.91888807989272},
#      'southwest': {'lat': 9.891003070107278, 'lng': 8.916188420107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116242405272440066619">Aliyu zainul abideen</a>'],
#      'photo_reference': 'ATtYBwJG5OL_3UP7QDjcMop8AYOD_0fN64mXYffPH5XdLCMLFBFSo0vBZpBBOZZ8LQvxLeSK86QQ-dge4oPX7EDL32eX0G-y_P1lV9BcedkKnhPKn379kdAFIQsiuKhJ56iWGfTT6prFd5DinmvO26zgmj11TuTeEWNs6X_Bf0wp7thjHFG5',
#      'width': 1920}],
#    'place_id': 'ChIJFWiUH-dzUxAR55hi-MYXLwg',
#    'plus_code': {'compound_code': 'VWR9+W2 Jos', 'global_code': '6FXCVWR9+W2'},
#    'rating': 3.3,
#    'reference': 'ChIJFWiUH-dzUxAR55hi-MYXLwg',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 7},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Kachia',
#    'geometry': {'location': {'lat': 9.8572331, 'lng': 7.967971899999998},
#     'viewport': {'northeast': {'lat': 9.858620379892722,
#       'lng': 7.969346929892722},
#      'southwest': {'lat': 9.855920720107278, 'lng': 7.966647270107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission',
#    'place_id': 'ChIJ80U4ZjyJUhARGk5bZlIeNzY',
#    'plus_code': {'compound_code': 'VX49+V5 Kachia',
#     'global_code': '6FX9VX49+V5'},
#    'rating': 0,
#    'reference': 'ChIJ80U4ZjyJUhARGk5bZlIeNzY',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Jonah Jang Cres, High Level, Makurdi',
#    'geometry': {'location': {'lat': 7.711655800000001, 'lng': 8.5265235},
#     'viewport': {'northeast': {'lat': 7.712382379892722,
#       'lng': 8.528209429892721},
#      'southwest': {'lat': 7.709682720107278, 'lng': 8.525509770107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104445494535423861947">Slim Meyo</a>'],
#      'photo_reference': 'ATtYBwK9R9it21i9oYROE6AEzcPpr2Uh2SidNYIJ0ABxd2uvA23NORVr0_xmD8jqtkCoCYLCu8htDa0foSkd6gLhnJPOE0BERWmHDzAne-ZqFrPU0kEBIiH1SJe-6hORIFZ2IEJBDumAac7twjhaxLOZD-9ApAlaFzruj_oz6K4Yl1ayJ4CG',
#      'width': 1920}],
#    'place_id': 'ChIJ51B2sMGBUBARDKibZrme9gU',
#    'plus_code': {'compound_code': 'PG6G+MJ Makurdi',
#     'global_code': '6FVCPG6G+MJ'},
#    'rating': 3.1,
#    'reference': 'ChIJ51B2sMGBUBARDKibZrme9gU',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 35},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3 Abdulkadir ahmed Close (P.M.B 0281, Bauchi',
#    'geometry': {'location': {'lat': 10.310332, 'lng': 9.826602},
#     'viewport': {'northeast': {'lat': 10.31170367989272,
#       'lng': 9.827927879892721},
#      'southwest': {'lat': 10.30900402010728, 'lng': 9.825228220107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102114576626040120313">Mohammed Zahradeen Umar</a>'],
#      'photo_reference': 'ATtYBwL3WNqJiitCLNWeKUU4uye8FUfn0vUNZ_UyCuS0IIY4JojJnFhaGxaxpgSh7CWnoTEAzbmk81iynWT0_lruLYtAzZ3Bx0Yvjf3yLHlt0lI3dsuD5BRY7zWy2luqKxKW9J14Plb_-6GPdiUw1AHmCCMBfvZAshlpha8mlvB6QLW012FR',
#      'width': 1088}],
#    'place_id': 'ChIJ4X2l_AXXVBAR7v-eH-d9h3E',
#    'plus_code': {'compound_code': '8R6G+4J Bauchi',
#     'global_code': '7F2F8R6G+4J'},
#    'rating': 0,
#    'reference': 'ChIJ4X2l_AXXVBAR7v-eH-d9h3E',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Kofar Kabuga, Kano',
#    'geometry': {'location': {'lat': 11.9899944, 'lng': 8.4891647},
#     'viewport': {'northeast': {'lat': 11.99139672989272,
#       'lng': 8.490334129892721},
#      'southwest': {'lat': 11.98869707010728, 'lng': 8.487634470107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJE0nEt4CArhERRs1UvLzYZjY',
#    'plus_code': {'compound_code': 'XFQQ+XM Kano',
#     'global_code': '7F3CXFQQ+XM'},
#    'rating': 4.4,
#    'reference': 'ChIJE0nEt4CArhERRs1UvLzYZjY',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 12},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Complex, Federal Secretariat, Kawo, Kaduna',
#    'geometry': {'location': {'lat': 10.592473, 'lng': 7.449456},
#     'viewport': {'northeast': {'lat': 10.59382137989272,
#       'lng': 7.450810429892722},
#      'southwest': {'lat': 10.59112172010728, 'lng': 7.448110770107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJyZiAR9q1shERK9gFL9AG44I',
#    'plus_code': {'compound_code': 'HCRX+XQ Kaduna',
#     'global_code': '7F29HCRX+XQ'},
#    'rating': 0,
#    'reference': 'ChIJyZiAR9q1shERK9gFL9AG44I',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Port-Hacourt Rd, New Owerri, Owerri',
#    'geometry': {'location': {'lat': 5.4717813, 'lng': 7.0083439},
#     'viewport': {'northeast': {'lat': 5.473014629892722,
#       'lng': 7.009477279892723},
#      'southwest': {'lat': 5.470314970107278, 'lng': 7.006777620107279}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Center',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ8-OsvX1ZQhARaNsdHakfc98',
#    'plus_code': {'compound_code': 'F2C5+P8 Owerri',
#     'global_code': '6FQ9F2C5+P8'},
#    'rating': 2.8,
#    'reference': 'ChIJ8-OsvX1ZQhARaNsdHakfc98',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 13},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'ITF House, 6, 3rd Floor, Adetokunbo Ademola Cres, Wuse 2, Abuja',
#    'geometry': {'location': {'lat': 9.07677, 'lng': 7.493777},
#     'viewport': {'northeast': {'lat': 9.078071879892722,
#       'lng': 7.495215229892723},
#      'southwest': {'lat': 9.075372220107278, 'lng': 7.492515570107279}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJu0OOSjELThAR4d7V7h1GgD4',
#    'plus_code': {'compound_code': '3FGV+PG Abuja',
#     'global_code': '6FX93FGV+PG'},
#    'rating': 3,
#    'reference': 'ChIJu0OOSjELThAR4d7V7h1GgD4',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '9 Obafemi Awolowo Way, Agidingbi, Ikeja',
#    'geometry': {'location': {'lat': 6.617086, 'lng': 3.357951},
#     'viewport': {'northeast': {'lat': 6.618298179892721,
#       'lng': 3.359587779892722},
#      'southwest': {'lat': 6.615598520107278, 'lng': 3.356888120107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commision (NIMC) Lagos',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109021919043392669000">Austin Chikwado Ofor</a>'],
#      'photo_reference': 'ATtYBwK-FH7TBnp06XKVDdyzuJrjhWpUAFlugsW1s7ZJKGblziN5YFl8tQWsTFYaHm8rv3k3W701YYMM05LadTLUQ_nbBoK4eGYjYr0da8OYISM4Ra7bPKfttsbdkq6E5q4zpKB-WaW-JciS3-uewEXc4dsw2qojP0hbHuUnCECygykmgSsF',
#      'width': 2358}],
#    'place_id': 'ChIJD34txsmTOxAR5AEgvWczmGI',
#    'plus_code': {'compound_code': 'J985+R5 Ikeja',
#     'global_code': '6FR5J985+R5'},
#    'rating': 3.4,
#    'reference': 'ChIJD34txsmTOxAR5AEgvWczmGI',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 53},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1 Proda Road,Proda Junction, Emene industrial Layout',
#    'geometry': {'location': {'lat': 6.460105899999999,
#      'lng': 7.579008999999999},
#     'viewport': {'northeast': {'lat': 6.461432879892723,
#       'lng': 7.580321279892722},
#      'southwest': {'lat': 6.458733220107279, 'lng': 7.577621620107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116030890989805302110">onyi okeke</a>'],
#      'photo_reference': 'ATtYBwJmt3EyNK4J1abWzGe-QT8jIL4LxmPvkFSZ-swph7NeBR4dY2KGdamn-ru4FFYoxTOYgIm8lhvTkaoGBXfQIgbKYTPCkm0FKwRfPB_xJpiWvHk5jeFtnO5RM3lZ_Lpe9xVNVaMm08DtlCkeM7Ils8WFGri7_BKNtg0vqd0T_vCdJ9I3',
#      'width': 1152}],
#    'place_id': 'ChIJ87i9KbilRBARjzOeBDbKx-c',
#    'plus_code': {'compound_code': 'FH6H+2J Enugu',
#     'global_code': '6FR9FH6H+2J'},
#    'rating': 4,
#    'reference': 'ChIJ87i9KbilRBARjzOeBDbKx-c',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 26},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Bayajida Rd, Ungwan Munchi, Kaduna',
#    'geometry': {'location': {'lat': 10.5436173, 'lng': 7.4609879},
#     'viewport': {'northeast': {'lat': 10.54495552989272,
#       'lng': 7.46233667989272},
#      'southwest': {'lat': 10.54225587010728, 'lng': 7.459637020107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission, Northwest Zonal Office',
#    'place_id': 'ChIJS98oGDi1shER1iS7xWsBExw',
#    'plus_code': {'compound_code': 'GFV6+C9 Kaduna',
#     'global_code': '7F29GFV6+C9'},
#    'rating': 2,
#    'reference': 'ChIJS98oGDi1shER1iS7xWsBExw',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Tal-Udu, FCE Junction Kano',
#    'geometry': {'location': {'lat': 11.988203, 'lng': 8.496804},
#     'viewport': {'northeast': {'lat': 11.98937482989272,
#       'lng': 8.498143229892724},
#      'southwest': {'lat': 11.98667517010728, 'lng': 8.49544357010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'National Identity Management Commission (Nimc)',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJRbzDx9CBrhERDCs5gEROpvQ',
#    'plus_code': {'compound_code': 'XFQW+7P Kano',
#     'global_code': '7F3CXFQW+7P'},
#    'rating': 5,
#    'reference': 'ChIJRbzDx9CBrhERDCs5gEROpvQ',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Ndume bypass, Ndume',
#    'geometry': {'location': {'lat': 5.5025021, 'lng': 7.517955600000001},
#     'viewport': {'northeast': {'lat': 5.503745479892721,
#       'lng': 7.519157379892723},
#      'southwest': {'lat': 5.501045820107277, 'lng': 7.51645772010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission Umuahia',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJyTS2v4zDQhARJtViYuKIT54',
#    'plus_code': {'compound_code': 'GG39+25 Ndume',
#     'global_code': '6FQ9GG39+25'},
#    'rating': 3.7,
#    'reference': 'ChIJyTS2v4zDQhARJtViYuKIT54',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 3},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Umueme, Port Harcourt',
#    'geometry': {'location': {'lat': 4.822006, 'lng': 7.0079724},
#     'viewport': {'northeast': {'lat': 4.823459929892723,
#       'lng': 7.009288279892722},
#      'southwest': {'lat': 4.820760270107279, 'lng': 7.006588620107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission',
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105954586937635012132">Eleje Chinwendu</a>'],
#      'photo_reference': 'ATtYBwJPiTOSvWYumHd9rsNgskLV3VcdNpzOvHKXjRAPQoNinDDB_-3j-8utI5ABTIGc0RA_FboBx_inOA6XhCqzsjcBRnV2rjW-DcfeHXVFEYFUNHoq4EJgkRlSi3CfZFZlOwSkrCjvUtAMSDfl6ZSvOr_Ore3Z4F-n2I2sgsnDKwNEyb3I',
#      'width': 2240}],
#    'place_id': 'ChIJ79K8E9bNaRARd51XXSlz0Kc',
#    'plus_code': {'compound_code': 'R2C5+R5 Port Harcourt',
#     'global_code': '6FP9R2C5+R5'},
#    'rating': 3.6,
#    'reference': 'ChIJ79K8E9bNaRARd51XXSlz0Kc',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 12},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '238 Port Harcourt - Aba Expy, Rumuokwurusi, Port Harcourt',
#    'geometry': {'location': {'lat': 4.8496083, 'lng': 7.0527365},
#     'viewport': {'northeast': {'lat': 4.850934679892722,
#       'lng': 7.054089179892721},
#      'southwest': {'lat': 4.848235020107278, 'lng': 7.051389520107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'National Identity Management Commission Nimc',
#    'place_id': 'ChIJgRk7A3nNaRAR61Ty7IIGSkU',
#    'plus_code': {'compound_code': 'R3X3+R3 Port Harcourt',
#     'global_code': '6FP9R3X3+R3'},
#    'rating': 3,
#    'reference': 'ChIJgRk7A3nNaRAR61Ty7IIGSkU',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 4}],
#  'status': 'OK'}

# %%
places_result.keys()
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
# Lists
institutions = []
direccion = []
status = []

# define all the results
results = places_result[ 'results' ]

# loop para guardar cada uno de los elementos
for row in tqdm( range( 0 , len( results ) ) ):
    
    # nombre de las institucion
    name = results[ row ]['name']
    
    # Direccion
    direcc = results[ row ]['formatted_address']
    
    # Status de la institucion
    stat = results[ row ]['business_status']
    
    # Save results
    status.append( stat )
    direccion.append( direcc )
    institutions.append( name )

    # Diccionario
final_result = { 'Institution': institutions, 'Direccion' : direccion, 'Status' : status }
# Dataframe
df_result = pd.DataFrame( final_result )
df_result
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<?, ?it/s]
#                                           Institution  \
# 0             National Identity Management Commission
# 1        National Identity Management Commission NIMC
# 2      National Identity Management Commission (Nimc)
# 3             National Identity Management Commission
# 4      National Identity Management Commission (Nimc)
# 5             National Identity Management Commission
# 6             National Identity Management Commission
# 7      National Identity Management Commission (Nimc)
# 8      National Identity Management Commission (Nimc)
# 9             National Identity Management Commission
# 10     National Identity Management Commission (Nimc)
# 11                National Identity Management Center
# 12     National Identity Management Commission (Nimc)
# 13  National Identity Management Commision (NIMC) ...
# 14            National Identity Management Commission
# 15  National Identity Management Commission, North...
# 16     National Identity Management Commission (Nimc)
# 17    National Identity Management Commission Umuahia
# 18            National Identity Management Commission
# 19       National Identity Management Commission Nimc
#
#                                             Direccion       Status
# 0   11 Sokode Crescent, Off Dalaba Street Zone 5, ...  OPERATIONAL
# 1                           Lafia - Shandam Rd, Lafia  OPERATIONAL
# 2        Asa-Dam Rd, opp. Dangote Flour Mills, Ilorin  OPERATIONAL
# 3                 zone 3, No 4 Maputo St, Wuse, Abuja  OPERATIONAL
# 4                            Lamingo Dam Road Plateau  OPERATIONAL
# 5                                                 Jos  OPERATIONAL
# 6                                              Kachia  OPERATIONAL
# 7                Jonah Jang Cres, High Level, Makurdi  OPERATIONAL
# 8        3 Abdulkadir ahmed Close (P.M.B 0281, Bauchi  OPERATIONAL
# 9                                  Kofar Kabuga, Kano  OPERATIONAL
# 10         Complex, Federal Secretariat, Kawo, Kaduna  OPERATIONAL
# 11                Port-Hacourt Rd, New Owerri, Owerri  OPERATIONAL
# 12  ITF House, 6, 3rd Floor, Adetokunbo Ademola Cr...  OPERATIONAL
# 13            9 Obafemi Awolowo Way, Agidingbi, Ikeja  OPERATIONAL
# 14  1 Proda Road,Proda Junction, Emene industrial ...  OPERATIONAL
# 15                 Bayajida Rd, Ungwan Munchi, Kaduna  OPERATIONAL
# 16                         Tal-Udu, FCE Junction Kano  OPERATIONAL
# 17                                Ndume bypass, Ndume  OPERATIONAL
# 18                              Umueme, Port Harcourt  OPERATIONAL
# 19  238 Port Harcourt - Aba Expy, Rumuokwurusi, Po...  OPERATIONAL

# %% [markdown]
# # 3. Function:

# %% [markdown]
# ### Function Crear una matrix aleatoria de orden 100x10. Crear un función que permita estandariza cada columna; es decir, cada observación de una columna debe restarse por su media y dividirse por la desviación estándar de la columna. Llame a esta función como standarize.

# %%
random.seed(1000)

x1 = np.random.rand(100,10)

# %%
matriz = x1.reshape(100, 10) 
print("Matriz 10x100 \n", matriz)
# Out:
# Matriz 10x100
#  [[9.47179066e-01 4.38225337e-01 7.53999780e-01 5.61482453e-01
#   3.78484955e-01 1.57585881e-01 5.22779943e-01 6.22766347e-01
#   9.18124481e-01 4.58042231e-01]
#  [1.56861546e-02 8.37796962e-01 5.19591062e-01 4.99587976e-01
#   4.62126541e-01 9.05092127e-02 1.68822091e-01 6.30282095e-01
#   5.29988622e-01 6.41276714e-01]
#  [5.21352315e-01 7.79309756e-01 6.53516429e-01 6.54593776e-01
#   8.66919768e-01 6.40521248e-02 6.85184303e-01 4.11389505e-02
#   3.68799469e-01 4.06220971e-01]
#  [4.38616628e-01 1.36984863e-02 2.00394109e-01 8.95507827e-02
#   6.33257726e-01 3.20380996e-02 7.26973560e-01 8.28620860e-01
#   5.27208323e-01 3.87404137e-01]
#  [7.89378150e-01 9.93866975e-01 9.83853322e-02 2.47669611e-02
#   1.95152235e-01 7.46440403e-01 3.94422862e-01 5.53945073e-01
#   4.16922389e-02 8.48178837e-01]
#  [7.32936119e-01 3.15350069e-01 1.18365750e-01 9.73759604e-02
#   8.34879172e-01 6.29291328e-01 7.85931906e-01 9.54628178e-01
#   1.55686415e-01 3.74491511e-01]
#  [2.35123667e-01 5.66015619e-01 8.58261715e-01 7.90596785e-01
#   7.96098984e-01 9.53493080e-01 8.85156225e-01 2.48973753e-01
#   3.28527407e-01 7.03250920e-02]
#  [3.49236371e-01 2.18760036e-01 7.04118323e-01 6.95639395e-01
#   7.86298382e-01 8.35561489e-01 4.36310204e-02 4.70647063e-01
#   4.23895274e-01 2.37234617e-02]
#  [8.64321041e-01 4.67195800e-01 6.55597231e-01 5.58142512e-01
#   8.38673602e-01 5.70646986e-01 3.90739107e-01 2.98451518e-01
#   9.76573321e-01 8.37738661e-01]
#  [3.34624116e-01 6.32115212e-01 3.49986015e-01 1.94346002e-01
#   1.65917678e-01 6.14237077e-01 4.37869339e-01 3.24493191e-01
#   9.98159329e-01 6.62185589e-01]
#  [7.51275709e-01 4.04834271e-01 4.13408487e-01 3.98151442e-01
#   2.91583735e-01 7.11622976e-01 4.04280239e-01 2.28408721e-01
#   6.06823483e-02 3.36016678e-01]
#  [1.78183126e-01 3.74440115e-01 2.30326121e-01 3.34046845e-01
#   2.63366422e-02 6.16714843e-02 4.47382778e-01 7.20345149e-02
#   5.39471494e-01 5.96851671e-01]
#  [2.37499286e-01 6.00651265e-01 7.37188193e-01 8.63795045e-01
#   6.32843120e-02 8.58169486e-01 4.12716902e-01 1.59210760e-01
#   2.43131305e-01 9.90812843e-01]
#  [5.83870384e-01 9.84230187e-01 3.42541025e-01 2.24328341e-01
#   6.35165066e-01 9.85514164e-01 4.65841552e-01 9.79798771e-01
#   8.70381735e-01 7.25752324e-02]
#  [8.61594489e-01 3.52581331e-02 2.67028009e-01 5.63996520e-01
#   9.69468274e-01 9.89675733e-01 3.93881348e-01 2.31456331e-01
#   9.04842169e-01 6.60603474e-01]
#  [5.98285381e-01 2.67470164e-01 7.04681863e-02 4.09937617e-01
#   7.23398314e-01 3.01524086e-02 5.53839572e-01 1.25808388e-01
#   8.00791357e-01 4.71129937e-02]
#  [8.93637108e-01 1.99268151e-01 1.02764961e-01 2.26759525e-01
#   8.76122582e-01 3.84029043e-01 9.52368988e-01 6.36383282e-01
#   4.53383636e-01 6.75992020e-01]
#  [6.30278095e-01 5.92553088e-01 9.69870752e-01 8.57550671e-01
#   4.73838299e-01 5.29203773e-01 4.80384868e-01 2.01458019e-01
#   6.15002866e-01 6.50370282e-01]
#  [7.15239618e-01 7.03405630e-01 6.29243052e-01 4.83167109e-01
#   8.78663656e-01 1.50681413e-01 1.62487634e-01 6.35065602e-02
#   5.75021839e-01 4.55825232e-01]
#  [8.14597046e-01 9.58804468e-01 3.03719414e-02 4.20177323e-01
#   2.78443399e-01 4.61260077e-01 1.15675405e-01 2.39238379e-01
#   7.99244409e-01 5.84259866e-01]
#  [7.45946844e-01 2.99565499e-01 6.99700422e-01 4.10030023e-01
#   8.91093398e-01 3.08467732e-01 6.11262189e-01 6.09098227e-01
#   4.85219926e-01 4.32615393e-01]
#  [3.52624555e-01 6.90937499e-01 3.74414412e-01 4.51051461e-01
#   8.50126536e-01 2.91178245e-01 9.14174251e-01 8.31093996e-01
#   1.87391645e-01 4.96372090e-01]
#  [8.78850917e-01 1.90933503e-01 9.84369291e-01 9.82113268e-01
#   1.43260259e-01 6.38457178e-01 1.81270404e-01 1.28506487e-01
#   9.74986672e-01 7.87717644e-01]
#  [1.89802203e-02 7.81262500e-01 1.60963175e-02 1.01126393e-01
#   6.68002033e-01 9.11086219e-01 8.18182557e-01 6.08390548e-01
#   5.69567409e-01 9.62486519e-01]
#  [5.10458473e-01 1.84793842e-01 6.06214642e-01 3.09258038e-01
#   9.45111459e-01 1.71499790e-01 6.27630321e-01 5.46955092e-01
#   3.18436982e-01 5.09661494e-01]
#  [2.85593387e-02 9.38391983e-01 6.50972464e-01 7.91780820e-01
#   9.16607571e-01 6.92991351e-01 5.61582869e-01 6.30527457e-01
#   2.76780452e-01 8.57116265e-01]
#  [6.12287242e-01 8.33438614e-01 9.91196730e-01 9.34482458e-01
#   2.46550944e-01 6.43140980e-01 2.33923771e-01 5.05249197e-01
#   5.49826471e-01 6.72237764e-01]
#  [8.35340506e-02 1.91363241e-01 5.50186702e-01 6.25819109e-01
#   3.11248430e-02 4.19957395e-01 7.85573363e-01 4.67764045e-01
#   3.36508537e-01 2.09636046e-01]
#  [2.57318261e-01 4.37153894e-01 5.92896090e-01 5.48555265e-01
#   7.07585007e-01 5.58402235e-02 2.73556697e-01 5.82352161e-01
#   6.71931477e-01 8.81347270e-01]
#  [5.65871477e-01 2.60659642e-01 5.15939354e-01 9.08624193e-04
#   3.30057693e-01 9.07824541e-01 3.35977259e-01 2.82536476e-01
#   8.60044839e-01 9.50313623e-01]
#  [8.75750066e-01 9.20088769e-01 8.56581172e-01 5.10833526e-01
#   1.16415888e-01 5.99443172e-01 5.22210431e-01 7.32998275e-01
#   3.95792221e-01 7.74999959e-02]
#  [3.69182903e-01 7.11277467e-01 1.63532254e-01 2.07170673e-02
#   3.60657907e-01 5.08567445e-01 2.72231289e-01 8.93910611e-01
#   2.67142715e-02 9.71905199e-01]
#  [8.41610278e-01 6.97362767e-01 9.93011268e-01 2.49139414e-01
#   1.52030348e-01 4.47176006e-01 9.51869884e-02 5.49786625e-01
#   4.02042952e-01 6.37375471e-02]
#  [6.69862010e-01 8.49406118e-01 5.77424403e-01 7.69969985e-01
#   7.81820819e-01 4.98382684e-01 8.59922106e-01 7.04470953e-01
#   9.84822525e-02 6.27858997e-01]
#  [8.04608789e-01 5.03569064e-01 8.79537125e-01 9.40967712e-01
#   7.22551566e-01 2.32166717e-01 9.51527967e-01 4.65458132e-01
#   9.70875415e-01 7.36029049e-01]
#  [9.65031750e-03 7.61746125e-01 7.24486170e-01 4.21962651e-02
#   3.24983685e-01 4.99877655e-01 6.30138451e-01 1.35592715e-01
#   4.37647642e-01 8.04894949e-01]
#  [3.36698718e-01 1.37345447e-01 7.49877112e-02 4.03789270e-01
#   1.78899935e-01 6.12136311e-01 8.86260620e-01 6.25587571e-01
#   7.12014908e-02 8.84322010e-02]
#  [8.07584667e-01 4.50737438e-01 1.82900335e-01 7.38232284e-01
#   3.81842026e-01 8.54938584e-01 8.99207989e-01 9.81329212e-01
#   1.57612350e-01 2.91729077e-01]
#  [1.30350954e-01 7.21263928e-01 1.86103634e-01 3.66544663e-01
#   8.96481358e-01 3.25357181e-01 5.62267623e-01 6.20902701e-01
#   3.42656043e-01 3.35714811e-02]
#  [3.26046575e-01 8.13235114e-01 5.84211799e-01 2.48807447e-01
#   9.09465951e-01 9.82952998e-01 1.10363127e-01 8.05468665e-01
#   7.38741385e-01 1.59543679e-01]
#  [3.24410831e-01 1.88666348e-01 6.13281493e-01 4.73339186e-03
#   9.49493655e-01 3.86678595e-01 5.80909165e-01 1.92806212e-02
#   3.71676901e-01 2.37630296e-01]
#  [8.71300571e-01 1.09921014e-01 6.23503860e-01 6.96271689e-01
#   4.31593134e-01 6.73575248e-02 1.34727858e-01 3.65313685e-02
#   2.87304190e-01 8.21764048e-01]
#  [6.77703046e-01 5.68240096e-01 3.01175206e-01 6.32861997e-01
#   6.31847240e-01 8.23637047e-01 3.09283509e-01 9.81772119e-01
#   3.31733326e-01 8.76364005e-02]
#  [1.32402173e-01 5.09335239e-02 3.90479801e-01 8.91182618e-01
#   4.25626043e-02 2.33989913e-01 6.68633526e-01 6.82386733e-01
#   3.49996884e-01 8.06591514e-01]
#  [5.90726534e-01 3.03434004e-01 2.49120248e-02 1.68748608e-01
#   6.87353315e-01 9.80455627e-01 2.08744727e-01 2.93933637e-01
#   3.25035758e-01 2.73670208e-01]
#  [9.18500854e-01 2.54188655e-02 2.52831601e-01 7.82771167e-01
#   5.30405397e-01 7.11994950e-01 1.07334225e-01 2.90956181e-01
#   2.76469598e-01 6.05370841e-01]
#  [1.26963264e-02 5.36388245e-01 6.08943601e-01 2.15446296e-01
#   3.83932454e-02 4.69612905e-01 9.94144236e-01 3.98115883e-01
#   9.43904242e-01 4.02767864e-01]
#  [3.83639471e-01 4.90858385e-02 2.30910807e-01 8.79026129e-01
#   7.41224272e-01 3.38228716e-01 7.01767028e-01 5.19920680e-01
#   5.63724788e-02 5.46033896e-01]
#  [6.98160266e-01 1.51379075e-01 5.59870522e-01 8.34962853e-01
#   8.05431420e-01 6.71246128e-02 5.71853569e-01 7.78087974e-01
#   7.80635541e-01 1.40067617e-01]
#  [5.72500880e-01 9.22812482e-01 3.62586702e-01 5.35406635e-01
#   9.47905643e-01 1.17381564e-01 9.20534411e-01 8.42558125e-01
#   2.56588116e-01 2.71071756e-01]
#  [2.99357171e-01 8.86849349e-01 3.18131782e-01 7.24302340e-01
#   1.14853928e-01 7.74461253e-01 8.96123389e-01 7.52091810e-01
#   5.48993938e-01 2.43089523e-01]
#  [8.93115454e-01 7.89947663e-02 8.39274988e-01 2.80095946e-01
#   1.15220020e-02 8.21324913e-01 8.68868048e-01 4.46627341e-01
#   4.95339354e-01 2.59719161e-01]
#  [7.78133749e-01 5.86297518e-01 8.95752995e-01 1.30522720e-02
#   9.18491301e-01 4.99729043e-01 6.47846540e-01 7.41093379e-01
#   4.22867633e-01 2.02240680e-01]
#  [5.07650483e-01 1.67349109e-01 5.08246206e-01 9.99620792e-02
#   3.40260032e-01 8.62642003e-01 7.44941044e-01 5.54303542e-01
#   1.16824635e-01 3.15964334e-02]
#  [7.82310244e-01 7.90218561e-01 5.17351190e-01 8.27943101e-02
#   3.54331369e-01 4.34527534e-01 3.01748847e-01 2.70268854e-01
#   4.22450770e-01 4.58849656e-01]
#  [8.35783908e-01 8.87997810e-02 4.22480906e-01 3.50009781e-01
#   7.75375076e-01 7.83003830e-01 1.32126167e-01 8.30651844e-01
#   2.18696333e-01 3.99048031e-01]
#  [7.47220808e-01 9.38491213e-01 9.14014335e-01 4.05075120e-02
#   9.74387117e-01 8.95786590e-01 2.21478814e-01 6.72113785e-01
#   7.55694018e-02 5.55676842e-01]
#  [6.41642186e-01 8.94435949e-01 8.72029550e-02 5.41982048e-01
#   1.67466497e-02 7.46588693e-01 1.26386730e-01 3.37278720e-01
#   4.43918377e-01 8.57330004e-01]
#  [7.67421071e-01 7.40681937e-01 7.83662503e-02 9.62783378e-01
#   4.00469052e-01 9.65126768e-01 6.10391704e-01 6.54163001e-01
#   5.21065260e-01 9.74567938e-01]
#  [7.54679964e-01 2.77440849e-01 5.57441858e-01 1.93551122e-01
#   4.21515620e-01 8.09308668e-03 9.32984096e-01 4.03216453e-01
#   4.32907585e-01 9.25485012e-01]
#  [3.96211088e-01 3.39256636e-01 4.79307359e-01 5.56300624e-01
#   4.80303978e-01 9.14389674e-01 9.99357375e-01 4.60149765e-01
#   6.46744870e-01 7.39083398e-01]
#  [1.18435805e-01 8.47354499e-01 8.48124087e-01 7.88155775e-01
#   8.09554597e-01 6.61215552e-01 2.94132962e-01 8.80021906e-01
#   5.24784694e-01 4.24830501e-01]
#  [1.47446549e-01 6.21764305e-01 9.76509329e-01 2.44122525e-01
#   5.76091876e-01 3.88389602e-01 7.44983004e-01 4.45122504e-01
#   3.54036228e-01 9.00755507e-01]
#  [7.27771069e-01 3.22000578e-01 9.66925969e-01 4.80964735e-01
#   7.71661141e-01 6.38352971e-02 9.05727442e-01 1.85536821e-01
#   6.55225056e-01 1.36077814e-01]
#  [7.64188236e-01 1.56580319e-02 2.31413623e-01 7.64441802e-01
#   1.23804985e-01 4.77050422e-01 6.24003001e-01 6.62527871e-01
#   1.98665523e-01 1.10028036e-01]
#  [3.27774545e-01 4.45501670e-01 6.42726796e-01 6.37256821e-01
#   8.01662705e-01 5.77932233e-01 2.95225749e-01 7.67405852e-01
#   8.65919502e-01 5.75827623e-01]
#  [6.88680124e-01 3.20163390e-01 3.02607903e-01 6.46438208e-01
#   4.47647937e-01 7.20079674e-02 1.87395829e-01 4.32551786e-01
#   5.41301887e-01 7.26240771e-01]
#  [3.57297337e-01 8.38417015e-01 4.38205773e-02 2.10683913e-01
#   9.86593594e-01 6.38151903e-01 8.18062668e-01 4.26891397e-01
#   1.31764835e-01 3.35322198e-01]
#  [1.77591689e-01 3.57576027e-01 2.53945069e-01 5.81526392e-01
#   2.14932875e-01 6.93562719e-01 5.74763743e-01 7.15822991e-01
#   1.73855415e-01 5.96653467e-01]
#  [7.59143166e-01 6.06392805e-01 3.05009851e-01 2.08274047e-01
#   6.21757153e-01 8.05016240e-02 5.05023613e-01 6.89413417e-01
#   5.37450399e-01 4.13791406e-03]
#  [2.30673997e-01 7.91813180e-01 6.21179649e-01 9.19767221e-01
#   9.98906052e-01 6.30410799e-01 8.89602564e-01 8.72578414e-02
#   8.80936046e-01 1.09478288e-01]
#  [1.32793331e-02 6.90696579e-01 1.59142975e-01 7.23470593e-01
#   6.05938309e-01 2.47180211e-01 6.87342794e-01 3.87983969e-01
#   5.26457430e-02 4.01664726e-01]
#  [9.01539971e-01 6.60772733e-01 8.62281051e-01 1.99625806e-01
#   8.64191462e-01 9.14256198e-01 4.02656431e-01 3.27566365e-02
#   3.88585828e-01 8.51049274e-01]
#  [5.20142729e-01 4.38907512e-01 3.14944553e-01 2.33405087e-01
#   9.05820609e-01 6.69260515e-01 1.71268681e-01 5.29786147e-01
#   9.93164790e-01 7.15073954e-01]
#  [4.91804494e-01 7.19333875e-01 8.51425199e-01 2.45604015e-01
#   7.03084464e-01 6.80528938e-01 5.85304243e-01 6.60703609e-01
#   5.13182977e-01 7.86989525e-01]
#  [2.48329060e-01 5.39860903e-01 1.46625923e-01 4.26910914e-01
#   6.18814697e-01 9.37095698e-01 6.38107435e-02 5.68114333e-01
#   7.51453139e-01 9.20832727e-01]
#  [2.88614028e-01 4.88320616e-01 7.62788098e-01 6.39194168e-01
#   3.10711696e-01 4.33141476e-01 3.32590853e-01 2.54972285e-01
#   9.10153126e-01 7.57141579e-02]
#  [7.60894868e-01 5.50520880e-01 7.00082543e-01 1.29518613e-01
#   9.68519200e-01 6.39450693e-01 9.85229384e-01 7.95685221e-01
#   2.18205217e-01 8.44339220e-01]
#  [2.91565817e-02 5.75185568e-01 2.65808071e-02 2.26334989e-01
#   1.48891301e-01 4.91292646e-01 7.12224695e-01 7.37243227e-01
#   2.58167576e-02 4.80162604e-01]
#  [2.92723679e-01 4.67249744e-01 5.57574856e-01 4.08842474e-01
#   4.90920394e-01 2.92451279e-01 3.36782732e-01 3.44242176e-01
#   4.86547019e-01 4.01975000e-01]
#  [7.51746037e-01 4.20687228e-01 5.25997929e-01 6.05247194e-01
#   9.13356819e-01 3.04389449e-01 4.69817586e-01 3.73321611e-01
#   9.10825157e-01 3.62002178e-01]
#  [1.34970882e-03 6.58943490e-03 6.15165228e-01 7.09449692e-01
#   2.36173462e-01 8.38487011e-01 9.45097163e-01 8.11105792e-01
#   1.39586950e-02 5.41978878e-01]
#  [9.82598879e-01 3.57450629e-01 5.28154150e-01 7.36419146e-02
#   9.38402435e-02 7.86767326e-01 8.61742497e-01 7.30092697e-01
#   3.16320497e-01 8.28147737e-01]
#  [2.46802457e-01 3.07772434e-01 8.38363803e-01 1.36962602e-01
#   6.53295801e-01 8.06227154e-01 9.76761039e-01 2.66200349e-01
#   6.55221155e-01 1.05060438e-02]
#  [5.81416799e-02 3.78401815e-02 2.96284333e-01 5.94678686e-02
#   2.34446219e-01 2.29531979e-02 9.03025626e-01 3.99030944e-01
#   6.32885141e-01 6.17755408e-01]
#  [2.08880212e-01 4.23108119e-01 3.80544835e-01 8.13973713e-01
#   8.31436855e-01 7.00024245e-01 4.47732594e-01 3.65528976e-01
#   9.82542265e-01 2.69246451e-02]
#  [4.76613347e-01 5.93491952e-01 2.02227621e-01 7.72862382e-01
#   1.48279511e-01 7.22399519e-01 4.38847463e-01 8.91435992e-01
#   6.57345338e-02 9.52912153e-01]
#  [9.28909034e-01 7.32292548e-01 4.20321525e-01 5.15816243e-01
#   6.19204571e-01 5.66131802e-01 4.48059450e-01 1.89337669e-01
#   7.70945393e-01 1.42592775e-02]
#  [8.37661756e-01 6.70743873e-01 6.13436566e-01 4.14926320e-01
#   8.88634641e-02 5.27526200e-01 5.53758669e-01 9.57370341e-01
#   4.87165116e-01 1.93805480e-01]
#  [1.16936370e-01 2.15812707e-01 8.53074453e-01 5.20200147e-01
#   9.84401848e-01 7.12948155e-01 7.40598589e-01 8.24250256e-01
#   1.78296141e-01 9.92541613e-01]
#  [6.11461728e-01 5.62608873e-01 5.85048755e-01 4.35306705e-01
#   1.10822363e-01 5.98822605e-01 7.10347422e-01 7.76684777e-01
#   1.59404526e-01 2.71228723e-01]
#  [8.55478904e-01 7.56741509e-01 3.23220793e-01 2.71029895e-01
#   7.21535988e-01 1.58343358e-01 9.21229718e-01 2.12797718e-01
#   5.38812364e-02 5.29913435e-01]
#  [1.35505161e-01 7.88583333e-01 6.80929009e-01 1.21759040e-01
#   9.04392276e-01 5.03969355e-01 7.27370855e-01 1.34582233e-01
#   1.28959652e-01 3.74141639e-01]
#  [3.23080019e-01 8.15905695e-01 9.49948085e-01 8.65900013e-01
#   1.50102593e-01 8.21126019e-01 2.80550637e-01 7.88375571e-01
#   3.45749171e-01 1.22389582e-01]
#  [5.01270720e-01 9.75356154e-01 3.47596088e-01 5.34428030e-01
#   4.19230794e-01 9.18189452e-01 2.27998436e-01 4.47024533e-01
#   2.01706851e-01 7.77464958e-01]
#  [7.90570838e-02 9.35766698e-01 5.53897209e-01 8.39962446e-01
#   2.78680705e-01 8.03720612e-01 2.60770729e-01 8.79403164e-01
#   7.20952061e-01 7.03349594e-01]
#  [2.19126254e-01 2.41954319e-01 8.34952525e-01 7.85947170e-01
#   3.67004630e-01 5.25437525e-01 6.26317633e-01 5.81600484e-01
#   7.77554783e-01 6.23692172e-01]
#  [9.64235775e-02 5.58960514e-01 2.63538386e-01 9.91938383e-01
#   3.06771735e-01 4.79002099e-01 2.73522542e-01 9.55285729e-01
#   1.97178292e-01 2.67515787e-01]
#  [4.10557902e-03 4.76488184e-01 3.07229466e-01 2.48581933e-01
#   8.20053206e-02 7.56831522e-01 9.06477124e-02 3.46996811e-01
#   3.99870588e-01 7.63141397e-01]
#  [3.46357448e-01 1.59780483e-01 9.01766055e-01 4.04046411e-01
#   6.39527261e-01 4.34802938e-02 1.40051802e-01 6.10875904e-01
#   5.25260769e-01 4.02881042e-01]]

# %%
media = np.mean(x1)
print(media)
# Out:
# 0.5033657385103996

# %%
desv_stand = np.std(x1)
print(desv_stand)
# Out:
# 0.2882234686759918

# %% [markdown]
# Construyendo la funcion standarize

# %%
def standarize (matriz):
    normal =np.norm(matriz)
    matriz = (matriz/normal)
    return matriz
    x1_standar = standarize(matriz)
    print("Matriz Estandarizada \n", x1_standar)
