# %% [markdown]
# 1.Obtener el nombre de todas las variables

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
junin_data = pd.read_excel("C:/Users/USER/Documents/GitHub/1ECO35_R_PYTHON/data/Region_Junin.xlsx")

# %%
junin_data
# Out:
#      Unnamed: 0 Region          District               Place  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1             1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2             2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3             3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4             4  JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..          ...    ...               ...                 ...            ...
# 192         192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193         193  JUNIN             YAULI         P.POMACOCHA              1
# 194         194  JUNIN             YAULI          PACHACHACA              2
# 195         195  JUNIN             YAULI               YAULI              2
# 196         196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
# ...

# %%
print(junin_data.columns) #mostrar todas las variables
# Out:
# Index(['Unnamed: 0', 'Region', 'District', 'Place', '4_6_years_men',
#        '4_6_years_women', '4_6_years_total', '6_14_years_men',
#        '6_14_years_women', '6_14_years_total', 'man_read', 'women_read',
#        'total_read', 'men_not_read', 'women_not_read', 'total_not_read',
#        'man_write', 'women_write', 'total_write', 'men_not_write',
#        'women_not_write', 'total_not_write', 'instruction_men',
#        'instruction_women', 'instruction_total', 'no_instruction_men',
#        'no_instruction_women', 'no_instruction_total', 'finished_instr_men',
#        'finished_instr_women', 'finished_instr_total',
#        'not_finished_instr_men', 'not_finished_instr_women',
#        'not_finished_instr_total', 'peruvian_men', 'peruvian_women',
#        'foreign_men', 'foreign_women', 'whites', 'natives', 'mestizos',
#        'blacks'],
#       dtype='object')

# %% [markdown]
# 2.Mostrar el tipo de variables (type) así como presentar los principales estadísticos.

# %%
junin_data.info() #mostrar el tipo de variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                197 non-null    int64
#  1   Region                    197 non-null    object
#  2   District                  197 non-null    object
#  3   Place                     197 non-null    object
#  4   4_6_years_men             197 non-null    int64
#  5   4_6_years_women           197 non-null    int64
#  6   4_6_years_total           197 non-null    int64
#  7   6_14_years_men            197 non-null    int64
#  8   6_14_years_women          197 non-null    int64
#  9   6_14_years_total          197 non-null    int64
#  10  man_read                  197 non-null    int64
#  11  women_read                197 non-null    int64
#  12  total_read                197 non-null    int64
#  13  men_not_read              197 non-null    int64
# ...

# %%
junin_data.describe() #principales estadisticos
# Out:
#        Unnamed: 0  4_6_years_men  4_6_years_women  4_6_years_total  \
# count  197.000000     197.000000       197.000000       197.000000
# mean    98.000000      16.979695        15.345178        32.324873
# std     57.013156      22.571419        21.618979        43.489455
# min      0.000000       0.000000         0.000000         0.000000
# 25%     49.000000       4.000000         4.000000         8.000000
# 50%     98.000000      10.000000         9.000000        20.000000
# 75%    147.000000      20.000000        18.000000        39.000000
# max    196.000000     184.000000       184.000000       368.000000
#
#        6_14_years_men  6_14_years_women  6_14_years_total    man_read  \
# count      197.000000        197.000000        197.000000  197.000000
# mean        79.005076         62.482234        141.538071   34.654822
# std         99.837291         90.879972        188.535210   51.091581
# min          0.000000          0.000000         10.000000    0.000000
# ...

# %% [markdown]
# 3.Verifique si las columnas presentan missing values

# %%
junin_data.isnull().values.any() #Si tengo al menos una fila con missing value 
#Si es TRUE hay al menos un missing values 
#Si es FALSE no hay missing value
# Out:
# False

# %% [markdown]
# 4.Cambie el nombre de las siguientes variables:

# %%
#renombrar variables
junin_data.rename(columns = {'Place': 'comunidad','men_not_read': 'nlee_hombre', 'women_not_read': 'nlee_mujer', 'men_not_write': 'nesc_hombre', 'women_not_write' : 'nesc_mujer'}, inplace = True)

# %%
junin_data
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1             1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2             2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3             3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4             4  JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..          ...    ...               ...                 ...            ...
# 192         192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193         193  JUNIN             YAULI         P.POMACOCHA              1
# 194         194  JUNIN             YAULI          PACHACHACA              2
# 195         195  JUNIN             YAULI               YAULI              2
# 196         196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
# ...

# %% [markdown]
# 6.Muestre los valores únicos de las siguientes variables ( comunidad , District)

# %%
junin_data.comunidad.unique()
# Out:
# array(['C.CIUDAD DEL CERRO', 'P.YANACANCHA', 'VICO', 'RANCA', 'PASCO',
#        'QUIRLACOCHA', 'CAJAMARQUILLA', 'CAICO', 'ROCO', 'C.SACRA FAMILIA',
#        'P.QUINUA', 'H.PARIAHUANCA', 'P.SULLUMARCA', 'H.SAN ANDRÉS',
#        'P.HUALLAY', 'C.HUAYCHAO', 'COCHAMARCA', 'P.CHACAYÁN',
#        'VILCABAMBA', 'CUCHES', 'CHANGO', 'MITO', 'ANTAPIRCA', 'P.CAYNA',
#        'A. COLPAS', 'P.YACAS', 'C.MASQUIN', 'P.YAMOR', 'PÁUCAR', 'TANGOR',
#        'QUIO', 'CAURY', 'CHUCCHUC', 'COQUIN', 'A.YAPOC', 'P.YANAHUANCA',
#        'HUAYLACIRCA', 'HUARANTAMBO', 'ANDUCHACA', 'VILLO', 'MICHIVILCA',
#        'PILLAO', 'YACÁN', 'TÁPUC', 'CHAUPIMARCA', 'P.OXAPAMPA', 'P.JAUJA',
#        'A.CHUNÁN', 'C.PACAPACHA', 'HUANCAS', 'A.HUERTAS', 'PACA', 'MASMA',
#        'ATAURA', 'HUALÁ', 'JULCÁN', 'P.RICRÁN', 'A.PAUCÁN', 'P.APATA',
#        'HUAMALÍ', 'A.SAN LORENZO', 'PACUCHO', 'P.ORCOTUNA', 'A.VICSO',
#        'TISTES', 'P.HUARIPAMPA', 'A.PARCO', 'PACCHA', 'CANCHAPUNCO',
# ...

# %%
junin_data.comunidad.is_unique
#evaluar si estos valores tienen valores unicos 
#si es TRUE tienen valores unicos 
#si es FALSE tiene repeticiones
# Out:
# False

# %%
junin_data.District.unique()
# Out:
# array(['CIUDAD DEL CERRO', 'HUAYLLAY', 'CHACAYÁN', 'CAYNA', 'YANAHUANCA',
#        'NINACACA', 'JAUJA', 'APATA', 'ORCOTUNA', 'HUARIPAMPA',
#        'MUQUIYAUYO', 'ACOLLA', 'CINCOS', 'MITO', 'LLOCLLAPAMPA',
#        'CONCEPCIÓN', 'COCHAS', 'MATAHUASI', 'HUANCAYO', 'CHUPACA',
#        'SAN GERÓNIMO', 'SAPALLANGA', 'CHONGOS', 'SICAYA', 'COLCA',
#        'HUAYUCACHI', 'TARMA', 'JUNÍN', 'ACOBAMBA', 'OROYA', 'CARHUAMAYO',
#        'CHANCHAMAYO', 'VITOC', 'CHACAPALCA', 'YAULI'], dtype=object)

# %%
junin_data.District.is_unique
#evaluar si estos valores tienen valores unicos 
#si es TRUE tienen valores unicos 
#si es FALSE tiene repeticiones
# Out:
# False

# %% [markdown]
# 7. Borrar las variables finished_instr_total, finished_instr_men y finished_instr_women

# %%
junin_data.drop(['finished_instr_total','finished_instr_men','finished_instr_women'], axis=1)
# de esta manera eliminamos las columnas finished_instr_total, finished_instr_men y finished_instr_women
# axis=1 lo entendemos como una operacion que se hara de forma vertical
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1             1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2             2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3             3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4             4  JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..          ...    ...               ...                 ...            ...
# 192         192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193         193  JUNIN             YAULI         P.POMACOCHA              1
# 194         194  JUNIN             YAULI          PACHACHACA              2
# 195         195  JUNIN             YAULI               YAULI              2
# 196         196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
# ...

# %% [markdown]
# 8. Crear columnas con las siguiente información: el % de mujeres que no escriben ni leen, % de varones que no escriben ni leen y % de nativos respecto al total de la población

# %%
junin_data['%nesc_mujer']=junin_data.nesc_mujer/junin_data.total_not_write #creamos la variable que mide el % de mujeres que no escriben
junin_data['%nlee_mujer']=junin_data.nlee_mujer/junin_data.total_not_read #creamos la variable que mide el % de mujeres que no leen
junin_data['%nesc_hombre']=junin_data.nesc_hombre/junin_data.total_not_write #creamos la variable que mide el % de hombres que no escriben
junin_data['%nlee_hombre']=junin_data.nlee_hombre/junin_data.total_not_read #creamos la variable que mide el % de hombres que no leen
junin_data['%nativos']=junin_data.natives/(junin_data.whites+junin_data.natives+junin_data.mestizos+junin_data.blacks) #creamos la variable que mide el % de nativos
junin_data['poblacion']=(junin_data.whites+junin_data.natives+junin_data.mestizos+junin_data.blacks) #creamos la variable que mide la población total
junin_data
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1             1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2             2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3             3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4             4  JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..          ...    ...               ...                 ...            ...
# 192         192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193         193  JUNIN             YAULI         P.POMACOCHA              1
# 194         194  JUNIN             YAULI          PACHACHACA              2
# 195         195  JUNIN             YAULI               YAULI              2
# 196         196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
# ...

# %% [markdown]
# 9. Crear una base de datos con la siguiente información:
#
# a. Quedarse con la información de los distritos de Ciudad del Cerro, Jauja, Acolla, San Gerónimo, Tarma, Oroya y Concepción
#
# b. Ciudades con una cantidad de niños (4-6 años) mayor a 50 y de (6-14 años) > 70
#
# c. Ordenar las variables según el total de la población y cantidad de población nativa
#
# d. Solo quedarse con las variables trabajadas en 8, Distrito, y comunidad.
#
# e. Guardar la mitad de la información en bases diferentes (llamar a cada uno Base1 y Base 2)
#
# f. Guardar la Base1 en formato csv y excel en la carpeta data. (Use el siguiente nombre Base1_WG(numero de grupo))

# %%
# a. Nos quedamos con la información solicitada
base=junin_data[(junin_data["District"] == "CIUDAD DEL CERRO")|(junin_data["District"] == "CIUDAD DEL CERRO")|
           (junin_data["District"] == "JAUJA")|(junin_data["District"] == "ACOLLA")|
           (junin_data["District"] == "SAN GERÓNIMO")|(junin_data["District"] == "TARMA")|
           (junin_data["District"] == "OROYA")|(junin_data["District"] == "CONCEPCIÓN")]       

# b. Nos quedamos con las ciudades con cantidades mayores a las solicitadas
Base=base[(base["4_6_years_total"]> 50 ) & (base["6_14_years_total"]> 70 )]       
Base
# Out:
#      Unnamed: 0 Region          District            comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO   C.CIUDAD DEL CERRO             65
# 47           47  JUNIN             JAUJA              P.JAUJA             69
# 51           51  JUNIN             JAUJA            A.HUERTAS             22
# 57           57  JUNIN             JAUJA             P.RICRÁN             36
# 74           74  JUNIN            ACOLLA             P.ACOLLA             45
# 96           96  JUNIN        CONCEPCIÓN         P.CONCEPCIÓN             38
# 97           97  JUNIN        CONCEPCIÓN  SANTA ROSA DE OCOPA             28
# 121         121  JUNIN      SAN GERÓNIMO       P.SAN GERÓNIMO             51
# 161         161  JUNIN             TARMA              P.TARMA            107
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# ...

# %%
#c. ordenamos la base de datos de acuerdo al número de poblacion y nativos por distrito (usamos sort)
BASE = Base.sort_values(["poblacion","natives"], ascending = [False,True])
BASE
# Out:
#      Unnamed: 0 Region          District            comunidad  4_6_years_men  \
# 161         161  JUNIN             TARMA              P.TARMA            107
# 47           47  JUNIN             JAUJA              P.JAUJA             69
# 0             0  JUNIN  CIUDAD DEL CERRO   C.CIUDAD DEL CERRO             65
# 121         121  JUNIN      SAN GERÓNIMO       P.SAN GERÓNIMO             51
# 96           96  JUNIN        CONCEPCIÓN         P.CONCEPCIÓN             38
# 74           74  JUNIN            ACOLLA             P.ACOLLA             45
# 51           51  JUNIN             JAUJA            A.HUERTAS             22
# 97           97  JUNIN        CONCEPCIÓN  SANTA ROSA DE OCOPA             28
# 57           57  JUNIN             JAUJA             P.RICRÁN             36
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 161              117              224             386               427
# ...

# %%
#d. Nos quedamos con las variables importantes
data=BASE.iloc[:,[2,3,42,43,44,45,46,47]]
data
# Out:
#              District            comunidad  %nesc_mujer  %nlee_mujer  \
# 161             TARMA              P.TARMA     0.560907     0.581105
# 47              JAUJA              P.JAUJA     0.499142     0.547980
# 0    CIUDAD DEL CERRO   C.CIUDAD DEL CERRO     0.381279     0.412104
# 121      SAN GERÓNIMO       P.SAN GERÓNIMO     0.581776     0.606414
# 96         CONCEPCIÓN         P.CONCEPCIÓN     0.534591     0.556291
# 74             ACOLLA             P.ACOLLA     0.493197     0.531987
# 51              JAUJA            A.HUERTAS     0.579439     0.735484
# 97         CONCEPCIÓN  SANTA ROSA DE OCOPA     0.600000     0.631016
# 57              JAUJA             P.RICRÁN     0.480851     0.549020
#
#      %nesc_hombre  %nlee_hombre  %nativos  poblacion
# 161      0.439093      0.418895  0.182257       1037
# 47       0.500858      0.452020  0.138955        842
# 0        0.618721      0.587896  0.490501        579
# 121      0.418224      0.393586  0.272097        577
# ...

# %%
#e. Dividimos los datos en dos partes
Base1=data.iloc[[0,1,2,3,4],:]
Base1
# Out:
#              District           comunidad  %nesc_mujer  %nlee_mujer  \
# 161             TARMA             P.TARMA     0.560907     0.581105
# 47              JAUJA             P.JAUJA     0.499142     0.547980
# 0    CIUDAD DEL CERRO  C.CIUDAD DEL CERRO     0.381279     0.412104
# 121      SAN GERÓNIMO      P.SAN GERÓNIMO     0.581776     0.606414
# 96         CONCEPCIÓN        P.CONCEPCIÓN     0.534591     0.556291
#
#      %nesc_hombre  %nlee_hombre  %nativos  poblacion
# 161      0.439093      0.418895  0.182257       1037
# 47       0.500858      0.452020  0.138955        842
# 0        0.618721      0.587896  0.490501        579
# 121      0.418224      0.393586  0.272097        577
# 96       0.465409      0.443709  0.333333        423

# %%
Base2=data.iloc[[5,6,7,8],:]
Base2
# Out:
#       District            comunidad  %nesc_mujer  %nlee_mujer  %nesc_hombre  \
# 74      ACOLLA             P.ACOLLA     0.493197     0.531987      0.506803
# 51       JAUJA            A.HUERTAS     0.579439     0.735484      0.420561
# 97  CONCEPCIÓN  SANTA ROSA DE OCOPA     0.600000     0.631016      0.400000
# 57       JAUJA             P.RICRÁN     0.480851     0.549020      0.519149
#
#     %nlee_hombre  %nativos  poblacion
# 74      0.468013  0.925000        360
# 51      0.264516  0.780000        250
# 97      0.368984  0.737903        248
# 57      0.450980  0.967742        248

# %%
#f.Guardamos la Base1 en dos formatos
Base1.to_csv("../Base1_WG2.csv")
Base1.to_excel("../Base1_WG2.xlsx")

# %% [markdown]
# 10. Crear una función que me permita extraer un rango de columnas y de filas. Crear una función que me permite extraer una columna según el nombre de la variable y dos filas.

# %%
#Funcion que selecciona rango de columnas y filas
def select(a,cname1,cname2,f1,f2): #select(Base de datos, nombre de columna1, nombre columna2, rango 1, rango2)
    y = a.loc[f1:f2,(cname1,cname2)]
    return y

# %%
select(junin_data,'comunidad','natives',1,5)
# Out:
#       comunidad  natives
# 1  P.YANACANCHA      100
# 2          VICO       69
# 3         RANCA       25
# 4         PASCO       37
# 5   QUIRLACOCHA       65

# %%
#Funcion que extrae columnas por el nombre
def extraer(a,cname,f1,f2): #select(Base de datos, nombre de columna1, rango 1, rango2)
    y = a.loc[f1:f2,cname]
    return y

# %%
extraer(junin_data,'natives',2,4)
# Out:
# 2    69
# 3    25
# 4    37
# Name: natives, dtype: int64
