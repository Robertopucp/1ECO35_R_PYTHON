# %% [markdown]
# ## Trabajo grupal 3: Grupo 1

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
junin = pd.read_excel("../data/Region_Junin.xlsx")

# %%
junin.drop(junin.columns[0], axis=1, inplace=True)  # Drop the first column to show better
junin
# Out:
#     Region          District               Place  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI          PACHACHACA              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# ..               ...              ...             ...               ...
# 192                0                1              71                 0
# 193                0                1              15                 7
# 194                0                2              20                 8
# 195                6                8              74                38
# 196                5               14              87                25
#
#      6_14_years_total  man_read  ...  not_finished_instr_women  \
# 0                 468       158  ...                       209
# 1                  96        30  ...                        50
# 2                  71        25  ...                        25
# 3                  44        25  ...                        25
# 4                  42         3  ...                        25
# ..                ...       ...  ...                       ...
# 192                71        42  ...                         0
# 193                22         8  ...                         7
# 194                28         7  ...                         8
# 195               112        41  ...                        37
# 196               112         8  ...                        30
#
#      not_finished_instr_total  peruvian_men  peruvian_women  foreign_men  \
# 0                         544           361             216            1
# 1                         100            50              50            0
# 2                          72            47              25            0
# 3                          50            25              25            0
# 4                          50            25              25            0
# ..                        ...           ...             ...          ...
# 192                        72            72               0            0
# 193                        23            16               7            0
# 194                        30            22               8            0
# 195                       103            76              44            0
# 196                       126            96              30            0
#
#      foreign_women  whites  natives  mestizos  blacks
# 0                1       4      284       290       1
# 1                0       0      100         0       0
# 2                0       0       69         3       0
# 3                0       0       25        25       0
# 4                0       0       37        13       0
# ..             ...     ...      ...       ...     ...
# 192              0       0       35        39       0
# 193              0       0       21         2       0
# 194              0       0        4        26       0
# 195              0      37       14        69       0
# 196              0       1      118         7       0
#
# [197 rows x 41 columns]

# %% [markdown]
# ##### Pregunta 1: Obtener el nombre de todas las variables

# %%
junin.columns    # Show all the head columns
# Out:
# Index(['Region', 'District', 'Place', '4_6_years_men', '4_6_years_women',
#        '4_6_years_total', '6_14_years_men', '6_14_years_women',
#        '6_14_years_total', 'man_read', 'women_read', 'total_read',
#        'men_not_read', 'women_not_read', 'total_not_read', 'man_write',
#        'women_write', 'total_write', 'men_not_write', 'women_not_write',
#        'total_not_write', 'instruction_men', 'instruction_women',
#        'instruction_total', 'no_instruction_men', 'no_instruction_women',
#        'no_instruction_total', 'finished_instr_men', 'finished_instr_women',
#        'finished_instr_total', 'not_finished_instr_men',
#        'not_finished_instr_women', 'not_finished_instr_total', 'peruvian_men',
#        'peruvian_women', 'foreign_men', 'foreign_women', 'whites', 'natives',
#        'mestizos', 'blacks'],
#       dtype='object')

# %%
type(junin.columns)   # Show the type
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ##### Pregunta 2: Mostrar el tipo de variables (type) así como presentar los principales estadísticos.

# %%
junin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Region                    197 non-null    object
#  1   District                  197 non-null    object
#  2   Place                     197 non-null    object
#  3   4_6_years_men             197 non-null    int64
#  4   4_6_years_women           197 non-null    int64
#  5   4_6_years_total           197 non-null    int64
#  6   6_14_years_men            197 non-null    int64
#  7   6_14_years_women          197 non-null    int64
#  8   6_14_years_total          197 non-null    int64
#  9   man_read                  197 non-null    int64
#  10  women_read                197 non-null    int64
#  11  total_read                197 non-null    int64
#  12  men_not_read              197 non-null    int64
#  13  women_not_read            197 non-null    int64
#  14  total_not_read            197 non-null    int64
#  15  man_write                 197 non-null    int64
#  16  women_write               197 non-null    int64
#  17  total_write               197 non-null    int64
#  18  men_not_write             197 non-null    int64
#  19  women_not_write           197 non-null    int64
#  20  total_not_write           197 non-null    int64
#  21  instruction_men           197 non-null    int64
#  22  instruction_women         197 non-null    int64
#  23  instruction_total         197 non-null    int64
#  24  no_instruction_men        197 non-null    int64
#  25  no_instruction_women      197 non-null    int64
#  26  no_instruction_total      197 non-null    int64
#  27  finished_instr_men        197 non-null    int64
#  28  finished_instr_women      197 non-null    int64
#  29  finished_instr_total      197 non-null    int64
#  30  not_finished_instr_men    197 non-null    int64
#  31  not_finished_instr_women  197 non-null    int64
#  32  not_finished_instr_total  197 non-null    int64
#  33  peruvian_men              197 non-null    int64
#  34  peruvian_women            197 non-null    int64
#  35  foreign_men               197 non-null    int64
#  36  foreign_women             197 non-null    int64
#  37  whites                    197 non-null    int64
#  38  natives                   197 non-null    int64
#  39  mestizos                  197 non-null    int64
#  40  blacks                    197 non-null    int64
# dtypes: int64(38), object(3)
# memory usage: 63.2+ KB

# %%
junin.describe()    # The principal stadistic
# Out:
#        4_6_years_men  4_6_years_women  4_6_years_total  6_14_years_men  \
# count     197.000000       197.000000       197.000000      197.000000
# mean       16.979695        15.345178        32.324873       79.005076
# std        22.571419        21.618979        43.489455       99.837291
# min         0.000000         0.000000         0.000000        0.000000
# 25%         4.000000         4.000000         8.000000       25.000000
# 50%        10.000000         9.000000        20.000000       55.000000
# 75%        20.000000        18.000000        39.000000       88.000000
# max       184.000000       184.000000       368.000000      950.000000
#
#        6_14_years_women  6_14_years_total    man_read  women_read  total_read  \
# count        197.000000        197.000000  197.000000  197.000000  197.000000
# mean          62.482234        141.538071   34.654822   11.705584   46.360406
# std           90.879972        188.535210   51.091581   34.676708   83.291516
# min            0.000000         10.000000    0.000000    0.000000    0.000000
# 25%           19.000000         42.000000    2.000000    0.000000    2.000000
# 50%           41.000000         91.000000   21.000000    0.000000   23.000000
# 75%           73.000000        160.000000   42.000000    7.000000   50.000000
# max          957.000000       1907.000000  317.000000  225.000000  542.000000
#
#        men_not_read  ...  not_finished_instr_women  not_finished_instr_total  \
# count    197.000000  ...                197.000000                197.000000
# mean      61.294416  ...                 79.238579                172.675127
# std       84.511046  ...                111.799104                220.657751
# min        0.000000  ...                  0.000000                  0.000000
# 25%       22.000000  ...                 25.000000                 50.000000
# 50%       41.000000  ...                 50.000000                108.000000
# 75%       65.000000  ...                 94.000000                197.000000
# max      817.000000  ...               1089.000000               2164.000000
#
#        peruvian_men  peruvian_women  foreign_men  foreign_women      whites  \
# count    197.000000      197.000000   197.000000     197.000000  197.000000
# mean      95.918782       77.664975     0.030457       0.010152    9.893401
# std      120.177520      110.539722     0.265511       0.100501   39.677190
# min        0.000000        0.000000     0.000000       0.000000    0.000000
# 25%       31.000000       25.000000     0.000000       0.000000    0.000000
# 50%       65.000000       50.000000     0.000000       0.000000    0.000000
# 75%      103.000000       91.000000     0.000000       0.000000    0.000000
# max     1132.000000     1141.000000     3.000000       1.000000  348.000000
#
#            natives    mestizos      blacks
# count   197.000000  197.000000  197.000000
# mean    110.558376   52.583756    0.776650
# std     131.094774  123.120065    7.584952
# min       0.000000    0.000000    0.000000
# 25%      40.000000    0.000000    0.000000
# 50%      73.000000    3.000000    0.000000
# 75%     143.000000   48.000000    0.000000
# max    1367.000000  808.000000   92.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ##### Pregunt 3: Verifique si las columnas presentan missing values

# %%
junin.isnull().sum()  # To know if the columns have missing values
# Out:
# Region                      0
# District                    0
# Place                       0
# 4_6_years_men               0
# 4_6_years_women             0
# 4_6_years_total             0
# 6_14_years_men              0
# 6_14_years_women            0
# 6_14_years_total            0
# man_read                    0
# women_read                  0
# total_read                  0
# men_not_read                0
# women_not_read              0
# total_not_read              0
# man_write                   0
# women_write                 0
# total_write                 0
# men_not_write               0
# women_not_write             0
# total_not_write             0
# instruction_men             0
# instruction_women           0
# instruction_total           0
# no_instruction_men          0
# no_instruction_women        0
# no_instruction_total        0
# finished_instr_men          0
# finished_instr_women        0
# finished_instr_total        0
# not_finished_instr_men      0
# not_finished_instr_women    0
# not_finished_instr_total    0
# peruvian_men                0
# peruvian_women              0
# foreign_men                 0
# foreign_women               0
# whites                      0
# natives                     0
# mestizos                    0
# blacks                      0
# dtype: int64

# %% [markdown]
# ##### Pregunta 4: Cambie el nombre de las siguientes variables: Place : comunidad, men_not_read: nlee_hombre, women_not_read: nlee_mujer,  total_not_read: ntotal_lee, men_not_write: nesc_hombre, women_not_write: nesc_hombre, total_not_write: nesc_total.

# %%
junin.rename(columns = {'Place':'comunidad', 'men_not_read':'nlee_hombre', 'women_not_read':'nlee_mujer', 'men_not_write':'nesc_hombre', 
                       'women_not_write':'nesc_mujer', 'total_not_write':'nesc_total'}, inplace = True)
junin
# Out:
#     Region          District           comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI          PACHACHACA              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# ..               ...              ...             ...               ...
# 192                0                1              71                 0
# 193                0                1              15                 7
# 194                0                2              20                 8
# 195                6                8              74                38
# 196                5               14              87                25
#
#      6_14_years_total  man_read  ...  not_finished_instr_women  \
# 0                 468       158  ...                       209
# 1                  96        30  ...                        50
# 2                  71        25  ...                        25
# 3                  44        25  ...                        25
# 4                  42         3  ...                        25
# ..                ...       ...  ...                       ...
# 192                71        42  ...                         0
# 193                22         8  ...                         7
# 194                28         7  ...                         8
# 195               112        41  ...                        37
# 196               112         8  ...                        30
#
#      not_finished_instr_total  peruvian_men  peruvian_women  foreign_men  \
# 0                         544           361             216            1
# 1                         100            50              50            0
# 2                          72            47              25            0
# 3                          50            25              25            0
# 4                          50            25              25            0
# ..                        ...           ...             ...          ...
# 192                        72            72               0            0
# 193                        23            16               7            0
# 194                        30            22               8            0
# 195                       103            76              44            0
# 196                       126            96              30            0
#
#      foreign_women  whites  natives  mestizos  blacks
# 0                1       4      284       290       1
# 1                0       0      100         0       0
# 2                0       0       69         3       0
# 3                0       0       25        25       0
# 4                0       0       37        13       0
# ..             ...     ...      ...       ...     ...
# 192              0       0       35        39       0
# 193              0       0       21         2       0
# 194              0       0        4        26       0
# 195              0      37       14        69       0
# 196              0       1      118         7       0
#
# [197 rows x 41 columns]

# %% [markdown]
# ##### Pregunta 6: Muestre los valores únicos de las siguientes variables ( comunidad , District)

# %%
junin.comunidad.unique()
# Out:
# array(['C.CIUDAD DEL CERRO', 'P.YANACANCHA', 'VICO', 'RANCA', 'PASCO',
#        'QUIRLACOCHA', 'CAJAMARQUILLA', 'CAICO', 'ROCO', 'C.SACRA FAMILIA',
#        'P.QUINUA', 'H.PARIAHUANCA', 'P.SULLUMARCA', 'H.SAN ANDRÉS',
#        'P.HUALLAY', 'C.HUAYCHAO', 'COCHAMARCA', 'P.CHACAYÁN',
#        'VILCABAMBA', 'CUCHES', 'CHANGO', 'MITO', 'ANTAPIRCA', 'P.CAYNA',
#        'A. COLPAS', 'P.YACAS', 'C.MASQUIN', 'P.YAMOR', 'PÁUCAR', 'TANGOR',
#        'QUIO', 'CAURY', 'CHUCCHUC', 'COQUIN', 'A.YAPOC', 'P.YANAHUANCA',
#        'HUAYLACIRCA', 'HUARANTAMBO', 'ANDUCHACA', 'VILLO', 'MICHIVILCA',
#        'PILLAO', 'YACÁN', 'TÁPUC', 'CHAUPIMARCA', 'P.OXAPAMPA', 'P.JAUJA',
#        'A.CHUNÁN', 'C.PACAPACHA', 'HUANCAS', 'A.HUERTAS', 'PACA', 'MASMA',
#        'ATAURA', 'HUALÁ', 'JULCÁN', 'P.RICRÁN', 'A.PAUCÁN', 'P.APATA',
#        'HUAMALÍ', 'A.SAN LORENZO', 'PACUCHO', 'P.ORCOTUNA', 'A.VICSO',
#        'TISTES', 'P.HUARIPAMPA', 'A.PARCO', 'PACCHA', 'CANCHAPUNCO',
#        'C.ULLUSCA', 'CANCHAS', 'P.MUQUIYAUYO', 'MUQUI', 'P.ACOLLA',
#        'MARCO', 'TRAGADERO', 'CHOCÓN', 'ACAYA', 'YAUJAILLO', 'CURICACA',
#        'P.CINCOS', 'C.LLACUARI', 'P.HUANCARÍ', 'C.CHALHUAS', 'ARAMACHAY',
#        'P.MITO', 'A.CHAMBARÁ', 'C.QUICHA', 'HUACHAC', 'A.ACO',
#        'P.LLOCLLAPAMPA', 'VISCAS ESPERANZA', 'CONCHAILLO', 'MATA-CHICO',
#        'MATA-GRANDE', 'P.CONCEPCIÓN', 'SANTA ROSA DE OCOPA', 'HUANTAR',
#        'A.ALAYO', 'C.SAN ANTONIO DE CARICANCHO', 'SANTO DOMINGO',
#        'P.CÓMAS', 'C.CHUPA', 'COCHAS', 'P.MATAHUASI', 'P.HUANCAYO',
#        'CAJAS', 'P.CHUPACA', 'A.ISCOS', 'ANTAPAMPA', 'HUAUSCA GRANDE',
#        'SAN JUAN DE TARPA', 'YANACANCHA', 'COPCA', 'HUAYAN', 'HUAMANCACA',
#        'PILCOMAYO', 'AHUAC', 'ACAC', 'P.SAN GERÓNIMO', 'HUALHUAS',
#        'SAN PEDRO DE SAÑO', 'QUICHUAY', 'CASACANCHA', 'A.INGENIO',
#        'P.SANTA CRUZ DE QUILCAY', 'RANGRA', 'P.SAPALLANGA', 'A.LA PUNTA',
#        'P.PUCARÁ', 'C.PATALÁ', 'MARCAVALLE', 'COCHARCAS', 'P.CHONGOS',
#        'C.TURPAC Y TINYARI', 'SOCOS', 'PUMPUNGA', 'CHUPURO',
#        'CARHUAPACHA', 'A.HUAMANCACA', 'P.SICAYA', 'A.HUANCHAC',
#        'C.CACHICAMARCA', 'P.COLCA', 'A.CHACAPAMPA', 'HUASICANCHA',
#        'CUCHO', 'CHILIAY', 'POTACA', 'LARIA', 'CHONGOS ALTO',
#        'P.HUAYUCACHI', 'HUAMANMARCA', 'VIQUES', 'CACAS', 'HUARAPUQUIO',
#        'CULLHUAS', 'RETAMA', 'PACHA', 'P.TARMA', 'MACO', 'MULLUERO',
#        'ANDAMARCA', 'CHANCHA', 'TARMATAMBO', 'P.JUNÍN', 'HUASAHUASY',
#        'PARI', 'YANEC', 'CHUPÁN', 'ACONCOCHA', 'ONDORES', 'P.ACOBAMBA',
#        'PICOY', 'C.HUARACAYO', 'A.PALCA', 'C.HUAILAHUICHÁN',
#        'P.PALCAMAYO', 'P.OROYA', 'HUAYNACANCHA', 'HUAYHUAY',
#        'P.CARHUAMAYO', 'ULCUMAYO', 'P.SAN RAMÓN', 'LA MERCED',
#        'P.VISCATÁN', 'PAN DE AZÚCAR', 'SUITUCANCHA', 'CHACAPALCA',
#        'P.POMACOCHA', 'PACHACHACA', 'YAULI', 'MINAS DE MOROCOCHA'],
#       dtype=object)

# %%
junin.District.unique()
# Out:
# array(['CIUDAD DEL CERRO', 'HUAYLLAY', 'CHACAYÁN', 'CAYNA', 'YANAHUANCA',
#        'NINACACA', 'JAUJA', 'APATA', 'ORCOTUNA', 'HUARIPAMPA',
#        'MUQUIYAUYO', 'ACOLLA', 'CINCOS', 'MITO', 'LLOCLLAPAMPA',
#        'CONCEPCIÓN', 'COCHAS', 'MATAHUASI', 'HUANCAYO', 'CHUPACA',
#        'SAN GERÓNIMO', 'SAPALLANGA', 'CHONGOS', 'SICAYA', 'COLCA',
#        'HUAYUCACHI', 'TARMA', 'JUNÍN', 'ACOBAMBA', 'OROYA', 'CARHUAMAYO',
#        'CHANCHAMAYO', 'VITOC', 'CHACAPALCA', 'YAULI'], dtype=object)

# %% [markdown]
# ##### Pregunta 7: Borrar las varaibles finished_instr_total, finished_instr_men y finished_instr_women

# %%
junin = junin.drop(['finished_instr_total', 'finished_instr_men', 'finished_instr_women'], axis=1)  # Use axis 1 to drop the columns
junin
# Out:
#     Region          District           comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI          PACHACHACA              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# ..               ...              ...             ...               ...
# 192                0                1              71                 0
# 193                0                1              15                 7
# 194                0                2              20                 8
# 195                6                8              74                38
# 196                5               14              87                25
#
#      6_14_years_total  man_read  ...  not_finished_instr_women  \
# 0                 468       158  ...                       209
# 1                  96        30  ...                        50
# 2                  71        25  ...                        25
# 3                  44        25  ...                        25
# 4                  42         3  ...                        25
# ..                ...       ...  ...                       ...
# 192                71        42  ...                         0
# 193                22         8  ...                         7
# 194                28         7  ...                         8
# 195               112        41  ...                        37
# 196               112         8  ...                        30
#
#      not_finished_instr_total  peruvian_men  peruvian_women  foreign_men  \
# 0                         544           361             216            1
# 1                         100            50              50            0
# 2                          72            47              25            0
# 3                          50            25              25            0
# 4                          50            25              25            0
# ..                        ...           ...             ...          ...
# 192                        72            72               0            0
# 193                        23            16               7            0
# 194                        30            22               8            0
# 195                       103            76              44            0
# 196                       126            96              30            0
#
#      foreign_women  whites  natives  mestizos  blacks
# 0                1       4      284       290       1
# 1                0       0      100         0       0
# 2                0       0       69         3       0
# 3                0       0       25        25       0
# 4                0       0       37        13       0
# ..             ...     ...      ...       ...     ...
# 192              0       0       35        39       0
# 193              0       0       21         2       0
# 194              0       0        4        26       0
# 195              0      37       14        69       0
# 196              0       1      118         7       0
#
# [197 rows x 38 columns]

# %% [markdown]
# ##### Pregunta 8: Crear columnas con las siguiente información: el % de mujeres que no escriben ni leen, % de varones que no escriben ni leen y % de nativos respecto al total de la población.

# %%
junin['Total_poblacion']=junin['peruvian_men']+junin['peruvian_women']+junin['foreign_men']+junin['foreign_women']

# %%
junin['%_women_nread_nwrite'] = junin['no_instruction_women'] * 100 / junin['Total_poblacion']

# %%
junin['%_men_nread_nwrite'] = junin['no_instruction_men'] * 100 / junin['Total_poblacion']

# %%
junin['%_natives'] = junin['natives'] * 100 / junin['Total_poblacion']

# %%
junin
# Out:
#     Region          District           comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI          PACHACHACA              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# ..               ...              ...             ...               ...
# 192                0                1              71                 0
# 193                0                1              15                 7
# 194                0                2              20                 8
# 195                6                8              74                38
# 196                5               14              87                25
#
#      6_14_years_total  man_read  ...  foreign_men  foreign_women  whites  \
# 0                 468       158  ...            1              1       4
# 1                  96        30  ...            0              0       0
# 2                  71        25  ...            0              0       0
# 3                  44        25  ...            0              0       0
# 4                  42         3  ...            0              0       0
# ..                ...       ...  ...          ...            ...     ...
# 192                71        42  ...            0              0       0
# 193                22         8  ...            0              0       0
# 194                28         7  ...            0              0       0
# 195               112        41  ...            0              0      37
# 196               112         8  ...            0              0       1
#
#      natives  mestizos  blacks  Total_poblacion  %_women_nread_nwrite  \
# 0        284       290       1              579             32.469775
# 1        100         0       0              100             50.000000
# 2         69         3       0               72             34.722222
# 3         25        25       0               50             50.000000
# 4         37        13       0               50             50.000000
# ..       ...       ...     ...              ...                   ...
# 192       35        39       0               72              0.000000
# 193       21         2       0               23             30.434783
# 194        4        26       0               30              6.666667
# 195       14        69       0              120             16.666667
# 196      118         7       0              126             23.809524
#
#      %_men_nread_nwrite   %_natives
# 0             51.986183   49.050086
# 1             45.000000  100.000000
# 2              9.722222   95.833333
# 3              0.000000   50.000000
# 4             50.000000   74.000000
# ..                  ...         ...
# 192           75.000000   48.611111
# 193           13.043478   91.304348
# 194           23.333333   13.333333
# 195           23.333333   11.666667
# 196           73.015873   93.650794
#
# [197 rows x 42 columns]

# %% [markdown]
# ##### Pregunta 9: Crear una base de datos con la siguiente información:

# %% [markdown]
# ###### a. Quedarse con la información de los distritos de Ciudad del Cerro, Jauja, Acolla, San Gerónimo, Tarma, Oroya y Concepción

# %%
junin1 = junin[junin["District"].isin(["CIUDAD DEL CERRO","JAUJA","ACOLLA","SAN GERÓNIMO",
                                      "TARMA","OROYA","CONCEPCIÓN"])] # filter by variables's values
junin1
# Out:
#     Region          District                    comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO           C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO                 P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                         VICO              1
# 3    JUNIN  CIUDAD DEL CERRO                        RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO                        PASCO              4
# 5    JUNIN  CIUDAD DEL CERRO                  QUIRLACOCHA              6
# 6    JUNIN  CIUDAD DEL CERRO                CAJAMARQUILLA              9
# 7    JUNIN  CIUDAD DEL CERRO                        CAICO             18
# 8    JUNIN  CIUDAD DEL CERRO                         ROCO              7
# 9    JUNIN  CIUDAD DEL CERRO              C.SACRA FAMILIA             16
# 10   JUNIN  CIUDAD DEL CERRO                     P.QUINUA              8
# 11   JUNIN  CIUDAD DEL CERRO                H.PARIAHUANCA              2
# 12   JUNIN  CIUDAD DEL CERRO                 P.SULLUMARCA             12
# 13   JUNIN  CIUDAD DEL CERRO                 H.SAN ANDRÉS              8
# 47   JUNIN             JAUJA                      P.JAUJA             69
# 48   JUNIN             JAUJA                     A.CHUNÁN             12
# 49   JUNIN             JAUJA                  C.PACAPACHA              1
# 50   JUNIN             JAUJA                      HUANCAS              3
# 51   JUNIN             JAUJA                    A.HUERTAS             22
# 52   JUNIN             JAUJA                         PACA              1
# 53   JUNIN             JAUJA                        MASMA             27
# 54   JUNIN             JAUJA                       ATAURA             24
# 55   JUNIN             JAUJA                        HUALÁ              9
# 56   JUNIN             JAUJA                       JULCÁN             19
# 57   JUNIN             JAUJA                     P.RICRÁN             36
# 58   JUNIN             JAUJA                     A.PAUCÁN             21
# 74   JUNIN            ACOLLA                     P.ACOLLA             45
# 75   JUNIN            ACOLLA                        MARCO             16
# 76   JUNIN            ACOLLA                    TRAGADERO             20
# 77   JUNIN            ACOLLA                       CHOCÓN              2
# 78   JUNIN            ACOLLA                        ACAYA              2
# 79   JUNIN            ACOLLA                    YAUJAILLO             11
# 80   JUNIN            ACOLLA                     CURICACA              8
# 96   JUNIN        CONCEPCIÓN                 P.CONCEPCIÓN             38
# 97   JUNIN        CONCEPCIÓN          SANTA ROSA DE OCOPA             28
# 98   JUNIN        CONCEPCIÓN                      HUANTAR              3
# 99   JUNIN        CONCEPCIÓN                      A.ALAYO              3
# 100  JUNIN        CONCEPCIÓN  C.SAN ANTONIO DE CARICANCHO             10
# 101  JUNIN        CONCEPCIÓN                SANTO DOMINGO             16
# 121  JUNIN      SAN GERÓNIMO               P.SAN GERÓNIMO             51
# 122  JUNIN      SAN GERÓNIMO                     HUALHUAS             20
# 123  JUNIN      SAN GERÓNIMO            SAN PEDRO DE SAÑO             19
# 124  JUNIN      SAN GERÓNIMO                     QUICHUAY             13
# 125  JUNIN      SAN GERÓNIMO                   CASACANCHA             10
# 126  JUNIN      SAN GERÓNIMO                    A.INGENIO             18
# 127  JUNIN      SAN GERÓNIMO      P.SANTA CRUZ DE QUILCAY             21
# 128  JUNIN      SAN GERÓNIMO                       RANGRA              7
# 161  JUNIN             TARMA                      P.TARMA            107
# 162  JUNIN             TARMA                         MACO             28
# 163  JUNIN             TARMA                     MULLUERO             11
# 164  JUNIN             TARMA                    ANDAMARCA              7
# 165  JUNIN             TARMA                      CHANCHA             17
# 166  JUNIN             TARMA                   TARMATAMBO              3
# 181  JUNIN             OROYA                      P.OROYA             11
# 182  JUNIN             OROYA                 HUAYNACANCHA              4
# 183  JUNIN             OROYA                        PACHA              2
# 184  JUNIN             OROYA                     HUAYHUAY             13
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# 5                  7               13              44                43
# 6                  8               17              31                39
# 7                 23               41              90                77
# 8                  4               11              42                19
# 9                  8               24              26                25
# 10                 6               14              17                19
# 11                 6                8              10                12
# 12                14               26              38                32
# 13                 0                8              17                25
# 47                71              140             375               327
# 48                11               23              45                21
# 49                 7                8              24                18
# 50                 2                5              29                40
# 51                38               60             103                87
# 52                 4                5              84                52
# 53                15               42             148               139
# 54                22               46              74                68
# 55                 9               18              57                28
# 56                11               30             106               144
# 57                21               57              98                93
# 58                13               34              85                69
# 74                38               83             160               117
# 75                12               28              94                55
# 76                13               33              87                52
# 77                 0                2              16                22
# 78                 2                4              29                21
# 79                 2               13              13                 4
# 80                 3               11              25                10
# 96                43               81             178               164
# 97                32               60              95                93
# 98                 0                3              47                41
# 99                 8               11              22                29
# 100                8               18              68                46
# 101               11               27              30                41
# 121               42               93             246               238
# 122               20               40              92                90
# 123               13               32              73                57
# 124               19               32              62                56
# 125                9               19              28                27
# 126                6               24              77                75
# 127               20               41             101                84
# 128                1                8              26                12
# 161              117              224             386               427
# 162               12               40              72                52
# 163               14               25             114                73
# 164                6               13              68                52
# 165               20               37             122                77
# 166                1                4              72                32
# 181                9               20              41                35
# 182                2                6              11                16
# 183                4                6               7                 3
# 184                8               21              55                33
#
#      6_14_years_total  man_read  ...  foreign_men  foreign_women  whites  \
# 0                 468       158  ...            1              1       4
# 1                  96        30  ...            0              0       0
# 2                  71        25  ...            0              0       0
# 3                  44        25  ...            0              0       0
# 4                  42         3  ...            0              0       0
# 5                  87        13  ...            0              0       0
# 6                  70         0  ...            0              0       0
# 7                 167        34  ...            0              0       4
# 8                  61         0  ...            0              0       0
# 9                  51         1  ...            0              0       0
# 10                 36         0  ...            0              0       0
# 11                 22         0  ...            0              0       0
# 12                 70         0  ...            0              0       0
# 13                 42         3  ...            0              0       0
# 47                702       265  ...            0              0      63
# 48                 66        28  ...            0              0       0
# 49                 42        17  ...            0              0       0
# 50                 69        13  ...            0              0       0
# 51                190        84  ...            0              0       0
# 52                136        75  ...            0              0       6
# 53                287        90  ...            0              0       0
# 54                142        37  ...            0              0       0
# 55                 85        39  ...            0              0       0
# 56                250        82  ...            0              0       0
# 57                191        42  ...            0              0       0
# 58                154        49  ...            0              0       0
# 74                277        66  ...            0              0       0
# 75                149        34  ...            0              0       0
# 76                139        67  ...            0              0       0
# 77                 38         2  ...            0              0       0
# 78                 50         7  ...            0              0       0
# 79                 17         3  ...            0              0       0
# 80                 35        18  ...            0              0       0
# 96                342        82  ...            0              0       0
# 97                188        54  ...            0              0       0
# 98                 88        34  ...            0              0       0
# 99                 51        13  ...            0              0       0
# 100               114        28  ...            0              0       0
# 101                71         2  ...            0              0       0
# 121               484       162  ...            0              0     348
# 122               182        40  ...            0              0     222
# 123               130        55  ...            0              0      50
# 124               118        31  ...            0              0      59
# 125                55        16  ...            0              0      31
# 126               152        45  ...            0              0      57
# 127               185        20  ...            0              0      31
# 128                38        15  ...            0              0      13
# 161               813       258  ...            3              1     158
# 162               124        36  ...            0              0       0
# 163               187        25  ...            0              0       0
# 164               120        41  ...            0              0       0
# 165               199        28  ...            0              0       0
# 166               104        29  ...            0              0       0
# 181                76        19  ...            0              0      15
# 182                27         0  ...            0              0       0
# 183                10         0  ...            0              0       0
# 184                88        47  ...            0              0       0
#
#      natives  mestizos  blacks  Total_poblacion  %_women_nread_nwrite  \
# 0        284       290       1              579             32.469775
# 1        100         0       0              100             50.000000
# 2         69         3       0               72             34.722222
# 3         25        25       0               50             50.000000
# 4         37        13       0               50             50.000000
# 5         65        35       0              100             50.000000
# 6         87         0       0               87             54.022989
# 7        175        29       0              208             40.384615
# 8         70         2       0               72             31.944444
# 9         73         2       0               75             44.000000
# 10        50         0       0               50             50.000000
# 11        24         6       0               30             60.000000
# 12        96         0       0               96             47.916667
# 13        44         6       0               50             50.000000
# 47       117       662       0              842             26.484561
# 48        89         0       0               89             35.955056
# 49        50         0       0               50             50.000000
# 50        74         0       0               74             56.756757
# 51       195        55       0              250             49.600000
# 52       141         0       0              141             39.716312
# 53       294        29       0              329             45.592705
# 54       104        84       0              188             43.617021
# 55        99         4       0              103             35.922330
# 56       178        72       0              250             50.000000
# 57       240         8       0              248             45.967742
# 58        65       123       0              188             43.617021
# 74       333        27       0              360             38.611111
# 75       167        10       0              177             37.853107
# 76       169         3       0              172             37.790698
# 77        40         0       0               40             55.000000
# 78        54         0       0               54             42.592593
# 79        30         0       0               30             20.000000
# 80        46         0       0               46             28.260870
# 96       141       282       0              423             12.056738
# 97       183        65       0              248             49.596774
# 98        90         1       0               91             45.054945
# 99        62         0       0               62             59.677419
# 100      132         0       0              132             40.909091
# 101       98         0       0               98             53.061224
# 121      157        72       0              577             48.526863
# 122        0         0       0              222             49.099099
# 123       64        48       0              162             42.592593
# 124       26        65       0              150             50.000000
# 125       35         8       0               74             48.648649
# 126       72        47       0              176             46.022727
# 127       42       153       0              226             46.017699
# 128       33         0       0               46             28.260870
# 161      189       689       1             1037             32.979749
# 162      164         0       0              164             39.024390
# 163      179        33       0              212             41.037736
# 164       91        42       0              133             42.857143
# 165      228         8       0              236             41.101695
# 166      108         0       0              108             30.555556
# 181       28        53       0               96             21.875000
# 182       33         0       0               33             54.545455
# 183       16         0       0               16             43.750000
# 184      108         1       0              109             37.614679
#
#      %_men_nread_nwrite   %_natives
# 0             51.986183   49.050086
# 1             45.000000  100.000000
# 2              9.722222   95.833333
# 3              0.000000   50.000000
# 4             50.000000   74.000000
# 5             38.000000   65.000000
# 6             45.977011  100.000000
# 7             37.019231   84.134615
# 8             68.055556   97.222222
# 9             56.000000   97.333333
# 10            50.000000  100.000000
# 11            40.000000   80.000000
# 12            52.083333  100.000000
# 13            50.000000   88.000000
# 47            22.090261   13.895487
# 48            22.471910  100.000000
# 49            18.000000  100.000000
# 50            17.567568  100.000000
# 51            37.600000   78.000000
# 52            21.985816  100.000000
# 53            29.483283   89.361702
# 54            24.468085   55.319149
# 55            63.106796   96.116505
# 56            22.000000   71.200000
# 57            40.322581   96.774194
# 58            34.042553   34.574468
# 74            33.333333   92.500000
# 75            24.293785   94.350282
# 76            34.883721   98.255814
# 77            45.000000  100.000000
# 78            51.851852  100.000000
# 79            63.333333  100.000000
# 80            19.565217  100.000000
# 96             6.855792   33.333333
# 97            30.241935   73.790323
# 98             1.098901   98.901099
# 99             6.451613  100.000000
# 100           45.454545  100.000000
# 101           43.877551  100.000000
# 121           51.473137   27.209705
# 122           50.450450    0.000000
# 123           37.654321   39.506173
# 124           39.333333   17.333333
# 125           51.351351   47.297297
# 126           53.977273   40.909091
# 127           40.707965   18.584071
# 128           58.695652   71.739130
# 161           22.565092   18.225651
# 162            1.219512  100.000000
# 163           58.490566   84.433962
# 164           50.375940   68.421053
# 165           25.000000   96.610169
# 166           69.444444  100.000000
# 181           36.458333   29.166667
# 182           45.454545  100.000000
# 183           56.250000  100.000000
# 184           19.266055   99.082569
#
# [57 rows x 42 columns]

# %% [markdown]
# ###### b. Ciudades con una cantidad de niños (4-6 años) mayor a 50 y de (6-14 años) > 70

# %%
junin1 = junin1[( junin1['4_6_years_total'] > 50 ) & (junin['6_14_years_total'] > 70)]
junin1
# Out:
# C:\Users\PERSONAL\AppData\Local\Temp/ipykernel_14472/985548408.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   junin1 = junin1[( junin1['4_6_years_total'] > 50 ) & (junin['6_14_years_total'] > 70)]
#     Region          District            comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO   C.CIUDAD DEL CERRO             65
# 47   JUNIN             JAUJA              P.JAUJA             69
# 51   JUNIN             JAUJA            A.HUERTAS             22
# 57   JUNIN             JAUJA             P.RICRÁN             36
# 74   JUNIN            ACOLLA             P.ACOLLA             45
# 96   JUNIN        CONCEPCIÓN         P.CONCEPCIÓN             38
# 97   JUNIN        CONCEPCIÓN  SANTA ROSA DE OCOPA             28
# 121  JUNIN      SAN GERÓNIMO       P.SAN GERÓNIMO             51
# 161  JUNIN             TARMA              P.TARMA            107
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 47                71              140             375               327
# 51                38               60             103                87
# 57                21               57              98                93
# 74                38               83             160               117
# 96                43               81             178               164
# 97                32               60              95                93
# 121               42               93             246               238
# 161              117              224             386               427
#
#      6_14_years_total  man_read  ...  foreign_men  foreign_women  whites  \
# 0                 468       158  ...            1              1       4
# 47                702       265  ...            0              0      63
# 51                190        84  ...            0              0       0
# 57                191        42  ...            0              0       0
# 74                277        66  ...            0              0       0
# 96                342        82  ...            0              0       0
# 97                188        54  ...            0              0       0
# 121               484       162  ...            0              0     348
# 161               813       258  ...            3              1     158
#
#      natives  mestizos  blacks  Total_poblacion  %_women_nread_nwrite  \
# 0        284       290       1              579             32.469775
# 47       117       662       0              842             26.484561
# 51       195        55       0              250             49.600000
# 57       240         8       0              248             45.967742
# 74       333        27       0              360             38.611111
# 96       141       282       0              423             12.056738
# 97       183        65       0              248             49.596774
# 121      157        72       0              577             48.526863
# 161      189       689       1             1037             32.979749
#
#      %_men_nread_nwrite  %_natives
# 0             51.986183  49.050086
# 47            22.090261  13.895487
# 51            37.600000  78.000000
# 57            40.322581  96.774194
# 74            33.333333  92.500000
# 96             6.855792  33.333333
# 97            30.241935  73.790323
# 121           51.473137  27.209705
# 161           22.565092  18.225651
#
# [9 rows x 42 columns]

# %% [markdown]
# ###### c. Ordenar las variables según el total de la población y cantidad de población nativa

# %%
junin1 = junin1.sort_values(["Total_poblacion", "natives"])   # Sort ascending by default
junin1
# Out:
#     Region          District            comunidad  4_6_years_men  \
# 97   JUNIN        CONCEPCIÓN  SANTA ROSA DE OCOPA             28
# 57   JUNIN             JAUJA             P.RICRÁN             36
# 51   JUNIN             JAUJA            A.HUERTAS             22
# 74   JUNIN            ACOLLA             P.ACOLLA             45
# 96   JUNIN        CONCEPCIÓN         P.CONCEPCIÓN             38
# 121  JUNIN      SAN GERÓNIMO       P.SAN GERÓNIMO             51
# 0    JUNIN  CIUDAD DEL CERRO   C.CIUDAD DEL CERRO             65
# 47   JUNIN             JAUJA              P.JAUJA             69
# 161  JUNIN             TARMA              P.TARMA            107
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 97                32               60              95                93
# 57                21               57              98                93
# 51                38               60             103                87
# 74                38               83             160               117
# 96                43               81             178               164
# 121               42               93             246               238
# 0                 46              111             297               171
# 47                71              140             375               327
# 161              117              224             386               427
#
#      6_14_years_total  man_read  ...  foreign_men  foreign_women  whites  \
# 97                188        54  ...            0              0       0
# 57                191        42  ...            0              0       0
# 51                190        84  ...            0              0       0
# 74                277        66  ...            0              0       0
# 96                342        82  ...            0              0       0
# 121               484       162  ...            0              0     348
# 0                 468       158  ...            1              1       4
# 47                702       265  ...            0              0      63
# 161               813       258  ...            3              1     158
#
#      natives  mestizos  blacks  Total_poblacion  %_women_nread_nwrite  \
# 97       183        65       0              248             49.596774
# 57       240         8       0              248             45.967742
# 51       195        55       0              250             49.600000
# 74       333        27       0              360             38.611111
# 96       141       282       0              423             12.056738
# 121      157        72       0              577             48.526863
# 0        284       290       1              579             32.469775
# 47       117       662       0              842             26.484561
# 161      189       689       1             1037             32.979749
#
#      %_men_nread_nwrite  %_natives
# 97            30.241935  73.790323
# 57            40.322581  96.774194
# 51            37.600000  78.000000
# 74            33.333333  92.500000
# 96             6.855792  33.333333
# 121           51.473137  27.209705
# 0             51.986183  49.050086
# 47            22.090261  13.895487
# 161           22.565092  18.225651
#
# [9 rows x 42 columns]

# %% [markdown]
# ###### d. Solo quedarse con las variables trabajadas en 8, Distrito, y comunidad.

# %%
junin1 = junin1[['District','comunidad','%_women_nread_nwrite','%_men_nread_nwrite','Total_poblacion']]
junin1
# Out:
#              District            comunidad  %_women_nread_nwrite  \
# 97         CONCEPCIÓN  SANTA ROSA DE OCOPA             49.596774
# 57              JAUJA             P.RICRÁN             45.967742
# 51              JAUJA            A.HUERTAS             49.600000
# 74             ACOLLA             P.ACOLLA             38.611111
# 96         CONCEPCIÓN         P.CONCEPCIÓN             12.056738
# 121      SAN GERÓNIMO       P.SAN GERÓNIMO             48.526863
# 0    CIUDAD DEL CERRO   C.CIUDAD DEL CERRO             32.469775
# 47              JAUJA              P.JAUJA             26.484561
# 161             TARMA              P.TARMA             32.979749
#
#      %_men_nread_nwrite  Total_poblacion
# 97            30.241935              248
# 57            40.322581              248
# 51            37.600000              250
# 74            33.333333              360
# 96             6.855792              423
# 121           51.473137              577
# 0             51.986183              579
# 47            22.090261              842
# 161           22.565092             1037

# %% [markdown]
# ###### e. Guardar la mitad de la información en bases diferentes (llamar a cada uno Base1 y Base 2)

# %%
base1 = junin1.iloc[0:5,:]
base1
# Out:
#       District            comunidad  %_women_nread_nwrite  %_men_nread_nwrite  \
# 97  CONCEPCIÓN  SANTA ROSA DE OCOPA             49.596774           30.241935
# 57       JAUJA             P.RICRÁN             45.967742           40.322581
# 51       JAUJA            A.HUERTAS             49.600000           37.600000
# 74      ACOLLA             P.ACOLLA             38.611111           33.333333
# 96  CONCEPCIÓN         P.CONCEPCIÓN             12.056738            6.855792
#
#     Total_poblacion
# 97              248
# 57              248
# 51              250
# 74              360
# 96              423

# %%
base2 = junin1.iloc[5:10,:]
base2
# Out:
#              District           comunidad  %_women_nread_nwrite  \
# 121      SAN GERÓNIMO      P.SAN GERÓNIMO             48.526863
# 0    CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             32.469775
# 47              JAUJA             P.JAUJA             26.484561
# 161             TARMA             P.TARMA             32.979749
#
#      %_men_nread_nwrite  Total_poblacion
# 121           51.473137              577
# 0             51.986183              579
# 47            22.090261              842
# 161           22.565092             1037

# %%
base1.to_csv("../base1_WG1.csv")
base1.to_excel("../base1_WG1.xlsx")

# %% [markdown]
# ##### Pregunta 10: Crear una función que me permita extraer columnas un rango de columnas y de filas. Crear una función que me permite extraer una columna según el nombre de la variable y dos filas.
