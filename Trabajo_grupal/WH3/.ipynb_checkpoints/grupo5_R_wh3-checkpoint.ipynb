# %% [markdown]
# # Workgroup 3
# ### Integrantes:
# - Diego Esteban Quispe (20192073)
# -
# -

# %% [markdown]
# ### Exploring a DataFrame

# %%
#install.packages("dplyr") # filter data
#install.packages("pacman") # call multiple packages
#install.packages("readxl") # excel, csv
#install.packages("plyr") # filter data
#install.packages("Hmisc") # summirze data
#install.packages("xlsx")
#install.packages("readxl")

# %%
pacman::p_load(tidyverse, haven, dplyr,readxl,stringr,Hmisc,xlsx)
library(readxl)

# %%
junin <- read_excel("../../data/Region_Junin.xlsx")
# Out:
# New names:
# * `` -> ...1

# %%
head(junin)
# Out:
#   ...1 Region District         Place              4_6_years_men 4_6_years_women
# 1 0    JUNIN  CIUDAD DEL CERRO C.CIUDAD DEL CERRO 65            46
# 2 1    JUNIN  CIUDAD DEL CERRO P.YANACANCHA        1             3
# 3 2    JUNIN  CIUDAD DEL CERRO VICO                1             0
# 4 3    JUNIN  CIUDAD DEL CERRO RANCA               0             6
# 5 4    JUNIN  CIUDAD DEL CERRO PASCO               4             4
# 6 5    JUNIN  CIUDAD DEL CERRO QUIRLACOCHA         6             7
#   4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total ...
# 1 111             297            171              468              ...
# 2   4              49             47               96              ...
# 3   1              46             25               71              ...
# 4   6              25             19               44              ...
# 5   8              21             21               42              ...
# 6  13              44             43               87              ...
#   not_finished_instr_women not_finished_instr_total peruvian_men peruvian_women
# 1 209                      544                      361          216
# 2  50                      100                       50           50
# 3  25                       72                       47           25
# 4  25                       50                       25           25
# 5  25                       50                       25           25
# 6  50                      100                       50           50
#   foreign_men foreign_women whites natives mestizos blacks
# 1 1           1             4      284     290      1
# 2 0           0             0      100       0      0
# 3 0           0             0       69       3      0
# 4 0           0             0       25      25      0
# 5 0           0             0       37      13      0
# 6 0           0             0       65      35      0

# %%
attach(junin) # variables as object

# %% [markdown]
# #### 1. Obtener el nombre de todas las variables

# %%
#Nombre de las variables
column <- names(junin)
print(column)
# Out:
#  [1] "...1"                     "Region"
#  [3] "District"                 "Place"
#  [5] "4_6_years_men"            "4_6_years_women"
#  [7] "4_6_years_total"          "6_14_years_men"
#  [9] "6_14_years_women"         "6_14_years_total"
# [11] "man_read"                 "women_read"
# [13] "total_read"               "men_not_read"
# [15] "women_not_read"           "total_not_read"
# [17] "man_write"                "women_write"
# [19] "total_write"              "men_not_write"
# [21] "women_not_write"          "total_not_write"
# [23] "instruction_men"          "instruction_women"
# [25] "instruction_total"        "no_instruction_men"
# [27] "no_instruction_women"     "no_instruction_total"
# [29] "finished_instr_men"       "finished_instr_women"
# [31] "finished_instr_total"     "not_finished_instr_men"
# [33] "not_finished_instr_women" "not_finished_instr_total"
# [35] "peruvian_men"             "peruvian_women"
# [37] "foreign_men"              "foreign_women"
# [39] "whites"                   "natives"
# [41] "mestizos"                 "blacks"

# %% [markdown]
# #### 2. Mostrar el tipo de variables (type) así como presentar los principales estadísticos.

# %%
#Tipo de variables
sapply(junin, class)
# Out:
#                     ...1                   Region                 District
#                "numeric"              "character"              "character"
#                    Place            4_6_years_men          4_6_years_women
#              "character"                "numeric"                "numeric"
#          4_6_years_total           6_14_years_men         6_14_years_women
#                "numeric"                "numeric"                "numeric"
#         6_14_years_total                 man_read               women_read
#                "numeric"                "numeric"                "numeric"
#               total_read             men_not_read           women_not_read
#                "numeric"                "numeric"                "numeric"
#           total_not_read                man_write              women_write
#                "numeric"                "numeric"                "numeric"
#              total_write            men_not_write          women_not_write
#                "numeric"                "numeric"                "numeric"
#          total_not_write          instruction_men        instruction_women
#                "numeric"                "numeric"                "numeric"
#        instruction_total       no_instruction_men     no_instruction_women
#                "numeric"                "numeric"                "numeric"
#     no_instruction_total       finished_instr_men     finished_instr_women
#                "numeric"                "numeric"                "numeric"
#     finished_instr_total   not_finished_instr_men not_finished_instr_women
#                "numeric"                "numeric"                "numeric"
# not_finished_instr_total             peruvian_men           peruvian_women
#                "numeric"                "numeric"                "numeric"
#              foreign_men            foreign_women                   whites
#                "numeric"                "numeric"                "numeric"
#                  natives                 mestizos                   blacks
#                "numeric"                "numeric"                "numeric"

# %%
#Principales estadisticos de cada variable
summary(junin)
# Out:
#       ...1        Region            District            Place
#  Min.   :  0   Length:197         Length:197         Length:197
#  1st Qu.: 49   Class :character   Class :character   Class :character
#  Median : 98   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 98
#  3rd Qu.:147
#  Max.   :196
#  4_6_years_men    4_6_years_women  4_6_years_total  6_14_years_men
#  Min.   :  0.00   Min.   :  0.00   Min.   :  0.00   Min.   :  0.00
#  1st Qu.:  4.00   1st Qu.:  4.00   1st Qu.:  8.00   1st Qu.: 25.00
#  Median : 10.00   Median :  9.00   Median : 20.00   Median : 55.00
#  Mean   : 16.98   Mean   : 15.35   Mean   : 32.32   Mean   : 79.01
#  3rd Qu.: 20.00   3rd Qu.: 18.00   3rd Qu.: 39.00   3rd Qu.: 88.00
#  Max.   :184.00   Max.   :184.00   Max.   :368.00   Max.   :950.00
#  6_14_years_women 6_14_years_total    man_read        women_read
#  Min.   :  0.00   Min.   :  10.0   Min.   :  0.00   Min.   :  0.00
#  1st Qu.: 19.00   1st Qu.:  42.0   1st Qu.:  2.00   1st Qu.:  0.00
#  Median : 41.00   Median :  91.0   Median : 21.00   Median :  0.00
#  Mean   : 62.48   Mean   : 141.5   Mean   : 34.65   Mean   : 11.71
#  3rd Qu.: 73.00   3rd Qu.: 160.0   3rd Qu.: 42.00   3rd Qu.:  7.00
#  Max.   :957.00   Max.   :1907.0   Max.   :317.00   Max.   :225.00
#    total_read      men_not_read    women_not_read   total_not_read
#  Min.   :  0.00   Min.   :  0.00   Min.   :  0.00   Min.   :   0.0
#  1st Qu.:  2.00   1st Qu.: 22.00   1st Qu.: 22.00   1st Qu.:  47.0
#  Median : 23.00   Median : 41.00   Median : 45.00   Median :  83.0
#  Mean   : 46.36   Mean   : 61.29   Mean   : 66.04   Mean   : 127.3
#  3rd Qu.: 50.00   3rd Qu.: 65.00   3rd Qu.: 78.00   3rd Qu.: 148.0
#  Max.   :542.00   Max.   :817.00   Max.   :916.00   Max.   :1733.0
#    man_write       women_write       total_write     men_not_write
#  Min.   :  0.00   Min.   :  0.000   Min.   :  0.00   Min.   :  0.00
#  1st Qu.:  0.00   1st Qu.:  0.000   1st Qu.:  0.00   1st Qu.: 25.00
#  Median : 12.00   Median :  0.000   Median : 13.00   Median : 50.00
#  Mean   : 22.23   Mean   :  6.107   Mean   : 28.29   Mean   : 73.72
#  3rd Qu.: 29.00   3rd Qu.:  2.000   3rd Qu.: 34.00   3rd Qu.: 82.00
#  Max.   :236.00   Max.   :153.000   Max.   :351.00   Max.   :936.00
#  women_not_write  total_not_write  instruction_men  instruction_women
#  Min.   :  0.00   Min.   :  14.0   Min.   :  0.00   Min.   :  0.000
#  1st Qu.: 25.00   1st Qu.:  50.0   1st Qu.:  0.00   1st Qu.:  0.000
#  Median : 48.00   Median :  96.0   Median :  9.00   Median :  0.000
#  Mean   : 71.46   Mean   : 145.8   Mean   : 27.47   Mean   :  8.208
#  3rd Qu.: 82.00   3rd Qu.: 167.0   3rd Qu.: 40.00   3rd Qu.:  0.000
#  Max.   :988.00   Max.   :1924.0   Max.   :274.00   Max.   :223.000
#  instruction_total no_instruction_men no_instruction_women no_instruction_total
#  Min.   :  0.00    Min.   :  0.00     Min.   :  0.00       Min.   :   9.0
#  1st Qu.:  0.00    1st Qu.: 25.00     1st Qu.: 24.00       1st Qu.:  50.0
#  Median : 12.00    Median : 49.00     Median : 50.00       Median :  94.0
#  Mean   : 35.68    Mean   : 68.43     Mean   : 69.72       Mean   : 138.1
#  3rd Qu.: 43.00    3rd Qu.: 67.00     3rd Qu.: 82.00       3rd Qu.: 147.0
#  Max.   :497.00    Max.   :899.00     Max.   :963.00       Max.   :1862.0
#  finished_instr_men finished_instr_women finished_instr_total
#  Min.   : 0.000     Min.   : 0.0000      Min.   :  0.000
#  1st Qu.: 0.000     1st Qu.: 0.0000      1st Qu.:  0.000
#  Median : 0.000     Median : 0.0000      Median :  0.000
#  Mean   : 2.391     Mean   : 0.9239      Mean   :  3.315
#  3rd Qu.: 0.000     3rd Qu.: 0.0000      3rd Qu.:  0.000
#  Max.   :69.000     Max.   :52.0000      Max.   :111.000
#  not_finished_instr_men not_finished_instr_women not_finished_instr_total
#  Min.   :   0.00        Min.   :   0.00          Min.   :   0.0
#  1st Qu.:  31.00        1st Qu.:  25.00          1st Qu.:  50.0
#  Median :  65.00        Median :  50.00          Median : 108.0
#  Mean   :  93.74        Mean   :  79.24          Mean   : 172.7
#  3rd Qu.: 103.00        3rd Qu.:  94.00          3rd Qu.: 197.0
#  Max.   :1075.00        Max.   :1089.00          Max.   :2164.0
#   peruvian_men     peruvian_women     foreign_men      foreign_women
#  Min.   :   0.00   Min.   :   0.00   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:  31.00   1st Qu.:  25.00   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :  65.00   Median :  50.00   Median :0.00000   Median :0.00000
#  Mean   :  95.92   Mean   :  77.67   Mean   :0.03046   Mean   :0.01015
#  3rd Qu.: 103.00   3rd Qu.:  91.00   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :1132.00   Max.   :1141.00   Max.   :3.00000   Max.   :1.00000
#      whites           natives          mestizos          blacks
#  Min.   :  0.000   Min.   :   0.0   Min.   :  0.00   Min.   : 0.0000
#  1st Qu.:  0.000   1st Qu.:  40.0   1st Qu.:  0.00   1st Qu.: 0.0000
#  Median :  0.000   Median :  73.0   Median :  3.00   Median : 0.0000
#  Mean   :  9.893   Mean   : 110.6   Mean   : 52.58   Mean   : 0.7766
#  3rd Qu.:  0.000   3rd Qu.: 143.0   3rd Qu.: 48.00   3rd Qu.: 0.0000
#  Max.   :348.000   Max.   :1367.0   Max.   :808.00   Max.   :92.0000

# %% [markdown]
# #### 3. Verifique si las columnas presentan missing values

# %%
cat(any(is.na(junin[,4])))
# Out:
# FALSE

# %%
#Codigo para encontrar variables con missing values
for (i in c(1:length(column))){
    if (any(is.na(junin[,i]))){
        cat("\n",column[i])
    }
}

# %% [markdown]
# Como el anterior bloque no tiene algun output, podemos decir que todas las variables no tienen missing values.

# %% [markdown]
# #### 4. Cambie el nombre de las variables
# - men_not_read: nlee_hombre
# - women_not_read: nlee_mujer
# - total_not_read: ntotal_lee
# - men_not_write: nesc_hombre
# - women_not_write: nesc_mujer
# - total_not_write: nesc_total

# %%
#Cambiando nombres de variables
junin <- rename(junin, nlee_hombre = men_not_read, nlee_mujer = women_not_read,
                 ntotal_lee = total_not_read, nesc_hombre = men_not_write, 
                 nesc_mujer = women_not_write, nesc_total = total_not_write,
                 comunidad = Place)

# %%
#Nombre de las variables
column1 <- names(junin)
print(column1)
# Out:
#  [1] "...1"                     "Region"
#  [3] "District"                 "comunidad"
#  [5] "4_6_years_men"            "4_6_years_women"
#  [7] "4_6_years_total"          "6_14_years_men"
#  [9] "6_14_years_women"         "6_14_years_total"
# [11] "man_read"                 "women_read"
# [13] "total_read"               "nlee_hombre"
# [15] "nlee_mujer"               "ntotal_lee"
# [17] "man_write"                "women_write"
# [19] "total_write"              "nesc_hombre"
# [21] "nesc_mujer"               "nesc_total"
# [23] "instruction_men"          "instruction_women"
# [25] "instruction_total"        "no_instruction_men"
# [27] "no_instruction_women"     "no_instruction_total"
# [29] "not_finished_instr_men"   "not_finished_instr_women"
# [31] "not_finished_instr_total" "peruvian_men"
# [33] "peruvian_women"           "foreign_men"
# [35] "foreign_women"            "whites"
# [37] "natives"                  "mestizos"
# [39] "blacks"

# %% [markdown]
# #### 6. Muestre los valores únicos de las siguientes variables ( comunidad , District)

# %%
#mostramos valores unicos
unique(junin$comunidad)
unique(junin$District)
# Out:
#   [1] "C.CIUDAD DEL CERRO"          "P.YANACANCHA"
#   [3] "VICO"                        "RANCA"
#   [5] "PASCO"                       "QUIRLACOCHA"
#   [7] "CAJAMARQUILLA"               "CAICO"
#   [9] "ROCO"                        "C.SACRA FAMILIA"
#  [11] "P.QUINUA"                    "H.PARIAHUANCA"
#  [13] "P.SULLUMARCA"                "H.SAN ANDRÉS"
#  [15] "P.HUALLAY"                   "C.HUAYCHAO"
#  [17] "COCHAMARCA"                  "P.CHACAYÁN"
#  [19] "VILCABAMBA"                  "CUCHES"
#  [21] "CHANGO"                      "MITO"
#  [23] "ANTAPIRCA"                   "P.CAYNA"
#  [25] "A. COLPAS"                   "P.YACAS"
#  [27] "C.MASQUIN"                   "P.YAMOR"
#  [29] "PÁUCAR"                      "TANGOR"
#  [31] "QUIO"                        "CAURY"
#  [33] "CHUCCHUC"                    "COQUIN"
#  [35] "A.YAPOC"                     "P.YANAHUANCA"
#  [37] "HUAYLACIRCA"                 "HUARANTAMBO"
#  [39] "ANDUCHACA"                   "VILLO"
#  [41] "MICHIVILCA"                  "PILLAO"
#  [43] "YACÁN"                       "TÁPUC"
#  [45] "CHAUPIMARCA"                 "P.OXAPAMPA"
#  [47] "P.JAUJA"                     "A.CHUNÁN"
#  [49] "C.PACAPACHA"                 "HUANCAS"
#  [51] "A.HUERTAS"                   "PACA"
#  [53] "MASMA"                       "ATAURA"
#  [55] "HUALÁ"                       "JULCÁN"
#  [57] "P.RICRÁN"                    "A.PAUCÁN"
#  [59] "P.APATA"                     "HUAMALÍ"
#  [61] "A.SAN LORENZO"               "PACUCHO"
#  [63] "P.ORCOTUNA"                  "A.VICSO"
#  [65] "TISTES"                      "P.HUARIPAMPA"
#  [67] "A.PARCO"                     "PACCHA"
#  [69] "CANCHAPUNCO"                 "C.ULLUSCA"
#  [71] "CANCHAS"                     "P.MUQUIYAUYO"
#  [73] "MUQUI"                       "P.ACOLLA"
#  [75] "MARCO"                       "TRAGADERO"
#  [77] "CHOCÓN"                      "ACAYA"
#  [79] "YAUJAILLO"                   "CURICACA"
#  [81] "P.CINCOS"                    "C.LLACUARI"
#  [83] "P.HUANCARÍ"                  "C.CHALHUAS"
#  [85] "ARAMACHAY"                   "P.MITO"
#  [87] "A.CHAMBARÁ"                  "C.QUICHA"
#  [89] "HUACHAC"                     "A.ACO"
#  [91] "P.LLOCLLAPAMPA"              "VISCAS ESPERANZA"
#  [93] "CONCHAILLO"                  "MATA-CHICO"
#  [95] "MATA-GRANDE"                 "P.CONCEPCIÓN"
#  [97] "SANTA ROSA DE OCOPA"         "HUANTAR"
#  [99] "A.ALAYO"                     "C.SAN ANTONIO DE CARICANCHO"
# [101] "SANTO DOMINGO"               "P.CÓMAS"
# [103] "C.CHUPA"                     "COCHAS"
# [105] "P.MATAHUASI"                 "P.HUANCAYO"
# [107] "CAJAS"                       "P.CHUPACA"
# [109] "A.ISCOS"                     "ANTAPAMPA"
# [111] "HUAUSCA GRANDE"              "SAN JUAN DE TARPA"
# [113] "YANACANCHA"                  "COPCA"
# [115] "HUAYAN"                      "HUAMANCACA"
# [117] "PILCOMAYO"                   "AHUAC"
# [119] "ACAC"                        "P.SAN GERÓNIMO"
# [121] "HUALHUAS"                    "SAN PEDRO DE SAÑO"
# [123] "QUICHUAY"                    "CASACANCHA"
# [125] "A.INGENIO"                   "P.SANTA CRUZ DE QUILCAY"
# [127] "RANGRA"                      "P.SAPALLANGA"
# [129] "A.LA PUNTA"                  "P.PUCARÁ"
# [131] "C.PATALÁ"                    "MARCAVALLE"
# [133] "COCHARCAS"                   "P.CHONGOS"
# [135] "C.TURPAC Y TINYARI"          "SOCOS"
# [137] "PUMPUNGA"                    "CHUPURO"
# [139] "CARHUAPACHA"                 "A.HUAMANCACA"
# [141] "P.SICAYA"                    "A.HUANCHAC"
# [143] "C.CACHICAMARCA"              "P.COLCA"
# [145] "A.CHACAPAMPA"                "HUASICANCHA"
# [147] "CUCHO"                       "CHILIAY"
# [149] "POTACA"                      "LARIA"
# [151] "CHONGOS ALTO"                "P.HUAYUCACHI"
# [153] "HUAMANMARCA"                 "VIQUES"
# [155] "CACAS"                       "HUARAPUQUIO"
# [157] "CULLHUAS"                    "RETAMA"
# [159] "PACHA"                       "P.TARMA"
# [161] "MACO"                        "MULLUERO"
# [163] "ANDAMARCA"                   "CHANCHA"
# [165] "TARMATAMBO"                  "P.JUNÍN"
# [167] "HUASAHUASY"                  "PARI"
# [169] "YANEC"                       "CHUPÁN"
# [171] "ACONCOCHA"                   "ONDORES"
# [173] "P.ACOBAMBA"                  "PICOY"
# [175] "C.HUARACAYO"                 "A.PALCA"
# [177] "C.HUAILAHUICHÁN"             "P.PALCAMAYO"
# [179] "P.OROYA"                     "HUAYNACANCHA"
# [181] "HUAYHUAY"                    "P.CARHUAMAYO"
# [183] "ULCUMAYO"                    "P.SAN RAMÓN"
# [185] "LA MERCED"                   "P.VISCATÁN"
# [187] "PAN DE AZÚCAR"               "SUITUCANCHA"
# [189] "CHACAPALCA"                  "P.POMACOCHA"
# [191] "PACHACHACA"                  "YAULI"
# [193] "MINAS DE MOROCOCHA"
#  [1] "CIUDAD DEL CERRO" "HUAYLLAY"         "CHACAYÁN"         "CAYNA"
#  [5] "YANAHUANCA"       "NINACACA"         "JAUJA"            "APATA"
#  [9] "ORCOTUNA"         "HUARIPAMPA"       "MUQUIYAUYO"       "ACOLLA"
# [13] "CINCOS"           "MITO"             "LLOCLLAPAMPA"     "CONCEPCIÓN"
# [17] "COCHAS"           "MATAHUASI"        "HUANCAYO"         "CHUPACA"
# [21] "SAN GERÓNIMO"     "SAPALLANGA"       "CHONGOS"          "SICAYA"
# [25] "COLCA"            "HUAYUCACHI"       "TARMA"            "JUNÍN"
# [29] "ACOBAMBA"         "OROYA"            "CARHUAMAYO"       "CHANCHAMAYO"
# [33] "VITOC"            "CHACAPALCA"       "YAULI"

# %% [markdown]
# #### 7. Borrar las varaibles finished_instr_total, finished_instr_men y finished_instr_women

# %%
junin$finished_instr_total <- NULL  #Usams NULLse eliminar la variables pedidas
junin$finished_instr_men <- NULL    
junin$finished_instr_women <- NULL

# %%
head(junin)
# Out:
#   ...1 Region District         comunidad          4_6_years_men 4_6_years_women
# 1 0    JUNIN  CIUDAD DEL CERRO C.CIUDAD DEL CERRO 65            46
# 2 1    JUNIN  CIUDAD DEL CERRO P.YANACANCHA        1             3
# 3 2    JUNIN  CIUDAD DEL CERRO VICO                1             0
# 4 3    JUNIN  CIUDAD DEL CERRO RANCA               0             6
# 5 4    JUNIN  CIUDAD DEL CERRO PASCO               4             4
# 6 5    JUNIN  CIUDAD DEL CERRO QUIRLACOCHA         6             7
#   4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total ...
# 1 111             297            171              468              ...
# 2   4              49             47               96              ...
# 3   1              46             25               71              ...
# 4   6              25             19               44              ...
# 5   8              21             21               42              ...
# 6  13              44             43               87              ...
#   not_finished_instr_women not_finished_instr_total peruvian_men peruvian_women
# 1 209                      544                      361          216
# 2  50                      100                       50           50
# 3  25                       72                       47           25
# 4  25                       50                       25           25
# 5  25                       50                       25           25
# 6  50                      100                       50           50
#   foreign_men foreign_women whites natives mestizos blacks
# 1 1           1             4      284     290      1
# 2 0           0             0      100       0      0
# 3 0           0             0       69       3      0
# 4 0           0             0       25      25      0
# 5 0           0             0       37      13      0
# 6 0           0             0       65      35      0

# %%
base_junin <- junin

# %% [markdown]
# #### 8. Crear columnas con las siguiente información: el % de mujeres que no escriben ni leen, % de varones que no escriben ni leen y % de nativos respecto al total de la población.

# %%
base_junin['%nesc_wom']=base_junin$nesc_mujer/base_junin$nesc_total #% de mujeres que no escriben
base_junin['%nlee_wom']=base_junin$nlee_mujer/base_junin$ntotal_lee #% de mujeres que no escriben
base_junin['%nesc_men']=base_junin$nesc_hombre/base_junin$nesc_total #% de hombres que no escriben
base_junin['%nlee_men']=base_junin$nlee_hombre/base_junin$ntotal_lee #% de hombres que no escriben
base_junin['%nativo']=base_junin$natives/(base_junin$whites+base_junin$natives+ base_junin$mestizos+base_junin$blacks) #% de nativos respecto al total de la población
base_junin['pob_tot']=(base_junin$whites+base_junin$natives+base_junin$mestizos+base_junin$blacks) #total de la población
base_junin
# Out:
#     ...1 Region District         comunidad          4_6_years_men
# 1    0   JUNIN  CIUDAD DEL CERRO C.CIUDAD DEL CERRO 65
# 2    1   JUNIN  CIUDAD DEL CERRO P.YANACANCHA        1
# 3    2   JUNIN  CIUDAD DEL CERRO VICO                1
# 4    3   JUNIN  CIUDAD DEL CERRO RANCA               0
# 5    4   JUNIN  CIUDAD DEL CERRO PASCO               4
# 6    5   JUNIN  CIUDAD DEL CERRO QUIRLACOCHA         6
# 7    6   JUNIN  CIUDAD DEL CERRO CAJAMARQUILLA       9
# 8    7   JUNIN  CIUDAD DEL CERRO CAICO              18
# 9    8   JUNIN  CIUDAD DEL CERRO ROCO                7
# 10   9   JUNIN  CIUDAD DEL CERRO C.SACRA FAMILIA    16
# 11  10   JUNIN  CIUDAD DEL CERRO P.QUINUA            8
# 12  11   JUNIN  CIUDAD DEL CERRO H.PARIAHUANCA       2
# 13  12   JUNIN  CIUDAD DEL CERRO P.SULLUMARCA       12
# 14  13   JUNIN  CIUDAD DEL CERRO H.SAN ANDRÉS        8
# 15  14   JUNIN  HUAYLLAY         P.HUALLAY           5
# 16  15   JUNIN  HUAYLLAY         C.HUAYCHAO          1
# 17  16   JUNIN  HUAYLLAY         COCHAMARCA          0
# 18  17   JUNIN  CHACAYÁN         P.CHACAYÁN          0
# 19  18   JUNIN  CHACAYÁN         VILCABAMBA         23
# 20  19   JUNIN  CHACAYÁN         CUCHES             17
# 21  20   JUNIN  CHACAYÁN         CHANGO             12
# 22  21   JUNIN  CHACAYÁN         MITO                4
# 23  22   JUNIN  CHACAYÁN         ANTAPIRCA          20
# 24  23   JUNIN  CAYNA            P.CAYNA            10
# 25  24   JUNIN  CAYNA            A. COLPAS           0
# 26  25   JUNIN  CAYNA            P.YACAS             4
# 27  26   JUNIN  CAYNA            C.MASQUIN           3
# 28  27   JUNIN  CAYNA            P.YAMOR            25
# 29  28   JUNIN  CAYNA            PÁUCAR             26
# 30  29   JUNIN  CAYNA            TANGOR              1
# ... ...  ...    ...              ...                ...
# 168 167  JUNIN  JUNÍN            P.JUNÍN            69
# 169 168  JUNIN  JUNÍN            CACAS              81
# 170 169  JUNIN  JUNÍN            HUASAHUASY         56
# 171 170  JUNIN  JUNÍN            PARI               13
# 172 171  JUNIN  JUNÍN            YANEC              12
# 173 172  JUNIN  JUNÍN            CHUPÁN              7
# 174 173  JUNIN  JUNÍN            ACONCOCHA           2
# 175 174  JUNIN  JUNÍN            ONDORES            18
# 176 175  JUNIN  ACOBAMBA         P.ACOBAMBA         44
# 177 176  JUNIN  ACOBAMBA         PICOY              12
# 178 177  JUNIN  ACOBAMBA         C.HUARACAYO        37
# 179 178  JUNIN  ACOBAMBA         A.PALCA            53
# 180 179  JUNIN  ACOBAMBA         C.HUAILAHUICHÁN    23
# 181 180  JUNIN  ACOBAMBA         P.PALCAMAYO        18
# 182 181  JUNIN  OROYA            P.OROYA            11
# 183 182  JUNIN  OROYA            HUAYNACANCHA        4
# 184 183  JUNIN  OROYA            PACHA               2
# 185 184  JUNIN  OROYA            HUAYHUAY           13
# 186 185  JUNIN  CARHUAMAYO       P.CARHUAMAYO       35
# 187 186  JUNIN  CARHUAMAYO       ULCUMAYO           27
# 188 187  JUNIN  CHANCHAMAYO      P.SAN RAMÓN         1
# 189 188  JUNIN  CHANCHAMAYO      LA MERCED          12
# 190 189  JUNIN  VITOC            P.VISCATÁN          2
# 191 190  JUNIN  VITOC            PAN DE AZÚCAR       2
# 192 191  JUNIN  CHACAPALCA       SUITUCANCHA         0
# 193 192  JUNIN  CHACAPALCA       CHACAPALCA          1
# 194 193  JUNIN  YAULI            P.POMACOCHA         1
# 195 194  JUNIN  YAULI            PACHACHACA          2
# 196 195  JUNIN  YAULI            YAULI               2
# 197 196  JUNIN  YAULI            MINAS DE MOROCOCHA  9
#     4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women
# 1   46              111             297            171
# 2    3                4              49             47
# 3    0                1              46             25
# 4    6                6              25             19
# 5    4                8              21             21
# 6    7               13              44             43
# 7    8               17              31             39
# 8   23               41              90             77
# 9    4               11              42             19
# 10   8               24              26             25
# 11   6               14              17             19
# 12   6                8              10             12
# 13  14               26              38             32
# 14   0                8              17             25
# 15  11               16              55             37
# 16   0                1              24              8
# 17   3                3              11              8
# 18   5                5             171            151
# 19  16               39              78             84
# 20   3               20              48             42
# 21   3               15             142             94
# 22   1                5              55             36
# 23  15               35              29             60
# 24   0               10              52             26
# 25   0                0              26              0
# 26   0                4              51              0
# 27   0                3              37              0
# 28   0               25              25              0
# 29  31               57              66             44
# 30   0                1              46              0
# ... ...             ...             ...            ...
# 168 73              142             284            191
# 169 79              160             194            172
# 170 44              100             135            137
# 171 14               27              62             45
# 172 16               28              49             29
# 173  7               14              18             18
# 174  2                4              23             23
# 175 13               31              51             51
# 176 41               85             197            163
# 177  8               20              40             32
# 178 32               69             104             72
# 179 53              106             132            151
# 180 18               41              55             52
# 181 25               43              82             75
# 182  9               20              41             35
# 183  2                6              11             16
# 184  4                6               7              3
# 185  8               21              55             33
# 186  6               41             110             32
# 187 11               38             102             19
# 188  2                3              28             35
# 189 13               25              63             57
# 190  0                2              15              8
# 191  4                6              18             10
# 192  4                4              25             33
# 193  0                1              71              0
# 194  0                1              15              7
# 195  0                2              20              8
# 196  6                8              74             38
# 197  5               14              87             25
#     6_14_years_total ... whites natives mestizos blacks %nesc_wom %nlee_wom
# 1   468              ...  4     284     290      1      0.3812785 0.4121037
# 2    96              ...  0     100       0      0      0.6756757 0.7142857
# 3    71              ...  0      69       3      0      0.4237288 0.5319149
# 4    44              ...  0      25      25      0      1.0000000 1.0000000
# 5    42              ...  0      37      13      0      0.5319149 0.5319149
# 6    87              ...  0      65      35      0      0.5581395 0.5542169
# 7    70              ...  0      87       0      0      0.5402299 0.5402299
# 8   167              ...  4     175      29      0      0.7387387 0.5131579
# 9    61              ...  0      70       2      0      0.3194444 0.3000000
# 10   51              ...  0      73       2      0      0.4400000 0.4459459
# 11   36              ...  0      50       0      0      0.5000000 0.5000000
# 12   22              ...  0      24       6      0      0.6000000 0.6000000
# 13   70              ...  0      96       0      0      0.4791667 0.4791667
# 14   42              ...  0      44       6      0      0.5319149 0.5319149
# 15   92              ...  0      92      16      0      0.4485981 0.4795918
# 16   32              ...  0      33       0      0      0.2580645 0.3076923
# 17   19              ...  0      22       0      0      0.5000000 0.5000000
# 18  322              ... 12     284      31      0      0.4859813 0.5217391
# 19  162              ...  0     201       0      0      0.4975124 0.4975124
# 20   90              ...  0     110       0      0      0.4090909 0.4090909
# 21  236              ...  0     251       0      0      0.3864542 0.3864542
# 22   91              ...  0      96       0      0      0.3854167 0.3854167
# 23   89              ...  0     124       0      0      0.6048387 0.6048387
# 24   78              ... 26       0      62      0      0.2941176 0.2941176
# 25   26              ...  0      26       0      0      0.0000000 0.0000000
# 26   51              ...  0      55       0      0      0.0000000 0.0000000
# 27   37              ...  0      40       0      0      0.0000000 0.0000000
# 28   25              ...  0      50       0      0      0.0000000 0.0000000
# 29  110              ...  0     119      28      0      0.6355932 0.5680000
# 30   46              ...  0      47       0      0      0.0000000 0.0000000
# ... ...                  ...    ...     ...      ...    ...       ...
# 168 475              ...  8     542      67      0      0.4402080 0.4417391
# 169 366              ...  0     526       0      0      0.5763889 0.5724299
# 170 272              ...  2       0     370      0      0.4617834 0.4617834
# 171 107              ...  0     134       0      0      0.5673077 0.5728155
# 172  78              ...  0     106       0      0      0.4245283 0.4245283
# 173  36              ...  0      56       0      0      0.4464286 0.4464286
# 174  46              ...  0      50       0      0      0.5000000 0.5000000
# 175 102              ...  0     167       0      0      0.3832335 0.3832335
# 176 360              ... 69     261     115      0      0.4647887 0.4875000
# 177  72              ...  4      72      16      0      0.5135135 0.5396825
# 178 176              ...  5     228      12      0      0.4639640 0.4660633
# 179 283              ... 30     197     162      0      0.5769231 0.5940594
# 180 107              ... 70      78       0      0      0.5111111 0.5762712
# 181 157              ...  0     156      44      0      0.4930556 0.5617284
# 182  76              ... 15      28      53      0      0.3392857 0.3653846
# 183  27              ...  0      33       0      0      0.5454545 0.5454545
# 184  10              ...  0      16       0      0      0.4375000 0.4375000
# 185  88              ...  0     108       1      0      0.6071429 0.6181818
# 186 142              ...  3     143      35      0      0.2146893 0.2156863
# 187 121              ...  4     123      32      0      0.1886792 0.1933333
# 188  63              ...  1      65       0      0      0.5471698 0.5750000
# 189 120              ... 57      78      10      0      0.4494382 0.4743590
# 190  23              ...  4      14       7      0      0.3333333 0.3333333
# 191  28              ...  2       6      26      0      0.4516129 0.4814815
# 192  58              ...  0      33      29      0      0.3837209 1.0000000
# 193  71              ...  0      35      39      0      0.0000000 0.0000000
# 194  22              ...  0      21       2      0      0.3500000 0.4666667
# 195  28              ...  0       4      26      0      0.2800000 0.3181818
# 196 112              ... 37      14      69      0      0.3536585 0.3859649
# 197 112              ...  1     118       7      0      0.2459016 0.2542373
#     %nesc_men %nlee_men %nativo   pob_tot
# 1   0.6187215 0.5878963 0.4905009 579
# 2   0.3243243 0.2857143 1.0000000 100
# 3   0.5762712 0.4680851 0.9583333  72
# 4   0.0000000 0.0000000 0.5000000  50
# 5   0.4680851 0.4680851 0.7400000  50
# 6   0.4418605 0.4457831 0.6500000 100
# 7   0.4597701 0.4597701 1.0000000  87
# 8   0.2612613 0.4868421 0.8413462 208
# 9   0.6805556 0.7000000 0.9722222  72
# 10  0.5600000 0.5540541 0.9733333  75
# 11  0.5000000 0.5000000 1.0000000  50
# 12  0.4000000 0.4000000 0.8000000  30
# 13  0.5208333 0.5208333 1.0000000  96
# 14  0.4680851 0.4680851 0.8800000  50
# 15  0.5514019 0.5204082 0.8518519 108
# 16  0.7419355 0.6923077 1.0000000  33
# 17  0.5000000 0.5000000 1.0000000  22
# 18  0.5140187 0.4782609 0.8685015 327
# 19  0.5024876 0.5024876 1.0000000 201
# 20  0.5909091 0.5909091 1.0000000 110
# 21  0.6135458 0.6135458 1.0000000 251
# 22  0.6145833 0.6145833 1.0000000  96
# 23  0.3951613 0.3951613 1.0000000 124
# 24  0.7058824 0.7058824 0.0000000  88
# 25  1.0000000 1.0000000 1.0000000  26
# 26  1.0000000 1.0000000 1.0000000  55
# 27  1.0000000 1.0000000 1.0000000  40
# 28  1.0000000 1.0000000 1.0000000  50
# 29  0.3644068 0.4320000 0.8095238 147
# 30  1.0000000 1.0000000 1.0000000  47
# ... ...       ...       ...       ...
# 168 0.5597920 0.5582609 0.8784441 617
# 169 0.4236111 0.4275701 1.0000000 526
# 170 0.5382166 0.5382166 0.0000000 372
# 171 0.4326923 0.4271845 1.0000000 134
# 172 0.5754717 0.5754717 1.0000000 106
# 173 0.5535714 0.5535714 1.0000000  56
# 174 0.5000000 0.5000000 1.0000000  50
# 175 0.6167665 0.6167665 1.0000000 167
# 176 0.5352113 0.5125000 0.5865169 445
# 177 0.4864865 0.4603175 0.7826087  92
# 178 0.5360360 0.5339367 0.9306122 245
# 179 0.4230769 0.4059406 0.5064267 389
# 180 0.4888889 0.4237288 0.5270270 148
# 181 0.5069444 0.4382716 0.7800000 200
# 182 0.6607143 0.6346154 0.2916667  96
# 183 0.4545455 0.4545455 1.0000000  33
# 184 0.5625000 0.5625000 1.0000000  16
# 185 0.3928571 0.3818182 0.9908257 109
# 186 0.7853107 0.7843137 0.7900552 181
# 187 0.8113208 0.8066667 0.7735849 159
# 188 0.4528302 0.4250000 0.9848485  66
# 189 0.5505618 0.5256410 0.5379310 145
# 190 0.6666667 0.6666667 0.5600000  25
# 191 0.5483871 0.5185185 0.1764706  34
# 192 0.1511628 0.0000000 0.5322581  62
# 193 0.4184397 1.0000000 0.4729730  74
# 194 0.6500000 0.5333333 0.9130435  23
# 195 0.7200000 0.6818182 0.1333333  30
# 196 0.6463415 0.6140351 0.1166667 120
# 197 0.7540984 0.7457627 0.9365079 126

# %% [markdown]
# #### 9. Crear una base de datos con la siguiente información:
# - Quedarse con la información de los distritos de Ciudad del Cerro, Jauja, Acolla, San Gerónimo, Tarma, Oroya y Concepción
# - Ciudades con una cantidad de niños (4-6 años) mayor a 50 y de (6-14 años) > 70
# - Ordenar las variables según el total de la población y cantidad de población nativa
# - Solo quedarse con las variables trabajadas en 8, Distrito, y comunidad.
# - Guardar la mitad de la información en bases diferentes (llamar a cada uno Base1 y Base 2)
# - Guardar la Base1 en formato csv y excel en la carpeta data. (Use el siguiente nombre Base1_WG(numero de grupo))

# %% [markdown]
# #### 10. Crear una función que me permita extraer columnas un rango de columnas y de filas. Crear una función que me permite extraer una columna según el nombre de la variable y dos filas.
