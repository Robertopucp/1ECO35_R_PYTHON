# %% [markdown]
# # Data base managment

# %%
import graphviz as gr

# %%
g = gr.Digraph()

g.edge("Genetic Factor", "Smoking"),
g.edge("Genetic Factor", "Lung Cancer"),
g.edge("Smoking", "Lung Cancer")

# %%
g

# %%
# !pip install causalgraphicalmodels
# Out:
# Requirement already satisfied: causalgraphicalmodels in c:\users\roberto\anaconda3\lib\site-packages (0.0.4)
# Requirement already satisfied: networkx in c:\users\roberto\anaconda3\lib\site-packages (from causalgraphicalmodels) (2.7.1)
# Requirement already satisfied: pandas in c:\users\roberto\anaconda3\lib\site-packages (from causalgraphicalmodels) (1.4.2)
# Requirement already satisfied: numpy in c:\users\roberto\anaconda3\lib\site-packages (from causalgraphicalmodels) (1.21.5)
# Requirement already satisfied: graphviz in c:\users\roberto\anaconda3\lib\site-packages (from causalgraphicalmodels) (0.16)
# Requirement already satisfied: pytz>=2020.1 in c:\users\roberto\anaconda3\lib\site-packages (from pandas->causalgraphicalmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\roberto\anaconda3\lib\site-packages (from pandas->causalgraphicalmodels) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\roberto\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->causalgraphicalmodels) (1.16.0)

# %%
from causalgraphicalmodels import CausalGraphicalModel



sprinkler = CausalGraphicalModel(
    nodes=["season", "rain", "sprinkler", "wet", "slippery"],
    edges=[
        ("season", "rain"), 
        ("season", "sprinkler"), 
        ("rain", "wet"),
        ("sprinkler", "wet"), 
        ("wet", "slippery")
    ]
)

# draw return a graphviz `dot` object, which jupyter can render
sprinkler.draw()
