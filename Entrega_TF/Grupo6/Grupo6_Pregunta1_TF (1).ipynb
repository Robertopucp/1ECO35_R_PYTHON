# %%
#Empezamos configurando el ambiente de trabajo, es decir, que nos preparamos importando las librerías y comandos necesarios.
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

#Además, determinamos el sitio web del cual extraeremos información: el sitio web de la SUNEDU
lista_sunedu="https://www.sunedu.gob.pe/lista-universidades/"
table_id1="tablepress-23" #Universidades Privadas
table_id2="tablepress-22" #Universidades Públicas
response=requests.get(lista_sunedu)
soup=BeautifulSoup(response.text, "html.parser")

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ariana\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ariana\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ariana\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ariana\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\ariana\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ariana\anaconda3\lib\site-packages (1.20.1)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\ariana\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ariana\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ariana\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ariana\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ariana\anaconda3\lib\site-packages (from requests) (2.10)

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\ariana\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ariana\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ariana\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %%
#Continuamos extrayendo la tabla correspondiente a las universidades privadas. Para ubicarla previamente se le inspecciona.

# %%
#Esto es muy importante dado que en el sitio web hay dos tablas, así que debe prestarse atención para anotar con cuál se trabaja

# %%
#Nótese que tambien se creó la dummy que indica el estado de su licencia [1 = licenciada; 0 = no licenciada]

# %%
privada_table=soup.find("table", attrs={"id": table_id1})
df_privada=pd.read_html(str(privada_table))
df_privada=df_privada[0]
df_privada['TIPO']="Privada"
df_privada['LICENCIADA']= pd.notnull(df_privada['FECHA DE PUB. DIARIO EL PERUANO'])*1
df_privada=df_privada.loc[:, ['UNIVERSIDAD', 'DEPARTAMENTO', 'PROVINCIA','TIPO', 'LICENCIADA']]
df_privada
# Out:
#                                           UNIVERSIDAD DEPARTAMENTO PROVINCIA  \
# 0            Pontificia Universidad Católica del Perú         Lima      Lima
# 1                Universidad Peruana Cayetano Heredia         Lima      Lima
# 2                 Universidad Católica de Santa María     Arequipa  Arequipa
# 3                            Universidad del Pacífico         Lima      Lima
# 4                                 Universidad de Lima         Lima      Lima
# ..                                                ...          ...       ...
# 87  Universidad Santo Tomás de Aquino de Ciencia e...        Junín  Huancayo
# 88                           Universidad Privada SISE         Lima      Lima
# 89     Universidad Seminario Evangélico de Lima (*12)         Lima      Lima
# 90         Universidad Seminario Bíblico Andino (*12)         Lima      Lima
# 91                      Universidad Católica San José         Lima      Lima
#
#        TIPO  LICENCIADA
# 0   Privada           1
# 1   Privada           1
# 2   Privada           1
# 3   Privada           1
# 4   Privada           1
# ..      ...         ...
# 87  Privada           0
# 88  Privada           0
# 89  Privada           0
# 90  Privada           0
# 91  Privada           0
#
# [92 rows x 5 columns]

# %%
#corresponde repetir el proceso, pero con las universidades públicas.
#Nótese que tambien se creó la dummy que indica el estado de su licencia [1 = licenciada; 0 = no licenciada]

# %%
publica_table=soup.find("table", attrs={"id": table_id2})
df_publica=pd.read_html(str(publica_table))
df_publica=df_publica[0]
df_publica['TIPO']="Publica"
df_publica['LICENCIADA']= pd.notnull(df_publica['FECHA DE PUB. DIARIO EL PERUANO'])*1
df_publica=df_publica.loc[:, ['UNIVERSIDAD', 'DEPARTAMENTO', 'PROVINCIA','TIPO', 'LICENCIADA']]
df_publica
# Out:
#                                           UNIVERSIDAD   DEPARTAMENTO  \
# 6               Lima  Publica           1
# 7                Ica  Publica           0
# 8           Huancayo  Publica           1
# 9             Maynas  Publica           1
# 10              Puno  Publica           1
# 11             Piura  Publica           1
# 12         Cajamarca  Publica           1
# 13              Lima  Publica           0
# 14     Leoncio Prado  Publica           1
# 15           Huánuco  Publica           1
# 16              Lima  Publica           0
# 17             Pasco  Publica           1
# 18            Callao  Publica           0
# 19            Huaura  Publica           0
# 20        Lambayeque  Publica           0
# 21             Tacna  Publica           1
# 22            Huaraz  Publica           1
# 23        San Martín  Publica           1
# 24  Coronel Portillo  Publica           1
# 25            Tumbes  Publica           0
# 26             Santa  Publica           1
# 27      Huancavelica  Publica           1
# 28         Tambopata  Publica           0
# 29       Chachapoyas  Publica           1
# 30           Abancay  Publica           0
# 31  Coronel Portillo  Publica           1
# 32              Lima  Publica           1
# 33       Andahuaylas  Publica           1
# 34    Mariscal Nieto  Publica           1
# 35         San Román  Publica           1
# 36              Jaén  Publica           1
# 37           Sullana  Publica           1
# 38             Chota  Publica           1
# 39          Barranca  Publica           1
# 40            Cañete  Publica           1
# 41             Bagua  Publica           1
# 42       Chanchamayo  Publica           1
# 43     La Convención  Publica           1
# 44     Alto Amazonas  Publica           1
# 45             Tarma  Publica           1
# 46            Huanta  Publica           1
# 47              Lima  Publica           0
# 48              Lima  Publica           0
# 49          Tayacaja  Publica           1
# 50   Sanchez Carrión  Publica           0

# %%
#Ahora se une las dos tablas en un solo dataframe

# %%
df_universidad=df_privada.append(df_publica, ignore_index=True)
df_universidad=pd.get_dummies(df_universidad, columns=['TIPO'])
df_universidad
# Out:
#                                            UNIVERSIDAD  DEPARTAMENTO  \
# 0             Pontificia Universidad Católica del Perú          Lima
# 1                 Universidad Peruana Cayetano Heredia          Lima
# 2                  Universidad Católica de Santa María      Arequipa
# 3                             Universidad del Pacífico          Lima
# 4                                  Universidad de Lima          Lima
# ..                                                 ...           ...
# 138            Universidad Nacional Autónoma de Huanta      Ayacucho
# 139  Universidad Nacional Tecnológica de San Juan d...          Lima
# 140       Universidad Autónoma Municipal de Los Olivos          Lima
# 141  Universidad Nacional Autónoma de Tayacaja Dani...  Huancavelica
# 142                  Universidad Nacional Ciro Alegría   La Libertad
#
#            PROVINCIA  LICENCIADA  TIPO_Privada  TIPO_Publica
# 0               Lima           1             1             0
# 1               Lima           1             1             0
# 2           Arequipa           1             1             0
# 3               Lima           1             1             0
# 4               Lima           1             1             0
# ..               ...         ...           ...           ...
# 138           Huanta           1             0             1
# 139             Lima           0             0             1
# 140             Lima           0             0             1
# 141         Tayacaja           1             0             1
# 142  Sanchez Carrión           0             0             1
#
# [143 rows x 6 columns]

# %% [markdown]
# ## Geocoding de las universidades

# %%
#Se inicia configurando el ambiente de trabajo, con lo cual se importa libreríasy comandos a usar.

# %%
# Packages
import pandas as pd
import os
import urllib.request, json
import csv
import numpy as np
from tqdm import tqdm_notebook as tqdm # libreria para contabilizar tiempo de ejecución

# %%
#lo que sigue es importantísimo: vincular con google maps, puesto que de este obtendremos la información geográfica

# %%
import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyDr6c93pk9Tepnfr5UqiLxOk_mnwG4Qevo')  # ingreso el Key (token)

# %%
#se define lat como latitud y lng como longitud.

# %%
df_universidad['lat']=None
df_universidad['lng']=None
for index in range(df_universidad.shape[0]):
    df_temp=df_universidad.take([index])
    geocode_result = gmaps.geocode(str(df_temp['UNIVERSIDAD'])+
                                   str(df_temp['DEPARTAMENTO'])+
                                   str(df_temp['PROVINCIA']) ,
                                   region='PE')
    lat=geocode_result[0]['geometry']['location']['lat']
    lng=geocode_result[0]['geometry']['location']['lng']
    df_universidad.loc[index,'lat']=lat
    df_universidad.loc[index,'lng']=lng
df_universidad

#Podemos ahora ver el conjunto de universidades con su respectiva información geográfica
# Out:
#                                            UNIVERSIDAD  DEPARTAMENTO  \
# 0             Pontificia Universidad Católica del Perú          Lima
# 1                 Universidad Peruana Cayetano Heredia          Lima
# 2                  Universidad Católica de Santa María      Arequipa
# 3                             Universidad del Pacífico          Lima
# 4                                  Universidad de Lima          Lima
# ..                                                 ...           ...
# 138            Universidad Nacional Autónoma de Huanta      Ayacucho
# 139  Universidad Nacional Tecnológica de San Juan d...          Lima
# 140       Universidad Autónoma Municipal de Los Olivos          Lima
# 141  Universidad Nacional Autónoma de Tayacaja Dani...  Huancavelica
# 142                  Universidad Nacional Ciro Alegría   La Libertad
#
#            PROVINCIA  LICENCIADA  TIPO_Privada  TIPO_Publica        lat  \
# 0               Lima           1             1             0 -12.069512
# 1               Lima           1             1             0 -12.023977
# 2           Arequipa           1             1             0 -16.406179
# 3               Lima           1             1             0 -12.083797
# 4               Lima           1             1             0 -12.084724
# ..               ...         ...           ...           ...        ...
# 138           Huanta           1             0             1 -12.939932
# 139             Lima           0             0             1 -12.046373
# 140             Lima           0             0             1 -12.000352
# 141         Tayacaja           1             0             1 -12.398693
# 142  Sanchez Carrión           0             0             1  -7.816461
#
#            lng     colors
# 0   -77.079359       pink
# 1   -77.056505       pink
# 2    -71.54763       pink
# 3   -77.048806       pink
# 4   -76.971009       pink
# ..         ...        ...
# 138 -74.243683  darkgreen
# 139 -77.042754    darkred
# 140  -77.08339    darkred
# 141  -74.86892  darkgreen
# 142 -78.045205    darkred
#
# [143 rows x 9 columns]

# %%
#Mediante el siguiente comando se exporta a EXCEL. Este archivo resultante ha sido subido al repositorio

# %%
df_universidad = df_universidad.to_excel("universidades grupo_6.xlsx")

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import chardet

# %%
# Out:
# Collecting geopandas
#   Using cached geopandas-0.11.0-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: packaging in c:\users\ariana\anaconda3\lib\site-packages (from geopandas) (20.9)
# Requirement already satisfied: shapely<2,>=1.7 in c:\users\ariana\anaconda3\lib\site-packages (from geopandas) (1.8.2)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pandas>=0.25.0 in c:\users\ariana\anaconda3\lib\site-packages (from geopandas) (1.2.4)
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\ariana\anaconda3\lib\site-packages (from geopandas) (3.3.1)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ariana\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ariana\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ariana\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (1.20.1)
# Requirement already satisfied: certifi in c:\users\ariana\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2020.12.5)
# Requirement already satisfied: six>=1.5 in c:\users\ariana\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.0->geopandas) (1.15.0)
# Requirement already satisfied: cligj>=0.4 in c:\users\ariana\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\ariana\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in c:\users\ariana\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\users\ariana\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (7.1.2)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_50444037d9454399bc908ca5f83f396e\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_50444037d9454399bc908ca5f83f396e\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-9w7htq1b'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_50444037d9454399bc908ca5f83f396e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_eea79e8544ca4222acd51e1454d9f5d4\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_eea79e8544ca4222acd51e1454d9f5d4\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-vawg3d1t'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_eea79e8544ca4222acd51e1454d9f5d4\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_67d0d494b47f4a56828aa007e6f89861\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_67d0d494b47f4a56828aa007e6f89861\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-ehmmeoqg'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_67d0d494b47f4a56828aa007e6f89861\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_86c1add197d641a68182793927c3d09e\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_86c1add197d641a68182793927c3d09e\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-ah8dwyya'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_86c1add197d641a68182793927c3d09e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_b47dcdd1b5714be7bb47613dfd23c190\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_b47dcdd1b5714be7bb47613dfd23c190\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-gnif25at'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_b47dcdd1b5714be7bb47613dfd23c190\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_69be41194f244094a41a900b80480bdf\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_69be41194f244094a41a900b80480bdf\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-hv4458na'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_69be41194f244094a41a900b80480bdf\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_31ad23ae3ad444b386764f4179b1a1a9\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_31ad23ae3ad444b386764f4179b1a1a9\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ariana\AppData\Local\Temp\pip-pip-egg-info-wvax01xt'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_31ad23ae3ad444b386764f4179b1a1a9\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_968467a7dbc2432e9ec3023a96cb6a3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona
(from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Ariana\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Ariana\AppData\Local\Temp\pip-wheel-o25_0eiw'
#        cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\
#   Complete output (42 lines):
#   C:\Users\Ariana\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   C:\Users\Ariana\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   C:\Users\Ariana\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.8\fiona
#   creating build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.8\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Ariana\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Ariana\AppData\Local\Temp\pip-record-26c9ll31\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Ariana\anaconda3\Include\fiona'
#          cwd: C:\Users\Ariana\AppData\Local\Temp\pip-install-cssp3xaq\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\
#     Complete output (12 lines):
#     C:\Users\Ariana\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     C:\Users\Ariana\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     C:\Users\Ariana\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Ariana\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ariana\\AppData\\Local\\Temp\\pip-install-cssp3xaq\\fiona_ab6e5b0ef4714624b5a9c6d3e67b75b0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Ariana\AppData\Local\Temp\pip-record-26c9ll31\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Ariana\anaconda3\Include\fiona' Check the logs for full command output.

# %%
# !pip install shapely
# Out:
# Requirement already satisfied: shapely in c:\users\ariana\anaconda3\lib\site-packages (1.8.2)

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\ariana\anaconda3\lib\site-packages (from folium) (1.20.1)
# Requirement already satisfied: requests in c:\users\ariana\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ariana\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ariana\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ariana\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ariana\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ariana\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ariana\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1

# %%
from IPython.display import display, HTML

# %%
import geopandas as gpd

# %%
# objects from Geopandas 

import geopandas as gpd
from geopandas import GeoSeries

# %%
import geopandas as gpd

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.9.0 tenacity-8.0.1

# %%
import json

# %%
# !pip install gdal
# Out:
# Requirement already satisfied: gdal in c:\users\ariana\anaconda3\envs\geo_env\lib\site-packages (3.0.2)

# %%
# !pip install folium
# Out:
# Collecting folium
#   Using cached folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Collecting branca>=0.3.0
#   Using cached branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ariana\anaconda3\envs\geo_env\lib\site-packages (from folium) (3.0.3)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: numpy in c:\users\ariana\anaconda3\envs\geo_env\lib\site-packages (from folium) (1.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ariana\anaconda3\envs\geo_env\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ariana\anaconda3\envs\geo_env\lib\site-packages (from requests->folium) (2022.5.18.1)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.10-py2.py3-none-any.whl (139 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, requests, branca, folium
# Successfully installed branca-0.5.0 charset-normalizer-2.1.0 folium-0.12.1.post1 idna-3.3 requests-2.28.1 urllib3-1.26.10

# %%
import folium

# %%
import pandas as pd

# %%
#Lo previo también sirvió para configurar el ambiente de trabajo.

# %%
#En lo que sigue se obtiene la coordenada del Perú, el cual será el punto de partida para la ubicación de las universidades
#contenidas en sus fronteras, sean privadas o públicas

# %%
#-10.40639427007711, -75.3383822662524 son las coordenadas del Perú

# %%
world = folium.Map(
    zoom_start=5,
    location=[-10.40639427007711, -75.33838226625241])

world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d465eab6ed9abb578cf561e7c3923977 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d465eab6ed9abb578cf561e7c3923977&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d465eab6ed9abb578cf561e7c3923977 = L.map(
#                 &quot;map_d465eab6ed9abb578cf561e7c3923977&quot;,
#                 {
#                     center: [-10.40639427007711, -75.33838226625241],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3cc2fc419610c45acd398fc1d685400 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d465eab6ed9abb578cf561e7c3923977);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#El siguiente ploteo es una primera visualización que permite confirmar si vamos (o no) por buen camino

# %%
world = folium.Map(
    zoom_start=6,
    location=[-10.40639427007711, -75.33838226625241]
)

for _, universidad in df_universidad.iterrows():
    folium.Marker(
        location=[universidad['lat'], universidad['lng']],
    ).add_to(world)

world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b92a9623e82f0297305c8148790046e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b92a9623e82f0297305c8148790046e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b92a9623e82f0297305c8148790046e1 = L.map(
#                 &quot;map_b92a9623e82f0297305c8148790046e1&quot;,
#                 {
#                     center: [-10.40639427007711, -75.33838226625241],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36aeee8956300ea08cd46573f36e5bce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_3f9330da0fd530a4edf180e82667702c = L.marker(
#                 [-12.069512, -77.0793592],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_5473b35bfc34fb4d84ed852d3d0db8fc = L.marker(
#                 [-12.0239773, -77.0565049],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_8d36d7e90697347ed0c628c3f1a5990b = L.marker(
#                 [-16.4061786, -71.5476298],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_6121b20d5ffc5cfc72314b0fd38019f1 = L.marker(
#                 [-12.0837969, -77.048806],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_fa45866b84c279b277aa88b7f2d025a9 = L.marker(
#                 [-12.0847243, -76.9710095],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_a2462ef73bdccbca24f1dadd3f8b3315 = L.marker(
#                 [-12.0458325, -76.96799],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_6adbfec1f9f534c662135a725abe106f = L.marker(
#                 [-12.0716313, -76.9650529],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_ab91b4a539ba6c5c62e700db6e83ddea = L.marker(
#                 [-12.0609372, -77.0975378],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_cce70136376acdddbf9d4fa5cef8c454 = L.marker(
#                 [-5.1766923, -80.6346434],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_2f4dec71114b20b8dae349fba7d04810 = L.marker(
#                 [-12.1318477, -76.9796467],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_44285b2af56de32bfae7397f55d31e30 = L.marker(
#                 [-15.532748, -70.118667],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_0165ee7d76bc6a8f7a223f0fe336062d = L.marker(
#                 [-12.0686357, -75.21029759999999],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_5161fac5f57d0031c4e522271f1356fd = L.marker(
#                 [-11.989087, -76.83966199999999],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_46e5b017114c04485a62e8c088bf7642 = L.marker(
#                 [-13.5371521, -71.90391389999999],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_6bcdd4443f486dcb73c5320d72a4e0b3 = L.marker(
#                 [-13.6391954, -72.8929],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_1195d70bfbc076d8fc50e0de3fa5124e = L.marker(
#                 [-18.0048523, -70.22611719999999],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_917a3dc3027e625393fb229a9b4186bc = L.marker(
#                 [-6.790111, -79.8783334],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_78961fecce896bc3b2f8249a387c8aaa = L.marker(
#                 [-9.0532681, -78.5907465],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_d1a061b1c2fd2b23f1c132fc79d728fc = L.marker(
#                 [-8.127885299999999, -79.03236919999999],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_cb7b13ee46be946b0a72d955d2e77035 = L.marker(
#                 [-9.9284112, -76.2371722],
#                 {}
#             ).addTo(map_b92a9623e82f0297305c8148790046e1);
#
#
#             var marker_07d6649f7d7c5ba33e2d249ade11242b = L.marker(
#                 [-17.1927361,

# %%
#Lo siguiente es crear subsets para diferencias universidades públicas de privadas; y crear un mapa para cada caso

# %%
temp_priv = df_universidad[df_universidad.TIPO_Privada==1]
temp_publ = df_universidad[df_universidad.TIPO_Privada==0]

# %%
def select_marker_color(row):
    if row['LICENCIADA'] == 1 and row['TIPO_Privada'] ==1:
        return 'pink'
    elif row['LICENCIADA'] == 0 and row['TIPO_Privada'] ==1:
        return 'blue'
    elif row['LICENCIADA'] == 1 and row['TIPO_Publica'] ==1:
        return 'darkgreen' 
    elif row['LICENCIADA'] == 0 and row['TIPO_Publica'] ==1:
        return 'darkred'
temp_priv['colors'] = temp_priv.apply(select_marker_color, axis=1)
temp_priv.head(10)
world_all_cities_colored = folium.Map(
    zoom_start=4.5
,
    location=[-10.40639427007711, -75.33838226625241]
)

for _, universidad in temp_priv.iterrows():
    folium.Marker(
        location=[universidad['lat'], universidad['lng']],
          popup=universidad[0],
        icon=folium.Icon(color=universidad['colors'], prefix='fa', icon='circle')
    ).add_to(world_all_cities_colored)
    
world_all_cities_colored
# Out:
# <ipython-input-184-7f5a334e0761>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_priv['colors'] = temp_priv.apply(select_marker_color, axis=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5da3a699e9a5364da759f2bfb7950209 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5da3a699e9a5364da759f2bfb7950209&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5da3a699e9a5364da759f2bfb7950209 = L.map(
#                 &quot;map_5da3a699e9a5364da759f2bfb7950209&quot;,
#                 {
#                     center: [-10.40639427007711, -75.33838226625241],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc277f58710121bb918641b125667d3e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5da3a699e9a5364da759f2bfb7950209);
#
#
#             var marker_8beb43fd56be2514ccfd663a17ca743f = L.marker(
#                 [-12.069512, -77.0793592],
#                 {}
#             ).addTo(map_5da3a699e9a5364da759f2bfb7950209);
#
#
#             var icon_f11c3225785c353dec12d9f2ed78fa47 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8beb43fd56be2514ccfd663a17ca743f.setIcon(icon_f11c3225785c353dec12d9f2ed78fa47);
#
#
#         var popup_45e1e66f3b5ecf25f5647a1e6d4d3610 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_55f5ba90e69f5c69837f56771240e6a1 = $(`&lt;div id=&quot;html_55f5ba90e69f5c69837f56771240e6a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pontificia Universidad Católica del Perú&lt;/div&gt;`)[0];
#             popup_45e1e66f3b5ecf25f5647a1e6d4d3610.setContent(html_55f5ba90e69f5c69837f56771240e6a1);
#
#
#         marker_8beb43fd56be2514ccfd663a17ca743f.bindPopup(popup_45e1e66f3b5ecf25f5647a1e6d4d3610)
#         ;
#
#
#
#
#             var marker_07acd914ed567689031b8bd8f8487f9a = L.marker(
#                 [-12.0239773, -77.0565049],
#                 {}
#             ).addTo(map_5da3a699e9a5364da759f2bfb7950209);
#
#
#             var icon_8f3c66d8f7fbc32eacab9d8b7b847519 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_07acd914ed567689031b8bd8f8487f9a.setIcon(icon_8f3c66d8f7fbc32eacab9d8b7b847519);
#
#
#         var popup_d19fa82d69c8ad696d74154fb4376bae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c592bd3d8a0db180187bfaeada30f817 = $(`&lt;div id=&quot;html_c592bd3d8a0db180187bfaeada30f817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universidad Peruana Cayetano Heredia&lt;/div&gt;`)[0];
#             popup_d19fa82d69c8ad696d74154fb4376bae.setContent(html_c592bd3d8a0db180187bfaeada30f817);
#
#
#         marker_07acd914ed567689031b8bd8f8487f9a.bindPopup(popup_d19fa82d69c8ad696d74154fb4376bae)
#         ;
#
#
#
#
#             var marker_b1db44a3603fe37ceffc8020a94af842 = L.marker(
#                 [-16.4061786, -71.5476298],
#                 {}
#             ).addTo(map_5da3a699e9a5364da759f2bfb7950209);
#
#
#             var icon_cebd2b6cb171148fef5a49fe382fc1b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b1db44a3603fe37ceffc8020a94af842.setIcon(icon_cebd2b6cb171148fef5a49fe382fc1b9);
#
#
#         var popup_e45f5e15cd7a9e92a92f56664d3829bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_21319aaa61cb17ab6d77c93a3e356b8c = $(`&lt;div id=&quot;html_21319aaa61cb17ab6d77c93a3e356b8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universidad Católica de Santa María&lt;/div&gt;`)[0];
#             popup_e45f5e15cd7a9e92a92f56664d3829bf.setContent(html_21319aaa61cb17ab6d77c93a3e356b8c);
#
#
#         marker_b1db44a3603fe37ceffc8020a94af842.bindPopup(popup_e45f5e15cd7a9e92a92f56664d3829bf)
#         ;
#
#
#
#
#             var marker_bcf46632d4a1cbca6173c6053a41f146 = L.marker(
#                 [-12.0837969, -77.048806],
#                 {}
#             ).addTo(map_5da3a699e9a5364da759f2bfb7950209);
#
#
#             var icon_68ca9870215cc6ed18f41a026f7dc341 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marke

# %%
def select_marker_color(row):
    if row['LICENCIADA'] == 1 and row['TIPO_Privada'] ==1:
        return 'pink'
    elif row['LICENCIADA'] == 0 and row['TIPO_Privada'] ==1:
        return 'blue'
    elif row['LICENCIADA'] == 1 and row['TIPO_Publica'] ==1:
        return 'darkgreen' 
    elif row['LICENCIADA'] == 0 and row['TIPO_Publica'] ==1:
        return 'darkred'
temp_publ['colors'] = temp_publ.apply(select_marker_color, axis=1)
temp_publ.head(10)
world_all_cities_colored = folium.Map(
    zoom_start=5
,
    location=[-10.40639427007711, -75.33838226625241]
)

for _, universidad in temp_publ.iterrows():
    folium.Marker(
        location=[universidad['lat'], universidad['lng']],
        popup=universidad[0],
        icon=folium.Icon(color=universidad['colors'], prefix='fa', icon='circle')
    ).add_to(world_all_cities_colored)
    
world_all_cities_colored
# Out:
# <ipython-input-185-9c59dcd8dd71>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_publ['colors'] = temp_publ.apply(select_marker_color, axis=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f496c2f536b2dd22df1e72466b9a8dc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f496c2f536b2dd22df1e72466b9a8dc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f496c2f536b2dd22df1e72466b9a8dc5 = L.map(
#                 &quot;map_f496c2f536b2dd22df1e72466b9a8dc5&quot;,
#                 {
#                     center: [-10.40639427007711, -75.33838226625241],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b818dda0b9132daf76ef445c632860f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f496c2f536b2dd22df1e72466b9a8dc5);
#
#
#             var marker_6abe259c8d58b270e85f122b82cc37dd = L.marker(
#                 [-12.0561578, -77.0845196],
#                 {}
#             ).addTo(map_f496c2f536b2dd22df1e72466b9a8dc5);
#
#
#             var icon_6774e34e6a381bcd02f4f5c8fb92a675 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6abe259c8d58b270e85f122b82cc37dd.setIcon(icon_6774e34e6a381bcd02f4f5c8fb92a675);
#
#
#         var popup_c2a820844c0db884096cf7ef1cb47764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_193630ab5f88b8beb1e894920156650c = $(`&lt;div id=&quot;html_193630ab5f88b8beb1e894920156650c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universidad Nacional Mayor de San Marcos&lt;/div&gt;`)[0];
#             popup_c2a820844c0db884096cf7ef1cb47764.setContent(html_193630ab5f88b8beb1e894920156650c);
#
#
#         marker_6abe259c8d58b270e85f122b82cc37dd.bindPopup(popup_c2a820844c0db884096cf7ef1cb47764)
#         ;
#
#
#
#
#             var marker_4fc920e29c3ded54783a5d2c003492dc = L.marker(
#                 [-13.1612479, -74.2257722],
#                 {}
#             ).addTo(map_f496c2f536b2dd22df1e72466b9a8dc5);
#
#
#             var icon_aaa0c778a7958896e596ff63ab8a9b9c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4fc920e29c3ded54783a5d2c003492dc.setIcon(icon_aaa0c778a7958896e596ff63ab8a9b9c);
#
#
#         var popup_b743acebdb6631a90e72c214c0fac549 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fc6615b9b321a7a47e515d4c6b86678b = $(`&lt;div id=&quot;html_fc6615b9b321a7a47e515d4c6b86678b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universidad Nacional de San Cristóbal de Huamanga&lt;/div&gt;`)[0];
#             popup_b743acebdb6631a90e72c214c0fac549.setContent(html_fc6615b9b321a7a47e515d4c6b86678b);
#
#
#         marker_4fc920e29c3ded54783a5d2c003492dc.bindPopup(popup_b743acebdb6631a90e72c214c0fac549)
#         ;
#
#
#
#
#             var marker_979532047a095a484adfde82660dabb2 = L.marker(
#                 [-13.52193, -71.9583208],
#                 {}
#             ).addTo(map_f496c2f536b2dd22df1e72466b9a8dc5);
#
#
#             var icon_7a341f51c3832b0de19c300006f67fc7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_979532047a095a484adfde82660dabb2.setIcon(icon_7a341f51c3832b0de19c300006f67fc7);
#
#
#         var popup_e846d08d6836b8956db439e3c1bcc5e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c4ea60b87dde1c0652a9fc15e129e581 = $(`&lt;div id=&quot;html_c4ea60b87dde1c0652a9fc15e129e581&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universidad Nacional de San Antonio Abad del Cusco&lt;/div&gt;`)[0];
#             popup_e846d08d6836b8956db439e3c1bcc5e2.setContent(html_c4ea60b87dde1c0652a9fc15e129e581);
#
#
#         marker_979532047a095a484adfde82660dabb2.bindPopup(popup_e846d08d6836b8956db439e3c1bcc5e2)
#         ;
#
#
#
#
#             var marker_73adf92c5946c51502aad802b79fc58f = L.marker(
#                 [-8.1142716, -79.03837349999999],
#                 {}
#             ).addTo(map_f496c2f536b2dd22df1e72466b9a8dc5);
#
#
#             var icon_e0e1ecf467102f2b5b6a48b5237a802c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quo
