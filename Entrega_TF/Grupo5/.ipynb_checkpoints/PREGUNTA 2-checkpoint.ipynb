# %% [markdown]
# # 2. Manejo de información geo-referenciada
#
# Debe trabajar con información cartográfica del Censo 2017. El archivo shapefile respectivo está en la carpeta 5 Informacion Cartografica Shape. La información geográfica de los centros de salud mental para Lima está en el excel Salud mental peru.xls.

# %% [markdown]
# ### 2.1. Subir la base de datos de las manzanas en formate GeodataFrame. Crear los centroides de las manzanas

# %%
#import packages

import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %%
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString, Polygon, MultiPoint
from shapely import wkt

# %%
# pip install xlrd

# %%
#get districts names

distritos = ['ATE','BARRANCO','BREÑA', 'CALLAO', 'CARABAYLLO','CHORRILLOS','COMAS','EL_AGUSTINO','INDEPENDENCIA',
           'JESUS_MARIA','LA_MOLINA_LIMA','LA_VICTORIA','LIMA','LINCE','LOS_OLIVOS_LIMA','MAGDALENA_DEL_MAR',
           'MIRAFLORES','PUEBLO_LIBRE','PUENTE_PIEDRA', 'RIMAC_LIMA','SAN_BORJA','SAN_ISIDRO','SAN_JUAN_DE_LURIGANCHO','SAN_JUAN_DE_MIRAFLORES','SAN_LUIS',
            'SAN_MARTIN_DE_PORRES','SAN_MIGUEL','SANTA_ANITA','SURCO','VILLA_EL_SALVADOR','VILLA_MARIA_DEL_TRIUNFO']

# %%
#import data "5_Informacion_Cartografica-Shape"

data = r"../../data/Trabajo_final/5_Informacion_Cartografica-Shape/" 
 

i = 0

for j in distritos:
        i = i + 1
        globals()[f'manzana{i}']  = gpd.read_file(f'{data}{j}/{j}.shp')
        globals()[f'manzana{i}']  = globals()[f'manzana{i}'][['Mz','geometry','UBIGEO']]
        globals()[f'manzana{i}']  = globals()[f'manzana{i}'].rename(columns = {"Mz":"id_manzana"})   
    
mapa = manzana1.copy()

for k in range(2,i+1):
    mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16908\333670943.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mapa = mapa.append(globals()[f'manzana{k}'] , ignore_index=True)

# %%
mapa = gpd.GeoDataFrame(mapa, geometry = "geometry", crs='24891')
mapa
# Out:
#                 id_manzana                                           geometry  \
# 0       150103000108200012  POLYGON ((-76.822 -12.033, -76.822 -12.033, -7...
# 1       150103000104101040  POLYGON ((-76.891 -12.025, -76.891 -12.026, -7...
# 2       150103000101800006  POLYGON ((-76.920 -12.042, -76.920 -12.042, -7...
# 3       150103000102900018  POLYGON ((-76.923 -12.025, -76.922 -12.025, -7...
# 4       150103000103800056  POLYGON ((-76.893 -12.034, -76.893 -12.034, -7...
# ...                    ...                                                ...
# 87854  150143000103400036D  POLYGON ((-76.937 -12.169, -76.937 -12.169, -7...
# 87855  150143000104600043L  POLYGON ((-76.918 -12.166, -76.918 -12.166, -7...
# 87856   150143000106800020  POLYGON ((-76.914 -12.207, -76.914 -12.207, -7...
# 87857   150143000108000026  POLYGON ((-76.909 -12.225, -76.909 -12.225, -7...
# 87858   150143000108000045  POLYGON ((-76.912 -12.222, -76.912 -12.222, -7...
#
#        UBIGEO
# 0      150103
# 1      150103
# 2      150103
# 3      150103
# 4      150103
# ...       ...
# 87854  150143
# 87855  150143
# 87856  150143
# 87857  150143
# 87858  150143
#
# [87859 rows x 3 columns]

# %%
# get centroids

mapa['centroids'] = mapa.centroid
mapa
# Out:
#                 id_manzana                                           geometry  \
# 0       150103000108200012  POLYGON ((-76.822 -12.033, -76.822 -12.033, -7...
# 1       150103000104101040  POLYGON ((-76.891 -12.025, -76.891 -12.026, -7...
# 2       150103000101800006  POLYGON ((-76.920 -12.042, -76.920 -12.042, -7...
# 3       150103000102900018  POLYGON ((-76.923 -12.025, -76.922 -12.025, -7...
# 4       150103000103800056  POLYGON ((-76.893 -12.034, -76.893 -12.034, -7...
# ...                    ...                                                ...
# 87854  150143000103400036D  POLYGON ((-76.937 -12.169, -76.937 -12.169, -7...
# 87855  150143000104600043L  POLYGON ((-76.918 -12.166, -76.918 -12.166, -7...
# 87856   150143000106800020  POLYGON ((-76.914 -12.207, -76.914 -12.207, -7...
# 87857   150143000108000026  POLYGON ((-76.909 -12.225, -76.909 -12.225, -7...
# 87858   150143000108000045  POLYGON ((-76.912 -12.222, -76.912 -12.222, -7...
#
#        UBIGEO                centroids
# 0      150103  POINT (-76.822 -12.033)
# 1      150103  POINT (-76.891 -12.026)
# 2      150103  POINT (-76.920 -12.042)
# 3      150103  POINT (-76.923 -12.025)
# 4      150103  POINT (-76.893 -12.034)
# ...       ...                      ...
# 87854  150143  POINT (-76.937 -12.169)
# 87855  150143  POINT (-76.918 -12.167)
# 87856  150143  POINT (-76.914 -12.207)
# 87857  150143  POINT (-76.909 -12.225)
# 87858  150143  POINT (-76.912 -12.222)
#
# [87859 rows x 4 columns]

# %%
mapa2 = gpd.GeoDataFrame(mapa, geometry='geometry', crs='24891')
mapa2 = mapa2.rename(columns={'centroids' : 'Mz centroids'})
mapa2
# Out:
#                 id_manzana                                           geometry  \
# 0       150103000108200012  POLYGON ((-76.822 -12.033, -76.822 -12.033, -7...
# 1       150103000104101040  POLYGON ((-76.891 -12.025, -76.891 -12.026, -7...
# 2       150103000101800006  POLYGON ((-76.920 -12.042, -76.920 -12.042, -7...
# 3       150103000102900018  POLYGON ((-76.923 -12.025, -76.922 -12.025, -7...
# 4       150103000103800056  POLYGON ((-76.893 -12.034, -76.893 -12.034, -7...
# ...                    ...                                                ...
# 87854  150143000103400036D  POLYGON ((-76.937 -12.169, -76.937 -12.169, -7...
# 87855  150143000104600043L  POLYGON ((-76.918 -12.166, -76.918 -12.166, -7...
# 87856   150143000106800020  POLYGON ((-76.914 -12.207, -76.914 -12.207, -7...
# 87857   150143000108000026  POLYGON ((-76.909 -12.225, -76.909 -12.225, -7...
# 87858   150143000108000045  POLYGON ((-76.912 -12.222, -76.912 -12.222, -7...
#
#        UBIGEO             Mz centroids
# 0      150103  POINT (-76.822 -12.033)
# 1      150103  POINT (-76.891 -12.026)
# 2      150103  POINT (-76.920 -12.042)
# 3      150103  POINT (-76.923 -12.025)
# 4      150103  POINT (-76.893 -12.034)
# ...       ...                      ...
# 87854  150143  POINT (-76.937 -12.169)
# 87855  150143  POINT (-76.918 -12.167)
# 87856  150143  POINT (-76.914 -12.207)
# 87857  150143  POINT (-76.909 -12.225)
# 87858  150143  POINT (-76.912 -12.222)
#
# [87859 rows x 4 columns]

# %%
mapa2['UBIGEO']=mapa2['UBIGEO'].astype(int)
mapa2['UBIGEO']
# Out:
# 0        150103
# 1        150103
# 2        150103
# 3        150103
# 4        150103
#           ...
# 87854    150143
# 87855    150143
# 87856    150143
# 87857    150143
# 87858    150143
# Name: UBIGEO, Length: 87859, dtype: int32

# %%
#Import data "Salud_mental_peru"

salud_mental = pd.read_excel(r'../../data/Trabajo_final/Salud_mental_peru.xls')

# %%
salud_mental
# Out:
#    Institución Departamento Provincia                 Distrito  UBIGEO  \
# 0        MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 1        MINSA         LIMA      LIMA  VILLA MARIA DEL TRIUNFO  150143
# 2        MINSA         LIMA      LIMA                SAN BORJA  150130
# 3        MINSA         LIMA      LIMA              LA VICTORIA  150115
# 4        MINSA         LIMA      LIMA          CERCADO DE LIMA  150101
# 5        MINSA         LIMA      LIMA            PUNTA HERMOZA  150126
# 6        MINSA         LIMA      LIMA                    RIMAC  150128
# 7        MINSA         LIMA      LIMA                    COMAS  150110
# 8        MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 9        MINSA         LIMA      LIMA              LA VICTORIA  150115
# 10       MINSA         LIMA      LIMA               LOS OLIVOS  150117
# 11       MINSA         LIMA      LIMA               PACHACAMAC  150123
# 12       MINSA         LIMA      LIMA                      ATE  150103
# 13       MINSA         LIMA      LIMA              EL AGUSTINO  150111
# 14       MINSA         LIMA      LIMA                LA MOLINA  150114
# 15       MINSA         LIMA      LIMA              CIENEGUILLA  150109
# 16       MINSA         LIMA      LIMA                    ANCON  150102
# 17       MINSA         LIMA      LIMA     SAN MARTIN DE PORRES  150135
# 18       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 19       MINSA         LIMA      LIMA            PUENTE PIEDRA  150125
# 20       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 21       MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 22       MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 23       MINSA         LIMA      LIMA               CARABAYLLO  150106
# 24       MINSA         LIMA      LIMA                     LIMA  150101
# 25       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 26       MINSA         LIMA      LIMA             PUEBLO LIBRE  150121
# 27       MINSA         LIMA      LIMA              SANTA ANITA  150137
# 28       MINSA         LIMA      LIMA                 BARRANCO  150104
# 29       MINSA         LIMA      LIMA  VILLA MARIA DEL TRIUNFO  150143
# 30       MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 31       MINSA         LIMA      LIMA                      ATE  150103
# 32       MINSA         LIMA      LIMA               CARABAYLLO  150106
# 33       MINSA         LIMA      LIMA            PUENTE PIEDRA  150125
# 34       MINSA         LIMA      LIMA               PACHACAMAC  150123
# 35       MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 36       MINSA         LIMA      LIMA   SAN JUAN DE MIRAFLORES  150133
# 37       MINSA         LIMA      LIMA              EL AGUSTINO  150111
#
#     lat_original long_original
# 0     -12.017282     -77.00095
# 1     -12.136658   -76.9482472
# 2     -12.107663    -76.999385
# 3     -12.062212    -77.005597
# 4     -12.066349    -77.035523
# 5     -12.333766    -76.823147
# 6     -12.029416  -77.02954497
# 7     -11.934511   -77.0456523
# 8     -12.186086   -76.9644885
# 9     -12.071416  -77.01337496
# 10    -11.977315   -77.0810609
# 11    -12.094998    -76.885043
# 12    -12.016739  -76.82504094
# 13    -12.032862  -77.00244761
# 14    -12.087299  -76.94220124
# 15    -12.112567    -76.817506
# 16    -11.709974   -77.1255055
# 17    -11.941694  -77.12550653
# 18    -12.191916  -77.00966007
# 19    -11.868171    -77.075281
# 20    -12.201012  -76.97877609
# 21    -12.201321   -76.9423404
# 22    -12.017345  -77.00097776
# 23    -11.901389  -77.03373058
# 24    -12.055652  -77.08246864
# 25    -12.159270   -77.0200131
# 26    -12.069488       -77.058
# 27    -12.045035    -76.975877
# 28    -12.146948   -77.0157362
# 29    -12.161575   -76.9382139
# 30    -12.243153   -76.9294507
# 31    -12.055808   -76.9528728
# 32    -11.880225  -76.99734605
# 33    -11.936079   -77.0941826
# 34    -12.128169    -76.871122
# 35    -12.002754   -77.0177604
# 36    -12.137509    -76.968200
# 37    -12.051241  -76.99732016

# %%
# Centros de Salud de Lima

# DataFrame to GeoDataFrame 

salud = gpd.GeoDataFrame(salud_mental, geometry=gpd.points_from_xy( salud_mental.long_original, salud_mental.lat_original ) )
salud
# Out:
#    Institución Departamento Provincia                 Distrito  UBIGEO  \
# 0        MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 1        MINSA         LIMA      LIMA  VILLA MARIA DEL TRIUNFO  150143
# 2        MINSA         LIMA      LIMA                SAN BORJA  150130
# 3        MINSA         LIMA      LIMA              LA VICTORIA  150115
# 4        MINSA         LIMA      LIMA          CERCADO DE LIMA  150101
# 5        MINSA         LIMA      LIMA            PUNTA HERMOZA  150126
# 6        MINSA         LIMA      LIMA                    RIMAC  150128
# 7        MINSA         LIMA      LIMA                    COMAS  150110
# 8        MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 9        MINSA         LIMA      LIMA              LA VICTORIA  150115
# 10       MINSA         LIMA      LIMA               LOS OLIVOS  150117
# 11       MINSA         LIMA      LIMA               PACHACAMAC  150123
# 12       MINSA         LIMA      LIMA                      ATE  150103
# 13       MINSA         LIMA      LIMA              EL AGUSTINO  150111
# 14       MINSA         LIMA      LIMA                LA MOLINA  150114
# 15       MINSA         LIMA      LIMA              CIENEGUILLA  150109
# 16       MINSA         LIMA      LIMA                    ANCON  150102
# 17       MINSA         LIMA      LIMA     SAN MARTIN DE PORRES  150135
# 18       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 19       MINSA         LIMA      LIMA            PUENTE PIEDRA  150125
# 20       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 21       MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 22       MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 23       MINSA         LIMA      LIMA               CARABAYLLO  150106
# 24       MINSA         LIMA      LIMA                     LIMA  150101
# 25       MINSA         LIMA      LIMA               CHORRILLOS  150108
# 26       MINSA         LIMA      LIMA             PUEBLO LIBRE  150121
# 27       MINSA         LIMA      LIMA              SANTA ANITA  150137
# 28       MINSA         LIMA      LIMA                 BARRANCO  150104
# 29       MINSA         LIMA      LIMA  VILLA MARIA DEL TRIUNFO  150143
# 30       MINSA         LIMA      LIMA        VILLA EL SALVADOR  150142
# 31       MINSA         LIMA      LIMA                      ATE  150103
# 32       MINSA         LIMA      LIMA               CARABAYLLO  150106
# 33       MINSA         LIMA      LIMA            PUENTE PIEDRA  150125
# 34       MINSA         LIMA      LIMA               PACHACAMAC  150123
# 35       MINSA         LIMA      LIMA   SAN JUAN DE LURIGANCHO  150132
# 36       MINSA         LIMA      LIMA   SAN JUAN DE MIRAFLORES  150133
# 37       MINSA         LIMA      LIMA              EL AGUSTINO  150111
#
#     lat_original long_original                     geometry
# 0     -12.017282     -77.00095  POINT (-77.00095 -12.01728)
# 1     -12.136658   -76.9482472  POINT (-76.94825 -12.13666)
# 2     -12.107663    -76.999385  POINT (-76.99939 -12.10766)
# 3     -12.062212    -77.005597  POINT (-77.00560 -12.06221)
# 4     -12.066349    -77.035523  POINT (-77.03552 -12.06635)
# 5     -12.333766    -76.823147  POINT (-76.82315 -12.33377)
# 6     -12.029416  -77.02954497  POINT (-77.02954 -12.02942)
# 7     -11.934511   -77.0456523  POINT (-77.04565 -11.93451)
# 8     -12.186086   -76.9644885  POINT (-76.96449 -12.18609)
# 9     -12.071416  -77.01337496  POINT (-77.01337 -12.07142)
# 10    -11.977315   -77.0810609  POINT (-77.08106 -11.97731)
# 11    -12.094998    -76.885043  POINT (-76.88504 -12.09500)
# 12    -12.016739  -76.82504094  POINT (-76.82504 -12.01674)
# 13    -12.032862  -77.00244761  POINT (-77.00245 -12.03286)
# 14    -12.087299  -76.94220124  POINT (-76.94220 -12.08730)
# 15    -12.112567    -76.817506  POINT (-76.81751 -12.11257)
# 16    -11.709974   -77.1255055  POINT (-77.12551 -11.70997)
# 17    -11.941694  -77.12550653  POINT (-77.12551 -11.94169)
# 18    -12.191916  -77.00966007  POINT (-77.00966 -12.19192)
# 19    -11.868171    -77.075281  POINT (-77.07528 -11.86817)
# 20    -12.201012  -76.97877609  POINT (-76.97878 -12.20101)
# 21    -12.201321   -76.9423404  POINT (-76.94234 -12.20132)
# 22    -12.017345  -77.00097776  POINT (-77.00098 -12.01734)
# 23    -11.901389  -77.03373058  POINT (-77.03373 -11.90139)
# 24    -12.055652  -77.08246864  POINT (-77.08247 -12.05565)
# 25    -12.159270   -77.0200131  POINT (-77.02001 -12.15927)
# 26    -12.069488       -77.058  POINT (-77.05800 -12.06949)
# 27    -12.045035    -76.975877  POINT (-76.97588 -12.04503)
# 28    -12.146948   -77.0157362  POINT (-77.01574 -12.14695)
# 29    -12.161575   -76.9382139  POINT (-76.93821 -12.16157)
# 30    -12.243153   -76.9294507  POINT (-76.92945 -12.24315)
# 31    -12.055808   -76.9528728  POINT (-76.95287 -12.05581)
# 32    -11.880225  -76.99734605  POINT (-76.99735 -11.88023)
# 33    -11.936079   -77.0941826  POINT (-77.09418 -11.93608)
# 34    -12.128169    -76.871122  POINT (-76.87112 -12.12817)
# 35    -12.002754   -77.0177604  POINT (-77.01776 -12.00275)
# 36    -12.137509    -76.968200  POINT (-76.96820 -12.13751)
# 37    -12.051241  -76.99732016  POINT (-76.99732 -12.05124)

# %%
salud['UBIGEO']=salud['UBIGEO'].astype(int)
salud['UBIGEO']
# Out:
# 0     150132
# 1     150143
# 2     150130
# 3     150115
# 4     150101
# 5     150126
# 6     150128
# 7     150110
# 8     150142
# 9     150115
# 10    150117
# 11    150123
# 12    150103
# 13    150111
# 14    150114
# 15    150109
# 16    150102
# 17    150135
# 18    150108
# 19    150125
# 20    150108
# 21    150142
# 22    150132
# 23    150106
# 24    150101
# 25    150108
# 26    150121
# 27    150137
# 28    150104
# 29    150143
# 30    150142
# 31    150103
# 32    150106
# 33    150125
# 34    150123
# 35    150132
# 36    150133
# 37    150111
# Name: UBIGEO, dtype: int32

# %%
mapa3 = mapa2.merge( salud, how="inner", on = 'UBIGEO')
mapa3
# Out:
#                 id_manzana                                         geometry_x  \
# 0       150103000108200012  POLYGON ((-76.822 -12.033, -76.822 -12.033, -7...
# 1       150103000108200012  POLYGON ((-76.822 -12.033, -76.822 -12.033, -7...
# 2       150103000104101040  POLYGON ((-76.891 -12.025, -76.891 -12.026, -7...
# 3       150103000104101040  POLYGON ((-76.891 -12.025, -76.891 -12.026, -7...
# 4       150103000101800006  POLYGON ((-76.920 -12.042, -76.920 -12.042, -7...
# ...                    ...                                                ...
# 141096  150143000106800020  POLYGON ((-76.914 -12.207, -76.914 -12.207, -7...
# 141097  150143000108000026  POLYGON ((-76.909 -12.225, -76.909 -12.225, -7...
# 141098  150143000108000026  POLYGON ((-76.909 -12.225, -76.909 -12.225, -7...
# 141099  150143000108000045  POLYGON ((-76.912 -12.222, -76.912 -12.222, -7...
# 141100  150143000108000045  POLYGON ((-76.912 -12.222, -76.912 -12.222, -7...
#
#         UBIGEO             Mz centroids Institución Departamento Provincia  \
# 0       150103  POINT (-76.822 -12.033)       MINSA         LIMA      LIMA
# 1       150103  POINT (-76.822 -12.033)       MINSA         LIMA      LIMA
# 2       150103  POINT (-76.891 -12.026)       MINSA         LIMA      LIMA
# 3       150103  POINT (-76.891 -12.026)       MINSA         LIMA      LIMA
# 4       150103  POINT (-76.920 -12.042)       MINSA         LIMA      LIMA
# ...        ...                      ...         ...          ...       ...
# 141096  150143  POINT (-76.914 -12.207)       MINSA         LIMA      LIMA
# 141097  150143  POINT (-76.909 -12.225)       MINSA         LIMA      LIMA
# 141098  150143  POINT (-76.909 -12.225)       MINSA         LIMA      LIMA
# 141099  150143  POINT (-76.912 -12.222)       MINSA         LIMA      LIMA
# 141100  150143  POINT (-76.912 -12.222)       MINSA         LIMA      LIMA
#
#                        Distrito  lat_original long_original  \
# 0                           ATE    -12.016739  -76.82504094
# 1                           ATE    -12.055808   -76.9528728
# 2                           ATE    -12.016739  -76.82504094
# 3                           ATE    -12.055808   -76.9528728
# 4                           ATE    -12.016739  -76.82504094
# ...                         ...           ...           ...
# 141096  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
# 141097  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
# 141098  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
# 141099  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
# 141100  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
#
#                          geometry_y
# 0       POINT (-76.82504 -12.01674)
# 1       POINT (-76.95287 -12.05581)
# 2       POINT (-76.82504 -12.01674)
# 3       POINT (-76.95287 -12.05581)
# 4       POINT (-76.82504 -12.01674)
# ...                             ...
# 141096  POINT (-76.93821 -12.16157)
# 141097  POINT (-76.94825 -12.13666)
# 141098  POINT (-76.93821 -12.16157)
# 141099  POINT (-76.94825 -12.13666)
# 141100  POINT (-76.93821 -12.16157)
#
# [141101 rows x 11 columns]

# %% [markdown]
# ###  2.2. Crear una variable dummy llamado Treatment que toma el valor de 1 si el centroide de la manzana se ubica a menos de 1 km de algun centro de salud mental

# %%
#get distance

pt1 = gpd.GeoDataFrame({'geometry': mapa3['Mz centroids']}, crs='24891') 
pt2 = gpd.GeoDataFrame({'geometry': mapa3['geometry_y']}, crs='24891')

mapa3["Distancia"] = pt1.apply(lambda x: pt2.distance(x)) #calculate distance from pt1 to pt2
mapa3["Distancia_KM"] = mapa3["Distancia"] * 100  # get distance in Km
mapa3["Distancia_KM"]
# Out:
# 0          1.660393
# 1         13.290503
# 2          6.689937
# 3          6.854386
# 4          9.790275
#             ...
# 141096     5.154321
# 141097     9.641126
# 141098     6.957537
# 141099     9.281867
# 141100     6.596187
# Name: Distancia_KM, Length: 141101, dtype: float64

# %%
mapa3['Treatment'] = np.where(mapa3['Distancia_KM'] < 1, 1, 0)

mapa3['Treatment']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 141096    0
# 141097    0
# 141098    0
# 141099    0
# 141100    0
# Name: Treatment, Length: 141101, dtype: int32

# %% [markdown]
# ### 2.3. Crear una dummy llamado Control que toma el valor de 1 si la manzana se ubica entre 1 a 2 km del centro de salud mental.

# %%
mapa3['Control'] = np.where((mapa3['Distancia_KM'] <= 2) & (mapa3['Distancia_KM'] >= 1), 1, 0)

mapa3['Control']
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 141096    0
# 141097    0
# 141098    0
# 141099    0
# 141100    0
# Name: Control, Length: 141101, dtype: int32

# %% [markdown]
# ### 2.4. Grafique las manzanas treatment en color rojo y en azul las manzanas de control. Mientras de color blanco o neutral, las manzanas que no son control o treatment. Usar como fondo de fondo de la imagen a Google maps. A nada una leyenda al gráfico y el siguiente titulo (Mental Health Center - treatment and control). Use hexbin para sombrear las manzanas tratadas, controles y neutrales.

# %%
import folium 
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap

# %%
Treatment1 = mapa3.loc[(mapa3['Treatment'].astype(str)).str.contains("1") ]
Treatment1
# Out:
#                  id_manzana  \
# 30       150103000107200054
# 51       150103000101100039
# 66      150103000107500005D
# 96       150103000105400057
# 100     150103000107800002J
# ...                     ...
# 141071  150143000102100003A
# 141076   150143000103300004
# 141077  150143000100300028F
# 141081   150143000101000027
# 141092  150143000103400036D
#
#                                                geometry_x  UBIGEO  \
# 30      POLYGON ((-76.821 -12.016, -76.821 -12.016, -7...  150103
# 51      POLYGON ((-76.957 -12.059, -76.957 -12.059, -7...  150103
# 66      POLYGON ((-76.827 -12.022, -76.827 -12.022, -7...  150103
# 96      POLYGON ((-76.829 -12.008, -76.829 -12.007, -7...  150103
# 100     POLYGON ((-76.828 -12.026, -76.828 -12.026, -7...  150103
# ...                                                   ...     ...
# 141071  POLYGON ((-76.944 -12.145, -76.945 -12.146, -7...  150143
# 141076  POLYGON ((-76.946 -12.164, -76.945 -12.164, -7...  150143
# 141077  POLYGON ((-76.950 -12.134, -76.950 -12.135, -7...  150143
# 141081  POLYGON ((-76.947 -12.144, -76.947 -12.144, -7...  150143
# 141092  POLYGON ((-76.937 -12.169, -76.937 -12.169, -7...  150143
#
#                    Mz centroids Institución Departamento Provincia  \
# 30      POINT (-76.821 -12.016)       MINSA         LIMA      LIMA
# 51      POINT (-76.958 -12.059)       MINSA         LIMA      LIMA
# 66      POINT (-76.827 -12.022)       MINSA         LIMA      LIMA
# 96      POINT (-76.829 -12.008)       MINSA         LIMA      LIMA
# 100     POINT (-76.827 -12.026)       MINSA         LIMA      LIMA
# ...                         ...         ...          ...       ...
# 141071  POINT (-76.945 -12.146)       MINSA         LIMA      LIMA
# 141076  POINT (-76.945 -12.164)       MINSA         LIMA      LIMA
# 141077  POINT (-76.950 -12.134)       MINSA         LIMA      LIMA
# 141081  POINT (-76.947 -12.144)       MINSA         LIMA      LIMA
# 141092  POINT (-76.937 -12.169)       MINSA         LIMA      LIMA
#
#                        Distrito  lat_original long_original  \
# 30                          ATE    -12.016739  -76.82504094
# 51                          ATE    -12.055808   -76.9528728
# 66                          ATE    -12.016739  -76.82504094
# 96                          ATE    -12.016739  -76.82504094
# 100                         ATE    -12.016739  -76.82504094
# ...                         ...           ...           ...
# 141071  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
# 141076  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
# 141077  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
# 141081  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
# 141092  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
#
#                          geometry_y  Distancia  Treatment  Control  \
# 30      POINT (-76.82504 -12.01674)   0.003664          1        0
# 51      POINT (-76.95287 -12.05581)   0.006121          1        0
# 66      POINT (-76.82504 -12.01674)   0.005876          1        0
# 96      POINT (-76.82504 -12.01674)   0.009499          1        0
# 100     POINT (-76.82504 -12.01674)   0.009815          1        0
# ...                             ...        ...        ...      ...
# 141071  POINT (-76.94825 -12.13666)   0.009532          1        0
# 141076  POINT (-76.93821 -12.16157)   0.007750          1        0
# 141077  POINT (-76.94825 -12.13666)   0.003014          1        0
# 141081  POINT (-76.94825 -12.13666)   0.007478          1        0
# 141092  POINT (-76.93821 -12.16157)   0.007673          1        0
#
#         Distancia_KM
# 30          0.366407
# 51          0.612093
# 66          0.587570
# 96          0.949890
# 100         0.981495
# ...              ...
# 141071      0.953153
# 141076      0.775031
# 141077      0.301392
# 141081      0.747760
# 141092      0.767326
#
# [12357 rows x 15 columns]

# %%
control1 = mapa3.loc[(mapa3['Control'].astype(str)).str.contains("1") ]
control1
# Out:
#                  id_manzana  \
# 0        150103000108200012
# 14      150103000106400045N
# 26       150103000105100039
# 38      150103000106900019A
# 40       150103000105500044
# ...                     ...
# 141072  150143000102100003A
# 141082   150143000101000027
# 141085  150143000101100024B
# 141088  150143000102900043B
# 141089  150143000108700007B
#
#                                                geometry_x  UBIGEO  \
# 0       POLYGON ((-76.822 -12.033, -76.822 -12.033, -7...  150103
# 14      POLYGON ((-76.814 -12.010, -76.814 -12.010, -7...  150103
# 26      POLYGON ((-76.836 -12.023, -76.836 -12.023, -7...  150103
# 38      POLYGON ((-76.814 -12.022, -76.814 -12.023, -7...  150103
# 40      POLYGON ((-76.835 -12.001, -76.834 -12.001, -7...  150103
# ...                                                   ...     ...
# 141072  POLYGON ((-76.944 -12.145, -76.945 -12.146, -7...  150143
# 141082  POLYGON ((-76.947 -12.144, -76.947 -12.144, -7...  150143
# 141085  POLYGON ((-76.957 -12.143, -76.957 -12.143, -7...  150143
# 141088  POLYGON ((-76.951 -12.161, -76.951 -12.160, -7...  150143
# 141089  POLYGON ((-76.934 -12.129, -76.935 -12.129, -7...  150143
#
#                    Mz centroids Institución Departamento Provincia  \
# 0       POINT (-76.822 -12.033)       MINSA         LIMA      LIMA
# 14      POINT (-76.814 -12.010)       MINSA         LIMA      LIMA
# 26      POINT (-76.836 -12.024)       MINSA         LIMA      LIMA
# 38      POINT (-76.814 -12.023)       MINSA         LIMA      LIMA
# 40      POINT (-76.834 -12.001)       MINSA         LIMA      LIMA
# ...                         ...         ...          ...       ...
# 141072  POINT (-76.945 -12.146)       MINSA         LIMA      LIMA
# 141082  POINT (-76.947 -12.144)       MINSA         LIMA      LIMA
# 141085  POINT (-76.957 -12.143)       MINSA         LIMA      LIMA
# 141088  POINT (-76.951 -12.161)       MINSA         LIMA      LIMA
# 141089  POINT (-76.934 -12.129)       MINSA         LIMA      LIMA
#
#                        Distrito  lat_original long_original  \
# 0                           ATE    -12.016739  -76.82504094
# 14                          ATE    -12.016739  -76.82504094
# 26                          ATE    -12.016739  -76.82504094
# 38                          ATE    -12.016739  -76.82504094
# 40                          ATE    -12.016739  -76.82504094
# ...                         ...           ...           ...
# 141072  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
# 141082  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
# 141085  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
# 141088  VILLA MARIA DEL TRIUNFO    -12.161575   -76.9382139
# 141089  VILLA MARIA DEL TRIUNFO    -12.136658   -76.9482472
#
#                          geometry_y  Distancia  Treatment  Control  \
# 0       POINT (-76.82504 -12.01674)   0.016604          0        1
# 14      POINT (-76.82504 -12.01674)   0.012967          0        1
# 26      POINT (-76.82504 -12.01674)   0.012918          0        1
# 38      POINT (-76.82504 -12.01674)   0.012649          0        1
# 40      POINT (-76.82504 -12.01674)   0.017881          0        1
# ...                             ...        ...        ...      ...
# 141072  POINT (-76.93821 -12.16157)   0.017336          0        1
# 141082  POINT (-76.93821 -12.16157)   0.019640          0        1
# 141085  POINT (-76.94825 -12.13666)   0.010697          0        1
# 141088  POINT (-76.93821 -12.16157)   0.012654          0        1
# 141089  POINT (-76.94825 -12.13666)   0.015962          0        1
#
#         Distancia_KM
# 0           1.660393
# 14          1.296656
# 26          1.291758
# 38          1.264890
# 40          1.788127
# ...              ...
# 141072      1.733617
# 141082      1.963962
# 141085      1.069683
# 141088      1.265443
# 141089      1.596186
#
# [22869 rows x 15 columns]

# %%
mapa3['Neutral'] = np.where(mapa3['Distancia_KM'] >2, 1, 0)
mapa3['Neutral']
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 141096    1
# 141097    1
# 141098    1
# 141099    1
# 141100    1
# Name: Neutral, Length: 141101, dtype: int32

# %%
f, ax = plt.subplots(1, figsize=(20,20))


T_1 = ax.hexbin(mapa3.lat_original, mapa3.long_original, C = mapa3.Treatment, gridsize=100, alpha=1, linewidths = 1, cmap='reds', edgecolors = 'red', label = 'Treatment')
C_1 = ax.hexbin(mapa3.lat_original, mapa3.long_original, C = mapa3.Control, gridsize=100, alpha=1, linewidths = 1, cmap='blue', edgecolors = 'blue', label = 'Control')
N_1 = ax.hexbin(mapa3.lat_original, mapa3.long_original, C = mapa3.Neutral, gridsize=100, alpha=1, linewidths = 1, cmap='gray', edgecolors = 'black', label = 'Neutral')

cx.add_basemap(ax, crs="EPSG:4326", source=cx.providers.OpenStreetMap.Mapnik, zoom = 15)

plt.xticks([])
plt.yticks([])

plt.title('MENTAL HEALTH CENTER - treatment and control')
plt.legend(loc='upper right',frameon=True, bbox_to_anchor=(1, 1), prop={'size': 10})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 4>()
#       1 f, ax = plt.subplots(1, figsize=(20,20))
# ----> 4 T_1 = ax.hexbin(mapa3.lat_original, mapa3.long_original, C = Treatment1, gridsize=100, alpha=1, linewidths = 1, cmap='reds', edgecolors = 'red', label = 'Treatment')
#       5 C_1 = ax.hexbin(mapa3.lat_original, mapa3.long_original, C = mapa3.Control, gridsize=100, alpha=1, linewidths = 1, cmap='blue', edgecolors = 'blue', label = 'Control')
#       6 N_1 = ax.hexbin(mapa3.lat_original, mapa3.long_original, C = mapa3.Neutral, gridsize=100, alpha=1, linewidths = 1, cmap='gray', edgecolors = 'black', label = 'Neutral')
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\axes\_axes.py:4628, in Axes.hexbin(self, x, y, C, gridsize, bins, xscale, yscale, extent, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, reduce_C_function, mincnt, marginals, **kwargs)
#    4485 @_preprocess_data(replace_names=["x", "y", "C"], label_namer="y")
#    4486 @docstring.dedent_interpd
#    4487 def hexbin(self, x, y, C=None, gridsize=100, bins=None,
#    (...)
#    4491            reduce_C_function=np.mean, mincnt=None, marginals=False,
#    4492            **kwargs):
#    4493     """
#    4494     Make a 2D hexagonal binning plot of points *x*, *y*.
#    4495
#    (...)
#    4626     hist2d : 2D histogram rectangular bins
#    4627     """
# -> 4628     self._process_unit_info([("x", x), ("y", y)], kwargs, convert=False)
#    4630     x, y, C = cbook.delete_masked_points(x, y, C)
#    4632     # Set the size of the hexagon grid
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\axes\_base.py:2526, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2524     # Update from data if axis is already set but no unit is set yet.
#    2525     if axis is not None and data is not None and not axis.have_units():
# -> 2526         axis.update_units(data)
#    2527 for axis_name, axis in axis_map.items():
#    2528     # Return if no axis is set.
#    2529     if axis is None:
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\axis.py:1449, in Axis.update_units(self, data)
#    1447 neednew = self.converter != converter
#    1448 self.converter = converter
# -> 1449 default = self.converter.default_units(data, self)
#    1450 if default is not None and self.units is None:
#    1451     self.set_units(default)
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
